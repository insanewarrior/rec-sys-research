# %%
import numpy as np
import pandas as pd
import optuna
from scipy.sparse import csr_matrix
from weighting_strategies import (
    bm25_weight, tfidf_weight, normalized_weight,
    log_weight, confidence_weight, power_weight,
    pmi_weight, robust_user_centric_weight, sigmoid_propensity_weight, power_lift_weight, robust_user_centric_weight_v2
)
from implicit.als import AlternatingLeastSquares
from implicit.evaluation import train_test_split, precision_at_k, ndcg_at_k

# %%
import sys
import os

# Add the parent directory to sys.path to resolve imports from sibling directories
sys.path.append(os.path.abspath(".."))

from utils.sparse import transform_dataframe_to_sparse

# %%
lastfm_df = (
    pd.read_csv(
        "/home/coder/projects/rec-sys-research/data/lastfm-dataset-360K/usersha1-artmbid-artname-plays.tsv",
        sep="\t",
        header=None,
        usecols=[0, 2, 3],
        names=['user_id', 'item_id', 'play_count'],
    )
    .loc[:, ['user_id', 'item_id', 'play_count']]
    .dropna()
    .rename(columns={'play_count': 'target'})
)
lastfm_df['user_id'].nunique(), lastfm_df['item_id'].nunique(), lastfm_df.shape[0]
# Out:
# (358868, 292363, 17535451)

# %%
user_item_matrix, user_mapping, item_mapping = transform_dataframe_to_sparse(
    lastfm_df, row_field='user_id', col_field='item_id', data_field='target'
)


train_val_mat, test_mat = train_test_split(user_item_matrix, train_percentage=0.9, random_state=42)
train_mat, val_mat = train_test_split(train_val_mat, train_percentage=0.9, random_state=42)

print(f"Train Shape: {train_mat.shape}, Val Shape: {val_mat.shape}, Test Shape: {test_mat.shape}")
# Out:
# Train Shape: (358868, 292363), Val Shape: (358868, 292363), Test Shape: (358868, 292363)

# %%
results_folder = "results/lastfm_360k"
results_filename = "lastfm_360k_experiment_results.csv"

import time

def run_hyperparameter_optimization(
    train_mat: csr_matrix,
    val_mat: csr_matrix,
    train_val_mat: csr_matrix,
    test_mat: csr_matrix,
    weighting_strategy: str,
    algorithm: str,
    n_trials: int = 20,
    output_dir: str = None,
) -> pd.DataFrame:
    results = []
    algorithms = {
        "ALS_factors=10": lambda: AlternatingLeastSquares(factors=10, random_state=42),
        "ALS_factors=100": lambda: AlternatingLeastSquares(factors=100, random_state=42),
    }
    strategies = [
        "no_weighting",
        "bm25",
        "tfidf",
        "log", 
        "confidence",
        "power",
        "normalized",
        "pmi",
        "robust_user_centric",
        "robust_user_centric_weight_v2",
        "sigmoid_propensity",
        "power_lift"
    ]
    if weighting_strategy not in strategies:
        raise ValueError(f"Weighting strategy '{weighting_strategy}' is not recognized.")
    strategy = weighting_strategy

    if algorithm not in algorithms:
        raise ValueError(f"Algorithm '{algorithm}' is not recognized.")
    algo_name = algorithm
    AlgoFactory = algorithms[algorithm]

    print(f"Running optimization for {algo_name} with {strategy}...")

    def get_weighted_matrix(matrix, params):
        weighted = matrix.copy()
        if strategy == "bm25":
            weighted = bm25_weight(weighted, K1=params.get("bm25_k1"), B=params.get("bm25_b"))
        elif strategy == "confidence":
            weighted = confidence_weight(weighted, alpha=params.get("conf_alpha"))
        elif strategy == "power":
            weighted = power_weight(weighted, p=params.get("power_p"))
        elif strategy == "tfidf":
            weighted = tfidf_weight(weighted)
        elif strategy == "log":
            weighted = log_weight(weighted)
        elif strategy == "normalized":
            weighted = normalized_weight(weighted)
        elif strategy == "pmi":
            weighted = pmi_weight(weighted)
        elif strategy == "robust_user_centric":
            weighted = robust_user_centric_weight(weighted, scale_factor=params.get("scale_factor"))
        elif strategy == "sigmoid_propensity":
            weighted = sigmoid_propensity_weight(weighted, p=params.get("p"), beta=params.get("beta"))
        elif strategy == "power_lift":
            weighted = power_lift_weight(weighted, p=params.get("p"))
        elif strategy == "robust_user_centric_weight_v2":
            weighted = robust_user_centric_weight_v2(weighted, lower_q=params.get("lower_q"), upper_q=params.get("upper_q"))
        return weighted

    def objective(trial):
        params = {}
        # Suggest weighting strategy parameters
        if strategy == "bm25":
            params["bm25_k1"] = trial.suggest_float("bm25_k1", 0.1, 1000)
            params["bm25_b"] = trial.suggest_float("bm25_b", 0.0, 1.0)
        elif strategy == "confidence":
            params["conf_alpha"] = trial.suggest_float("conf_alpha", 1.0, 150.0)
        elif strategy == "power":
            params["power_p"] = trial.suggest_float("power_p", 0.1, 1.5)
        elif strategy == "robust_user_centric":
            params["scale_factor"] = trial.suggest_float("scale_factor", 0.1, 10.0)
        elif strategy == "robust_user_centric_weight_v2":
            params["lower_q"] = trial.suggest_float("lower_q", 5.0, 45.0)
            params["upper_q"] = trial.suggest_float("upper_q", 55.0, 95.0)
        elif strategy == "sigmoid_propensity":
            params["p"] = trial.suggest_float("p", 0.1, 5.0)
            params["beta"] = trial.suggest_float("beta", 0.0, 1.0)
        elif strategy == "power_lift":
            params["p"] = trial.suggest_float("p", 0.1, 1.5)
        weighted_train = get_weighted_matrix(train_mat, params)
        
        # Train Model
        model = AlgoFactory()
        model.fit(weighted_train, show_progress=False)

        # Evaluate on Validation Set
        return ndcg_at_k(model, train_mat, val_mat, K=20, show_progress=False)

    # Optimize only if strategy has parameters
    current_trials = n_trials if strategy in ["bm25", "confidence", "power", "robust_user_centric", "robust_user_centric_weight_v2", "sigmoid_propensity", "power_lift"] else 1
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=current_trials, n_jobs=-1)

    # --- Final Retraining & Testing ---
    # Use best params to weight the full train_val matrix
    best_params = study.best_params
    weighted_train_val = get_weighted_matrix(train_val_mat, best_params)

    # Train Final Model
    final_model = AlgoFactory()
    
    start_time = time.time()
    final_model.fit(weighted_train_val, show_progress=False)
    end_time = time.time()
    
    # Evaluate on Test Set
    test_ndcg_10 = ndcg_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    test_precision_10 = precision_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    test_ndcg_20 = ndcg_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)
    test_precision_20 = precision_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)

    results.append({
        "Algorithm": algo_name,
        "Strategy": strategy,
        "Number of Optimization Trials": current_trials,
        "Best Val NDCG@20": study.best_value,
        "Test NDCG@10": test_ndcg_10,
        "Test NDCG@20": test_ndcg_20,
        "Test Precision@10": test_precision_10,
        "Test Precision@20": test_precision_20,
        "Final Train Time (s)": end_time - start_time,
        "Best Params": best_params
    })

    if output_dir:
        output_path = os.path.join(output_dir, f"{algo_name}_{strategy}_results.csv")
        pd.DataFrame(results).to_csv(output_path, index=False)
    return pd.DataFrame(results)

# %%
if not os.path.exists(results_folder):
    os.makedirs(results_folder)

# Execution of all experiments
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="confidence", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="confidence", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 09:25:14,851] A new study created in memory with name: no-name-af5ef919-2b93-421d-a4fd-849484d241b9
# Running optimization for ALS_factors=10 with no_weighting...
# [I 2026-01-30 09:25:25,418] Trial 0 finished with value: 0.09808161938868308 and parameters: {}. Best is trial 0 with value: 0.09808161938868308.
# [I 2026-01-30 09:25:42,413] A new study created in memory with name: no-name-499a5779-4433-46d4-87e8-647884361337
# Running optimization for ALS_factors=10 with bm25...
# [I 2026-01-30 09:26:21,753] Trial 1 finished with value: 0.09645463137925213 and parameters: {'bm25_k1': 225.48082597129576, 'bm25_b': 0.5287138717868045}. Best is trial 1 with value: 0.09645463137925213.
# [I 2026-01-30 09:26:21,814] Trial 3 finished with value: 0.11396118964270216 and parameters: {'bm25_k1': 23.043610429295562, 'bm25_b': 0.08553331531117592}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:26:22,187] Trial 0 finished with value: 0.09083202639244789 and parameters: {'bm25_k1': 390.3740339836404, 'bm25_b': 0.8429585315007274}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:26:22,662] Trial 2 finished with value: 0.08696873586782118 and parameters: {'bm25_k1': 730.9996598439025, 'bm25_b': 0.3629667005323126}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:00,568] Trial 4 finished with value: 0.08377728399514059 and parameters: {'bm25_k1': 999.0718547570991, 'bm25_b': 0.9304015463815763}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:00,988] Trial 6 finished with value: 0.10713892424112442 and parameters: {'bm25_k1': 73.08912261287642, 'bm25_b': 0.19772526426285586}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:01,263] Trial 5 finished with value: 0.08750993245564197 and parameters: {'bm25_k1': 656.4801619303367, 'bm25_b': 0.3329952698830747}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:01,907] Trial 7 finished with value: 0.08866428559794721 and parameters: {'bm25_k1': 561.5983485991102, 'bm25_b': 0.743489865162212}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:39,383] Trial 8 finished with value: 0.08589341956055456 and parameters: {'bm25_k1': 711.7530754833342, 'bm25_b': 0.9148698854131517}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:40,262] Trial 10 finished with value: 0.09487757223854561 and parameters: {'bm25_k1': 253.75655899310456, 'bm25_b': 0.761262544583418}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:40,308] Trial 9 finished with value: 0.08306932897749916 and parameters: {'bm25_k1': 972.3910034671267, 'bm25_b': 0.9731285673669118}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:27:40,986] Trial 11 finished with value: 0.09224955132938627 and parameters: {'bm25_k1': 355.6037292064945, 'bm25_b': 0.6924664847785981}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:28:19,041] Trial 12 finished with value: 0.0967682769746886 and parameters: {'bm25_k1': 217.65920502682104, 'bm25_b': 0.5310692716314643}. Best is trial 3 with value: 0.11396118964270216.
# [I 2026-01-30 09:28:19,207] Trial 14 finished with value: 0.11409730921204898 and parameters: {'bm25_k1': 21.764106966378222, 'bm25_b': 0.11015425545713609}. Best is trial 14 with value: 0.11409730921204898.
# [I 2026-01-30 09:28:19,253] Trial 13 finished with value: 0.10969904961010113 and parameters: {'bm25_k1': 52.864198124795905, 'bm25_b': 0.03440999080356516}. Best is trial 14 with value: 0.11409730921204898.
# [I 2026-01-30 09:28:20,012] Trial 15 finished with value: 0.11408357507214836 and parameters: {'bm25_k1': 21.79733500107922, 'bm25_b': 0.01844071271685349}. Best is trial 14 with value: 0.11409730921204898.
# [I 2026-01-30 09:28:58,636] Trial 16 finished with value: 0.11461017179811724 and parameters: {'bm25_k1': 9.387383629695933, 'bm25_b': 0.0038424319961242737}. Best is trial 16 with value: 0.11461017179811724.
# [I 2026-01-30 09:28:58,886] Trial 18 finished with value: 0.11361330040276456 and parameters: {'bm25_k1': 25.87593698223508, 'bm25_b': 0.0252104822380465}. Best is trial 16 with value: 0.11461017179811724.
# [I 2026-01-30 09:28:58,964] Trial 17 finished with value: 0.11297239983982493 and parameters: {'bm25_k1': 4.672546161886903, 'bm25_b': 0.020952568980264}. Best is trial 16 with value: 0.11461017179811724.
# [I 2026-01-30 09:28:59,652] Trial 19 finished with value: 0.10217429926333753 and parameters: {'bm25_k1': 124.28682055882362, 'bm25_b': 0.180397045856362}. Best is trial 16 with value: 0.11461017179811724.
# [I 2026-01-30 09:29:17,582] A new study created in memory with name: no-name-98b53ac8-e01a-4f1d-b791-1ce5786f9cf4
# Running optimization for ALS_factors=10 with tfidf...
# [I 2026-01-30 09:29:28,352] Trial 0 finished with value: 0.1146309868035351 and parameters: {}. Best is trial 0 with value: 0.1146309868035351.
# [I 2026-01-30 09:29:46,019] A new study created in memory with name: no-name-4233da7f-b9ae-433b-8f51-5ba6212e0b60
# Running optimization for ALS_factors=10 with log...
# [I 2026-01-30 09:29:56,637] Trial 0 finished with value: 0.10210944790580578 and parameters: {}. Best is trial 0 with value: 0.10210944790580578.
# [I 2026-01-30 09:30:14,119] A new study created in memory with name: no-name-d48e733b-7631-465d-a79f-36b10077d074
# Running optimization for ALS_factors=10 with confidence...
# [I 2026-01-30 09:30:53,878] Trial 2 finished with value: 0.07350820068458522 and parameters: {'conf_alpha': 42.33838823372816}. Best is trial 2 with value: 0.07350820068458522.
# [I 2026-01-30 09:30:53,900] Trial 1 finished with value: 0.05774193219206872 and parameters: {'conf_alpha': 70.98950379116994}. Best is trial 2 with value: 0.07350820068458522.
# [I 2026-01-30 09:30:53,987] Trial 3 finished with value: 0.11447390417293594 and parameters: {'conf_alpha': 3.4723751724861236}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:30:54,777] Trial 0 finished with value: 0.11321030775236014 and parameters: {'conf_alpha': 4.807304457674045}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:31:33,130] Trial 6 finished with value: 0.043196260985178224 and parameters: {'conf_alpha': 114.93416101961503}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:31:33,385] Trial 5 finished with value: 0.07322683406489643 and parameters: {'conf_alpha': 42.74285535118129}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:31:33,489] Trial 4 finished with value: 0.10380858798304045 and parameters: {'conf_alpha': 11.63479304501285}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:31:34,079] Trial 7 finished with value: 0.04801325309371992 and parameters: {'conf_alpha': 97.40386769945995}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:12,255] Trial 9 finished with value: 0.0495597659969569 and parameters: {'conf_alpha': 92.58412911336546}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:12,757] Trial 8 finished with value: 0.11277276825500553 and parameters: {'conf_alpha': 5.213608498060633}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:12,929] Trial 10 finished with value: 0.039485040431191165 and parameters: {'conf_alpha': 131.13850808419022}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:14,143] Trial 11 finished with value: 0.055437354258187826 and parameters: {'conf_alpha': 76.4090795335715}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:51,670] Trial 12 finished with value: 0.04090451966762646 and parameters: {'conf_alpha': 124.6421478400389}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:51,835] Trial 14 finished with value: 0.08011536728187371 and parameters: {'conf_alpha': 33.76248002019494}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:51,880] Trial 13 finished with value: 0.03659342018881251 and parameters: {'conf_alpha': 145.75124216441287}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:32:52,702] Trial 15 finished with value: 0.08438843495372576 and parameters: {'conf_alpha': 28.880644146350885}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:33:31,388] Trial 16 finished with value: 0.08135968681700896 and parameters: {'conf_alpha': 32.26858565989716}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:33:31,634] Trial 17 finished with value: 0.0938819280941101 and parameters: {'conf_alpha': 19.527569146380543}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:33:31,809] Trial 18 finished with value: 0.09604830750003052 and parameters: {'conf_alpha': 17.67856753250787}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:33:32,230] Trial 19 finished with value: 0.09663758525566185 and parameters: {'conf_alpha': 17.223363322224515}. Best is trial 3 with value: 0.11447390417293594.
# [I 2026-01-30 09:33:49,980] A new study created in memory with name: no-name-ababa257-f578-4d22-a15e-458de771b455
# Running optimization for ALS_factors=10 with power...
# [I 2026-01-30 09:34:29,148] Trial 0 finished with value: 0.10667022772820259 and parameters: {'power_p': 0.8870287414332618}. Best is trial 0 with value: 0.10667022772820259.
# [I 2026-01-30 09:34:29,170] Trial 1 finished with value: 0.10830827288019904 and parameters: {'power_p': 0.8563317979394065}. Best is trial 1 with value: 0.10830827288019904.
# [I 2026-01-30 09:34:29,529] Trial 3 finished with value: 0.06351875931855616 and parameters: {'power_p': 1.2855158061510616}. Best is trial 1 with value: 0.10830827288019904.
# [I 2026-01-30 09:34:32,302] Trial 2 finished with value: 0.11239626472652683 and parameters: {'power_p': 0.6938791834954882}. Best is trial 2 with value: 0.11239626472652683.
# [I 2026-01-30 09:35:07,539] Trial 4 finished with value: 0.11019462873652298 and parameters: {'power_p': 0.8131235114248311}. Best is trial 2 with value: 0.11239626472652683.
# [I 2026-01-30 09:35:07,916] Trial 5 finished with value: 0.09227084439569026 and parameters: {'power_p': 1.0586126065280625}. Best is trial 2 with value: 0.11239626472652683.
# [I 2026-01-30 09:35:08,058] Trial 6 finished with value: 0.11240020762506509 and parameters: {'power_p': 0.6904827002362887}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:35:19,820] Trial 7 finished with value: 0.10367117709506399 and parameters: {'power_p': 0.9314223219168872}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:35:46,359] Trial 8 finished with value: 0.10783377206501325 and parameters: {'power_p': 0.4535145301300517}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:35:46,544] Trial 9 finished with value: 0.10077994114400224 and parameters: {'power_p': 0.2755837129871958}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:35:46,973] Trial 10 finished with value: 0.11117029068340321 and parameters: {'power_p': 0.7822957536417443}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:35:59,934] Trial 11 finished with value: 0.05110795662566095 and parameters: {'power_p': 1.3820679400328626}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:36:25,384] Trial 12 finished with value: 0.04358118652703053 and parameters: {'power_p': 1.4446990861364843}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:36:25,945] Trial 14 finished with value: 0.10977775239951541 and parameters: {'power_p': 0.5135321921789735}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:36:26,064] Trial 13 finished with value: 0.037843505802175485 and parameters: {'power_p': 1.4961190872089163}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:36:38,794] Trial 15 finished with value: 0.11135593806912635 and parameters: {'power_p': 0.5843260542558932}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:37:04,711] Trial 18 finished with value: 0.11097767583018091 and parameters: {'power_p': 0.5628851451926896}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:37:05,146] Trial 16 finished with value: 0.11013503488289647 and parameters: {'power_p': 0.527990038931219}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:37:05,409] Trial 17 finished with value: 0.11119325733733078 and parameters: {'power_p': 0.5751617779213289}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:37:06,124] Trial 19 finished with value: 0.09348136432267222 and parameters: {'power_p': 0.10537660604999444}. Best is trial 6 with value: 0.11240020762506509.
# [I 2026-01-30 09:37:23,689] A new study created in memory with name: no-name-7137529b-7f1a-46e6-b947-74ed6c115af4
# Running optimization for ALS_factors=10 with normalized...
# [I 2026-01-30 09:37:34,484] Trial 0 finished with value: 0.05012925938321616 and parameters: {}. Best is trial 0 with value: 0.05012925938321616.
# [I 2026-01-30 09:37:52,213] A new study created in memory with name: no-name-bde56cd8-ef1f-4b70-90a9-e0a3f37f97f9
# Running optimization for ALS_factors=10 with pmi...
# [I 2026-01-30 09:38:03,241] Trial 0 finished with value: 0.10324318466406207 and parameters: {}. Best is trial 0 with value: 0.10324318466406207.
# [I 2026-01-30 09:38:21,224] A new study created in memory with name: no-name-933bc0b1-efcd-4a55-8ff5-8da1d1331939
# Running optimization for ALS_factors=10 with robust_user_centric...
# [I 2026-01-30 09:42:56,799] Trial 0 finished with value: 0.08547782638469505 and parameters: {'scale_factor': 1.4182502870876916}. Best is trial 0 with value: 0.08547782638469505.
# [I 2026-01-30 09:42:58,281] Trial 3 finished with value: 0.09528779818527776 and parameters: {'scale_factor': 3.6456394258394362}. Best is trial 3 with value: 0.09528779818527776.
# [I 2026-01-30 09:42:58,789] Trial 1 finished with value: 0.10264422496993518 and parameters: {'scale_factor': 9.07697856748529}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:43:03,296] Trial 2 finished with value: 0.05471041411490816 and parameters: {'scale_factor': 0.4218659044936013}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:47:32,397] Trial 4 finished with value: 0.09152540317933021 and parameters: {'scale_factor': 2.3969404656359985}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:47:32,514] Trial 5 finished with value: 0.10179194093325622 and parameters: {'scale_factor': 8.150073563872782}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:47:32,526] Trial 6 finished with value: 0.09953101903577578 and parameters: {'scale_factor': 6.138358817200032}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:47:39,224] Trial 7 finished with value: 0.08770344073108982 and parameters: {'scale_factor': 1.6520753166903448}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:52:09,903] Trial 9 finished with value: 0.10036026594584552 and parameters: {'scale_factor': 6.815486195227493}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:52:09,990] Trial 8 finished with value: 0.04769933680244827 and parameters: {'scale_factor': 0.21942400004935542}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:52:10,038] Trial 10 finished with value: 0.05239927456890723 and parameters: {'scale_factor': 0.345368531220035}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:52:16,519] Trial 11 finished with value: 0.10175981877793217 and parameters: {'scale_factor': 8.122158991964804}. Best is trial 1 with value: 0.10264422496993518.
# [I 2026-01-30 09:56:47,575] Trial 14 finished with value: 0.10339599671117254 and parameters: {'scale_factor': 9.983769963713478}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 09:56:48,004] Trial 13 finished with value: 0.10314136258852206 and parameters: {'scale_factor': 9.668612976726243}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 09:56:48,390] Trial 12 finished with value: 0.09997715028372112 and parameters: {'scale_factor': 6.483321423800888}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 09:56:53,995] Trial 15 finished with value: 0.10337496785581812 and parameters: {'scale_factor': 9.95357306200125}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 10:01:18,922] Trial 16 finished with value: 0.10337541309521424 and parameters: {'scale_factor': 9.95587618561208}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 10:01:21,855] Trial 18 finished with value: 0.10336201729976487 and parameters: {'scale_factor': 9.940062822968706}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 10:01:22,093] Trial 19 finished with value: 0.10335528876137963 and parameters: {'scale_factor': 9.933433276607353}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 10:01:22,607] Trial 17 finished with value: 0.10334015090325549 and parameters: {'scale_factor': 9.914810022645057}. Best is trial 14 with value: 0.10339599671117254.
# [I 2026-01-30 10:02:23,926] A new study created in memory with name: no-name-aaf5900b-56b9-44ed-a69a-5587d25a3334
# Running optimization for ALS_factors=10 with robust_user_centric_weight_v2...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:274: RuntimeWarning: overflow encountered in exp
#   weights = 1 / (1 + np.exp(-z_scores))
# [I 2026-01-30 10:06:52,238] Trial 1 finished with value: 0.07497702148224367 and parameters: {'lower_q': 17.054684474727154, 'upper_q': 88.75828970088341}. Best is trial 1 with value: 0.07497702148224367.
# [I 2026-01-30 10:06:55,517] Trial 3 finished with value: 0.07512645065702193 and parameters: {'lower_q': 16.889947575148724, 'upper_q': 86.55849972121413}. Best is trial 3 with value: 0.07512645065702193.
# [I 2026-01-30 10:06:56,069] Trial 2 finished with value: 0.07467974826296521 and parameters: {'lower_q': 37.83213114104956, 'upper_q': 94.72632974475508}. Best is trial 3 with value: 0.07512645065702193.
# [I 2026-01-30 10:07:02,538] Trial 0 finished with value: 0.07543340575300593 and parameters: {'lower_q': 37.49866032450562, 'upper_q': 84.19654698523715}. Best is trial 0 with value: 0.07543340575300593.
# [I 2026-01-30 10:11:17,485] Trial 4 finished with value: 0.07545638013718374 and parameters: {'lower_q': 15.316824786816197, 'upper_q': 80.42660466000878}. Best is trial 4 with value: 0.07545638013718374.
# [I 2026-01-30 10:11:23,500] Trial 5 finished with value: 0.07495706643885089 and parameters: {'lower_q': 30.744061350474546, 'upper_q': 90.7545792648194}. Best is trial 4 with value: 0.07545638013718374.
# [I 2026-01-30 10:11:27,849] Trial 6 finished with value: 0.07602087887398917 and parameters: {'lower_q': 43.76255592142278, 'upper_q': 75.66235114410239}. Best is trial 6 with value: 0.07602087887398917.
# [I 2026-01-30 10:11:32,972] Trial 7 finished with value: 0.07626174653425999 and parameters: {'lower_q': 41.78189238452147, 'upper_q': 67.12470286922166}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:15:41,121] Trial 8 finished with value: 0.0749430881966831 and parameters: {'lower_q': 26.21074992794854, 'upper_q': 90.53801003265431}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:15:48,743] Trial 11 finished with value: 0.0748858399293326 and parameters: {'lower_q': 42.39732778913944, 'upper_q': 92.73502619205192}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:15:50,491] Trial 9 finished with value: 0.07587425874692959 and parameters: {'lower_q': 16.14685331330255, 'upper_q': 72.10197532945978}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:15:58,190] Trial 10 finished with value: 0.07623749430079123 and parameters: {'lower_q': 22.783260004546268, 'upper_q': 62.906350123700435}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:19:35,423] Trial 12 finished with value: 0.07540957943644831 and parameters: {'lower_q': 15.648946306000692, 'upper_q': 81.4770350278155}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:19:50,590] Trial 14 finished with value: 0.07608766356214665 and parameters: {'lower_q': 44.99886714838937, 'upper_q': 62.388504458877506}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:20:28,675] Trial 13 finished with value: 0.07617422058861066 and parameters: {'lower_q': 6.035532053540432, 'upper_q': 60.13067956829898}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:20:29,149] Trial 15 finished with value: 0.0762390207924653 and parameters: {'lower_q': 7.41322999916612, 'upper_q': 57.760072464599574}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:23:53,989] Trial 16 finished with value: 0.07614504855070262 and parameters: {'lower_q': 5.385259810047689, 'upper_q': 60.919263832181606}. Best is trial 7 with value: 0.07626174653425999.
# [I 2026-01-30 10:24:06,666] Trial 17 finished with value: 0.0762727669403032 and parameters: {'lower_q': 6.94444910357142, 'upper_q': 56.26432243864631}. Best is trial 17 with value: 0.0762727669403032.
# [I 2026-01-30 10:24:11,539] Trial 18 finished with value: 0.0761395885074806 and parameters: {'lower_q': 23.91937745635646, 'upper_q': 66.34293749850077}. Best is trial 17 with value: 0.0762727669403032.
# [I 2026-01-30 10:24:15,172] Trial 19 finished with value: 0.0762943393038292 and parameters: {'lower_q': 6.629831898087994, 'upper_q': 55.136222101283046}. Best is trial 19 with value: 0.0762943393038292.
# [I 2026-01-30 10:25:15,977] A new study created in memory with name: no-name-72ef0cbd-56b8-4761-9e24-68e59f57b2c1
# Running optimization for ALS_factors=10 with sigmoid_propensity...
# [I 2026-01-30 10:25:55,476] Trial 0 finished with value: 0.09070460993271304 and parameters: {'p': 2.6409149955034046, 'beta': 0.1608085873047289}. Best is trial 0 with value: 0.09070460993271304.
# [I 2026-01-30 10:25:55,792] Trial 3 finished with value: 0.10094162269150586 and parameters: {'p': 0.8064415679769084, 'beta': 0.9635278769639519}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:25:55,913] Trial 1 finished with value: 0.09036387168510387 and parameters: {'p': 4.381397672869023, 'beta': 0.18618750426686959}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:25:56,503] Trial 2 finished with value: 0.09137222734886385 and parameters: {'p': 3.9988433140702058, 'beta': 0.22502888419299583}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:26:34,909] Trial 4 finished with value: 0.09897519036076431 and parameters: {'p': 2.5894810791033165, 'beta': 0.804469539681696}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:26:35,054] Trial 6 finished with value: 0.09957246447074884 and parameters: {'p': 3.441321763784593, 'beta': 0.998560308928994}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:26:35,135] Trial 5 finished with value: 0.09387694276339478 and parameters: {'p': 2.537769707324331, 'beta': 0.3147989191827095}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:26:36,165] Trial 7 finished with value: 0.09706137237549135 and parameters: {'p': 3.38009311587386, 'beta': 0.6465857623654391}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:14,200] Trial 9 finished with value: 0.10055264306973524 and parameters: {'p': 1.7481680929601473, 'beta': 0.9428963058908514}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:14,238] Trial 8 finished with value: 0.09622407669570546 and parameters: {'p': 4.796320174763177, 'beta': 0.635169029535924}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:14,490] Trial 10 finished with value: 0.09336929112921744 and parameters: {'p': 1.923614220262607, 'beta': 0.2594548138910098}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:15,282] Trial 11 finished with value: 0.09553106209883261 and parameters: {'p': 0.6730478347114075, 'beta': 0.37489486833743846}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:53,010] Trial 13 finished with value: 0.09642965102878577 and parameters: {'p': 0.5005123211056299, 'beta': 0.44691975377287096}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:53,805] Trial 12 finished with value: 0.0986646781407283 and parameters: {'p': 2.9117468117290524, 'beta': 0.7943595475876798}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:27:53,880] Trial 14 finished with value: 0.10030155439335989 and parameters: {'p': 0.19626187616369195, 'beta': 0.930409019017618}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:28:05,203] Trial 15 finished with value: 0.10076927736821865 and parameters: {'p': 0.53700470093488, 'beta': 0.9411487891541694}. Best is trial 3 with value: 0.10094162269150586.
# [I 2026-01-30 10:28:32,080] Trial 16 finished with value: 0.1011108112706664 and parameters: {'p': 1.3502448106625122, 'beta': 0.9973210722816986}. Best is trial 16 with value: 0.1011108112706664.
# [I 2026-01-30 10:28:32,489] Trial 18 finished with value: 0.10018840829019834 and parameters: {'p': 1.376160725660887, 'beta': 0.8549993794715186}. Best is trial 16 with value: 0.1011108112706664.
# [I 2026-01-30 10:28:32,583] Trial 17 finished with value: 0.10112618857305193 and parameters: {'p': 1.3407464432528267, 'beta': 0.999385700616504}. Best is trial 17 with value: 0.10112618857305193.
# [I 2026-01-30 10:28:33,852] Trial 19 finished with value: 0.09967293489822085 and parameters: {'p': 1.2801816495913978, 'beta': 0.788508966206662}. Best is trial 17 with value: 0.10112618857305193.
# [I 2026-01-30 10:28:51,779] A new study created in memory with name: no-name-655d5133-6240-40e3-b774-63180dbbb927
# Running optimization for ALS_factors=10 with power_lift...
# [I 2026-01-30 10:29:31,130] Trial 1 finished with value: 0.09840643667446695 and parameters: {'p': 0.1962671404952741}. Best is trial 1 with value: 0.09840643667446695.
# [I 2026-01-30 10:29:31,377] Trial 3 finished with value: 0.0763305445809577 and parameters: {'p': 0.508414931172264}. Best is trial 1 with value: 0.09840643667446695.
# [I 2026-01-30 10:29:31,669] Trial 2 finished with value: 0.09949741569704201 and parameters: {'p': 0.24499007526353878}. Best is trial 2 with value: 0.09949741569704201.
# [I 2026-01-30 10:29:32,484] Trial 0 finished with value: 0.010682942532240104 and parameters: {'p': 0.95035287912468}. Best is trial 2 with value: 0.09949741569704201.
# [I 2026-01-30 10:30:10,668] Trial 4 finished with value: 2.5881599814219454e-05 and parameters: {'p': 1.333679099885325}. Best is trial 2 with value: 0.09949741569704201.
# [I 2026-01-30 10:30:11,100] Trial 5 finished with value: 0.09955811776923734 and parameters: {'p': 0.25456267182413783}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:30:11,184] Trial 6 finished with value: 0.016849623938643553 and parameters: {'p': 0.8998188276654364}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:30:12,006] Trial 7 finished with value: 0.010109719846495505 and parameters: {'p': 0.9565139500441192}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:30:50,036] Trial 8 finished with value: 0.09803863733736022 and parameters: {'p': 0.3226278502999158}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:30:50,236] Trial 10 finished with value: 0.0895909572891917 and parameters: {'p': 0.40218114406048955}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:30:50,348] Trial 9 finished with value: 0.09708320332788609 and parameters: {'p': 0.15593964920342573}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:30:51,491] Trial 11 finished with value: 2.221058126796329e-05 and parameters: {'p': 1.3432625778637968}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:31:29,154] Trial 12 finished with value: 0.06752248684153732 and parameters: {'p': 0.6064052151608211}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:31:29,818] Trial 14 finished with value: 0.06728916473619219 and parameters: {'p': 0.6087766007044149}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:31:29,857] Trial 13 finished with value: 0.05873357957245345 and parameters: {'p': 0.6817604929302175}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:31:30,563] Trial 15 finished with value: 0.06273957809905768 and parameters: {'p': 0.6503822273407998}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:32:09,180] Trial 16 finished with value: 0.059657070856263004 and parameters: {'p': 0.6750233518254798}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:32:09,394] Trial 17 finished with value: 0.050559948182298926 and parameters: {'p': 0.7321257673169163}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:32:09,560] Trial 18 finished with value: 0.09867973513500664 and parameters: {'p': 0.3069553357676921}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:32:10,305] Trial 19 finished with value: 0.09712799789456726 and parameters: {'p': 0.33922563659704064}. Best is trial 5 with value: 0.09955811776923734.
# [I 2026-01-30 10:32:28,255] A new study created in memory with name: no-name-3af3014c-028d-47c0-aa5d-dc3fc38fcaa9
# Running optimization for ALS_factors=100 with no_weighting...
# [I 2026-01-30 10:32:48,659] Trial 0 finished with value: 0.131321756222197 and parameters: {}. Best is trial 0 with value: 0.131321756222197.
# [I 2026-01-30 10:33:20,621] A new study created in memory with name: no-name-63adced9-7601-4f58-a199-24eb87ec5cf4
# Running optimization for ALS_factors=100 with bm25...
# Warning NaN Detected in row 41275 of 292363
# [I 2026-01-30 10:34:41,049] Trial 2 finished with value: 0.10433326624727622 and parameters: {'bm25_k1': 362.8004977575351, 'bm25_b': 0.34130229611178364}. Best is trial 2 with value: 0.10433326624727622.
# [I 2026-01-30 10:34:41,407] Trial 1 finished with value: 0.10035880185612596 and parameters: {'bm25_k1': 370.2812088759295, 'bm25_b': 0.7468545165189714}. Best is trial 2 with value: 0.10433326624727622.
# [I 2026-01-30 10:34:41,799] Trial 3 finished with value: 0.10049439233833427 and parameters: {'bm25_k1': 574.1764021562484, 'bm25_b': 0.38702549642510187}. Best is trial 2 with value: 0.10433326624727622.
# Warning NaN Detected in row 169221 of 292363
# Warning NaN Detected in row 261 of 292363
# [I 2026-01-30 10:35:13,987] Trial 0 finished with value: 0.17104148728927204 and parameters: {'bm25_k1': 5.807540265751959, 'bm25_b': 0.8488361531754721}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:36:01,704] Trial 6 finished with value: 0.10973767475979215 and parameters: {'bm25_k1': 136.80461240309162, 'bm25_b': 0.9570032618853551}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:36:01,818] Trial 4 finished with value: 0.10037991754453696 and parameters: {'bm25_k1': 483.4495264907254, 'bm25_b': 0.5693567947535958}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:36:01,916] Trial 5 finished with value: 0.09502526606803706 and parameters: {'bm25_k1': 781.991850434663, 'bm25_b': 0.7462910696433608}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:36:35,544] Trial 7 finished with value: 0.11519962988638557 and parameters: {'bm25_k1': 137.3641307274724, 'bm25_b': 0.6221113843408214}. Best is trial 0 with value: 0.17104148728927204.
# Warning NaN Detected in row 304 of 292363
# [I 2026-01-30 10:37:20,732] Trial 8 finished with value: 0.10642616142451355 and parameters: {'bm25_k1': 321.2481140839611, 'bm25_b': 0.05949917038546537}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:37:21,554] Trial 9 finished with value: 0.14094418804139433 and parameters: {'bm25_k1': 40.81471317976915, 'bm25_b': 0.6315561788530554}. Best is trial 0 with value: 0.17104148728927204.
# Warning NaN Detected in row 20736 of 292363
# [I 2026-01-30 10:37:44,316] Trial 10 finished with value: 0.09408343974526687 and parameters: {'bm25_k1': 522.894368243669, 'bm25_b': 0.8929551597870157}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:38:00,360] Trial 11 finished with value: 0.11532696500573271 and parameters: {'bm25_k1': 143.3116764818584, 'bm25_b': 0.5096736740136217}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:38:41,363] Trial 12 finished with value: 0.09578951293414362 and parameters: {'bm25_k1': 863.8274290647827, 'bm25_b': 0.666493511497507}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:38:41,541] Trial 13 finished with value: 0.0892498108901033 and parameters: {'bm25_k1': 977.7216894678162, 'bm25_b': 0.925945355878379}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:39:03,812] Trial 14 finished with value: 0.1225127252439474 and parameters: {'bm25_k1': 87.59579911489763, 'bm25_b': 0.7730824544790905}. Best is trial 0 with value: 0.17104148728927204.
# Warning NaN Detected in row 20760 of 292363
# [I 2026-01-30 10:39:19,459] Trial 15 finished with value: 0.15976554816154415 and parameters: {'bm25_k1': 16.01111296315748, 'bm25_b': 0.8012693957423095}. Best is trial 0 with value: 0.17104148728927204.
# [I 2026-01-30 10:40:01,091] Trial 17 finished with value: 0.1718996025203015 and parameters: {'bm25_k1': 3.6915452916512734, 'bm25_b': 0.8011480654017011}. Best is trial 17 with value: 0.1718996025203015.
# [I 2026-01-30 10:40:02,067] Trial 16 finished with value: 0.15517520124481943 and parameters: {'bm25_k1': 20.485686024082682, 'bm25_b': 0.8274386808102782}. Best is trial 17 with value: 0.1718996025203015.
# [I 2026-01-30 10:40:03,964] Trial 18 finished with value: 0.14039519581874707 and parameters: {'bm25_k1': 43.524800295519356, 'bm25_b': 0.3501732467897569}. Best is trial 17 with value: 0.1718996025203015.
# [I 2026-01-30 10:40:05,706] Trial 19 finished with value: 0.10259164476509278 and parameters: {'bm25_k1': 251.47947008000654, 'bm25_b': 0.8522347992135624}. Best is trial 17 with value: 0.1718996025203015.
# [I 2026-01-30 10:40:38,346] A new study created in memory with name: no-name-ac1df3ac-3db0-41a3-9cf3-48d04af11a5b
# Running optimization for ALS_factors=100 with tfidf...
# [I 2026-01-30 10:40:59,271] Trial 0 finished with value: 0.16187185624065334 and parameters: {}. Best is trial 0 with value: 0.16187185624065334.
# [I 2026-01-30 10:41:31,716] A new study created in memory with name: no-name-a161e34d-acd6-4836-84bc-9a0c269d7e49
# Running optimization for ALS_factors=100 with log...
# [I 2026-01-30 10:41:52,635] Trial 0 finished with value: 0.14743598210264203 and parameters: {}. Best is trial 0 with value: 0.14743598210264203.
# [I 2026-01-30 10:42:24,966] A new study created in memory with name: no-name-324ea7db-bcfc-47d4-9a2d-1db581e5e3b0
# Running optimization for ALS_factors=100 with confidence...
# Warning NaN Detected in row 10494 of 292363
# Warning NaN Detected in row 292 of 292363
# Warning NaN Detected in row 297 of 292363
# Warning NaN Detected in row 297 of 292363
# Warning NaN Detected in row 4894 of 292363
# Warning NaN Detected in row 250 of 292363
# [I 2026-01-30 10:43:44,919] Trial 0 finished with value: 0.04569656325981567 and parameters: {'conf_alpha': 149.60243924624308}. Best is trial 0 with value: 0.04569656325981567.
# [I 2026-01-30 10:43:45,579] Trial 2 finished with value: 0.1425744298894083 and parameters: {'conf_alpha': 5.996994494514863}. Best is trial 2 with value: 0.1425744298894083.
# [I 2026-01-30 10:43:45,916] Trial 3 finished with value: 0.0772757558170844 and parameters: {'conf_alpha': 36.90874032350009}. Best is trial 2 with value: 0.1425744298894083.
# Warning NaN Detected in row 265 of 292363
# Warning NaN Detected in row 250 of 292363
# Warning NaN Detected in row 239 of 292363
# [I 2026-01-30 10:44:18,228] Trial 1 finished with value: 0.06846924461623177 and parameters: {'conf_alpha': 51.15587742332924}. Best is trial 2 with value: 0.1425744298894083.
# [I 2026-01-30 10:45:05,889] Trial 4 finished with value: 0.052016342418598364 and parameters: {'conf_alpha': 108.95255247086911}. Best is trial 2 with value: 0.1425744298894083.
# [I 2026-01-30 10:45:06,488] Trial 5 finished with value: 0.08312389999906447 and parameters: {'conf_alpha': 30.86190481567694}. Best is trial 2 with value: 0.1425744298894083.
# [I 2026-01-30 10:45:06,545] Trial 6 finished with value: 0.061259315437127426 and parameters: {'conf_alpha': 69.47095862601171}. Best is trial 2 with value: 0.1425744298894083.
# Warning NaN Detected in row 30977 of 292363
# [I 2026-01-30 10:45:40,527] Trial 7 finished with value: 0.1699253146311345 and parameters: {'conf_alpha': 1.449770352422187}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:46:26,051] Trial 9 finished with value: 0.061371423373381626 and parameters: {'conf_alpha': 69.12224334979567}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:46:26,229] Trial 8 finished with value: 0.062314402860519216 and parameters: {'conf_alpha': 65.9458651363438}. Best is trial 7 with value: 0.1699253146311345.
# Warning NaN Detected in row 281 of 292363
# [I 2026-01-30 10:46:32,117] Trial 10 finished with value: 0.058357482657754124 and parameters: {'conf_alpha': 79.39218709654341}. Best is trial 7 with value: 0.1699253146311345.
# Warning NaN Detected in row 10532 of 292363
# [I 2026-01-30 10:47:04,740] Trial 11 finished with value: 0.07412505261708756 and parameters: {'conf_alpha': 40.740732076323724}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:47:45,375] Trial 12 finished with value: 0.04894933420580839 and parameters: {'conf_alpha': 127.25782642376019}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:47:45,527] Trial 13 finished with value: 0.13404371417058486 and parameters: {'conf_alpha': 7.7442270538372355}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:47:46,149] Trial 14 finished with value: 0.15147899107645152 and parameters: {'conf_alpha': 4.391428374574824}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:48:27,888] Trial 15 finished with value: 0.15218335710159864 and parameters: {'conf_alpha': 4.276674126411225}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:49:05,257] Trial 17 finished with value: 0.1464170949593133 and parameters: {'conf_alpha': 5.289926101421955}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:49:05,433] Trial 16 finished with value: 0.163819983893304 and parameters: {'conf_alpha': 2.4451204716968276}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:49:08,376] Trial 18 finished with value: 0.1017807397490776 and parameters: {'conf_alpha': 18.355524897652007}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:49:11,539] Trial 19 finished with value: 0.09750188125707855 and parameters: {'conf_alpha': 20.534834199692888}. Best is trial 7 with value: 0.1699253146311345.
# [I 2026-01-30 10:49:44,017] A new study created in memory with name: no-name-4c98c67e-c6ea-4049-8bdb-e433889e89fe
# Running optimization for ALS_factors=100 with power...
# Warning NaN Detected in row 10494 of 292363
# [I 2026-01-30 10:51:05,042] Trial 2 finished with value: 0.1356286845550872 and parameters: {'power_p': 0.960289959637353}. Best is trial 2 with value: 0.1356286845550872.
# [I 2026-01-30 10:51:05,509] Trial 1 finished with value: 0.15780987511642197 and parameters: {'power_p': 0.47714255920378423}. Best is trial 1 with value: 0.15780987511642197.
# [I 2026-01-30 10:51:05,510] Trial 0 finished with value: 0.10972195173895206 and parameters: {'power_p': 1.1722625832953815}. Best is trial 1 with value: 0.15780987511642197.
# Warning NaN Detected in row 252 of 292363
# [I 2026-01-30 10:51:23,895] Trial 3 finished with value: 0.11934578004492365 and parameters: {'power_p': 1.0985968182309662}. Best is trial 1 with value: 0.15780987511642197.
# Warning NaN Detected in row 20793 of 292363
# [I 2026-01-30 10:52:25,740] Trial 5 finished with value: 0.1592873584855438 and parameters: {'power_p': 0.5623046594177248}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:52:26,179] Trial 6 finished with value: 0.09145731698450607 and parameters: {'power_p': 1.3045344079469692}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:52:26,191] Trial 4 finished with value: 0.10798027031275803 and parameters: {'power_p': 1.1842898894116718}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:52:58,929] Trial 7 finished with value: 0.07578791796277239 and parameters: {'power_p': 1.4145332202460854}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:53:45,814] Trial 8 finished with value: 0.06647854608126946 and parameters: {'power_p': 1.4816193279343628}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:53:46,141] Trial 10 finished with value: 0.15439129335618698 and parameters: {'power_p': 0.7369662801732209}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:53:46,601] Trial 9 finished with value: 0.09632314539687196 and parameters: {'power_p': 1.2697751282095588}. Best is trial 5 with value: 0.1592873584855438.
# Warning NaN Detected in row 10492 of 292363
# Warning NaN Detected in row 252 of 292363
# [I 2026-01-30 10:54:22,945] Trial 11 finished with value: 0.14501953300314907 and parameters: {'power_p': 0.284845946817299}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:55:05,392] Trial 12 finished with value: 0.06488104409092349 and parameters: {'power_p': 1.4932093616198119}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:55:05,478] Trial 13 finished with value: 0.12524940413541577 and parameters: {'power_p': 0.13261112015334553}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:55:27,375] Trial 14 finished with value: 0.15359761017564305 and parameters: {'power_p': 0.38711240362760047}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:55:46,632] Trial 15 finished with value: 0.15887325751871959 and parameters: {'power_p': 0.5214898865596391}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:56:25,244] Trial 17 finished with value: 0.15927257942981854 and parameters: {'power_p': 0.5517207151290688}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:56:25,556] Trial 16 finished with value: 0.15403556674974306 and parameters: {'power_p': 0.39389866521074446}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:56:27,221] Trial 18 finished with value: 0.15884454868593945 and parameters: {'power_p': 0.6139870920516253}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:56:29,838] Trial 19 finished with value: 0.1577218886941073 and parameters: {'power_p': 0.6592373393985003}. Best is trial 5 with value: 0.1592873584855438.
# [I 2026-01-30 10:57:02,186] A new study created in memory with name: no-name-2d80824c-b430-4e05-ac36-eceee6b105d9
# Running optimization for ALS_factors=100 with normalized...
# [I 2026-01-30 10:57:23,173] Trial 0 finished with value: 0.06250734770997242 and parameters: {}. Best is trial 0 with value: 0.06250734770997242.
# [I 2026-01-30 10:57:55,648] A new study created in memory with name: no-name-b0a8f3c3-ce37-436b-83cf-26c3315e1136
# Running optimization for ALS_factors=100 with pmi...
# [I 2026-01-30 10:58:16,929] Trial 0 finished with value: 0.16560076612843566 and parameters: {}. Best is trial 0 with value: 0.16560076612843566.
# [I 2026-01-30 10:58:49,599] A new study created in memory with name: no-name-0d47374f-3523-4fc3-b2d6-9a90b9fe1fc4
# Running optimization for ALS_factors=100 with robust_user_centric...
# [I 2026-01-30 11:03:55,590] Trial 0 finished with value: 0.15142964547107038 and parameters: {'scale_factor': 9.065984039553442}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:03:56,484] Trial 3 finished with value: 0.14899793676767595 and parameters: {'scale_factor': 7.861911944382816}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:03:56,989] Trial 2 finished with value: 0.06752354322839166 and parameters: {'scale_factor': 0.47558205414023025}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:04:06,061] Trial 1 finished with value: 0.15021172594419657 and parameters: {'scale_factor': 8.39261796407882}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:09:05,047] Trial 6 finished with value: 0.15055512619577718 and parameters: {'scale_factor': 8.599142416921612}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:09:05,258] Trial 4 finished with value: 0.13737954973615119 and parameters: {'scale_factor': 4.552284117916287}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:09:05,701] Trial 5 finished with value: 0.13549521281424 and parameters: {'scale_factor': 4.227984659703611}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:09:10,748] Trial 7 finished with value: 0.14516273743585367 and parameters: {'scale_factor': 6.438532623038759}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:14:12,360] Trial 10 finished with value: 0.13582095880968417 and parameters: {'scale_factor': 4.279813080304808}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:14:13,346] Trial 8 finished with value: 0.14970724894942697 and parameters: {'scale_factor': 8.175049134819641}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:14:13,519] Trial 9 finished with value: 0.14488467186472215 and parameters: {'scale_factor': 6.33251179335259}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:14:20,407] Trial 11 finished with value: 0.07229943237757328 and parameters: {'scale_factor': 0.6564006041305757}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:19:22,032] Trial 12 finished with value: 0.11431216572248944 and parameters: {'scale_factor': 2.2406078063788386}. Best is trial 0 with value: 0.15142964547107038.
# [I 2026-01-30 11:19:22,113] Trial 13 finished with value: 0.15276630460442683 and parameters: {'scale_factor': 9.918615873011124}. Best is trial 13 with value: 0.15276630460442683.
# [I 2026-01-30 11:19:22,576] Trial 14 finished with value: 0.15187303545565908 and parameters: {'scale_factor': 9.334809272968625}. Best is trial 13 with value: 0.15276630460442683.
# [I 2026-01-30 11:19:29,129] Trial 15 finished with value: 0.15232966605723183 and parameters: {'scale_factor': 9.618915296906014}. Best is trial 13 with value: 0.15276630460442683.
# [I 2026-01-30 11:24:32,594] Trial 17 finished with value: 0.15269411145602627 and parameters: {'scale_factor': 9.872021581166566}. Best is trial 13 with value: 0.15276630460442683.
# [I 2026-01-30 11:24:33,084] Trial 16 finished with value: 0.15273384299816675 and parameters: {'scale_factor': 9.905010725024765}. Best is trial 13 with value: 0.15276630460442683.
# [I 2026-01-30 11:24:33,340] Trial 18 finished with value: 0.15284042789107613 and parameters: {'scale_factor': 9.971762914520497}. Best is trial 18 with value: 0.15284042789107613.
# [I 2026-01-30 11:24:34,576] Trial 19 finished with value: 0.1525505097023619 and parameters: {'scale_factor': 9.776401977353785}. Best is trial 18 with value: 0.15284042789107613.
# [I 2026-01-30 11:25:49,989] A new study created in memory with name: no-name-5a5aa934-3a2a-4a5e-bccb-3c9a0c78f5c4
# Running optimization for ALS_factors=100 with robust_user_centric_weight_v2...
# [I 2026-01-30 11:30:51,368] Trial 2 finished with value: 0.08438849921913427 and parameters: {'lower_q': 26.34900373196878, 'upper_q': 71.60687887281625}. Best is trial 2 with value: 0.08438849921913427.
# [I 2026-01-30 11:30:53,952] Trial 0 finished with value: 0.08512784804145294 and parameters: {'lower_q': 14.330779970503267, 'upper_q': 58.90078507184058}. Best is trial 0 with value: 0.08512784804145294.
# [I 2026-01-30 11:30:54,171] Trial 1 finished with value: 0.08471607170634295 and parameters: {'lower_q': 26.455419523061657, 'upper_q': 68.22022299128602}. Best is trial 0 with value: 0.08512784804145294.
# ...
# [I 2026-01-30 12:01:37,029] Trial 1 finished with value: 0.049552013984328326 and parameters: {'p': 1.1834452998390856}. Best is trial 2 with value: 0.15220963690150588.
# [I 2026-01-30 12:02:25,194] Trial 6 finished with value: 0.09249927921171584 and parameters: {'p': 0.9577574089410725}. Best is trial 2 with value: 0.15220963690150588.
# [I 2026-01-30 12:02:25,500] Trial 4 finished with value: 0.06897392903647954 and parameters: {'p': 1.0897309935535406}. Best is trial 2 with value: 0.15220963690150588.
# [I 2026-01-30 12:02:25,926] Trial 5 finished with value: 0.06869352898628774 and parameters: {'p': 1.0911271058071499}. Best is trial 2 with value: 0.15220963690150588.
# Warning NaN Detected in row 18564 of 292363
# [I 2026-01-30 12:03:00,581] Trial 7 finished with value: 0.1459453359365008 and parameters: {'p': 0.5482787262548102}. Best is trial 2 with value: 0.15220963690150588.
# [I 2026-01-30 12:03:45,400] Trial 8 finished with value: 0.12986284434802156 and parameters: {'p': 0.6937382556898682}. Best is trial 2 with value: 0.15220963690150588.
# [I 2026-01-30 12:03:46,234] Trial 9 finished with value: 0.07151848607469667 and parameters: {'p': 1.0772871172029963}. Best is trial 2 with value: 0.15220963690150588.
# Warning NaN Detected in row 10493 of 292363
# [I 2026-01-30 12:04:09,518] Trial 10 finished with value: 0.14696740462337582 and parameters: {'p': 0.5363860783899831}. Best is trial 2 with value: 0.15220963690150588.
# [I 2026-01-30 12:04:24,132] Trial 11 finished with value: 0.15389283625134473 and parameters: {'p': 0.19791840640680897}. Best is trial 11 with value: 0.15389283625134473.
# [I 2026-01-30 12:05:06,023] Trial 12 finished with value: 0.14168749223925628 and parameters: {'p': 0.5931048796695528}. Best is trial 11 with value: 0.15389283625134473.
# [I 2026-01-30 12:05:06,550] Trial 13 finished with value: 0.1360437326135611 and parameters: {'p': 0.12303263007428455}. Best is trial 11 with value: 0.15389283625134473.
# [I 2026-01-30 12:05:29,740] Trial 14 finished with value: 0.15219265334406368 and parameters: {'p': 0.19041461526917858}. Best is trial 11 with value: 0.15389283625134473.
# Warning NaN Detected in row 192 of 292363
# Warning NaN Detected in row 10528 of 292363
# Warning NaN Detected in row 250 of 292363
# Warning NaN Detected in row 269 of 292363
# Warning NaN Detected in row 20739 of 292363
# Warning NaN Detected in row 10508 of 292363
# Warning NaN Detected in row 10510 of 292363
# Warning NaN Detected in row 51415 of 292363
# Warning NaN Detected in row 174347 of 292363
# Warning NaN Detected in row 245997 of 292363
# Warning NaN Detected in row 194784 of 292363
# Warning NaN Detected in row 31232 of 292363
# Warning NaN Detected in row 11667 of 292363
# Warning NaN Detected in row 185783 of 292363
# Warning NaN Detected in row 103918 of 292363
# Warning NaN Detected in row 186446 of 292363
# Warning NaN Detected in row 12833 of 292363
# Warning NaN Detected in row 4072 of 292363
# Warning NaN Detected in row 45045 of 292363
# Warning NaN Detected in row 169640 of 292363
# Warning NaN Detected in row 27493 of 292363
# Warning NaN Detected in row 27837 of 292363
# Warning NaN Detected in row 233027 of 292363
# Warning NaN Detected in row 8309 of 292363
# Warning NaN Detected in row 209 of 292363
# Warning NaN Detected in row 161 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 10516 of 292363
# Warning NaN Detected in row 41236 of 292363
# Warning NaN Detected in row 123362 of 292363
# Warning NaN Detected in row 42896 of 292363
# Warning NaN Detected in row 105343 of 292363
# Warning NaN Detected in row 75031 of 292363
# Warning NaN Detected in row 126516 of 292363
# Warning NaN Detected in row 106108 of 292363
# Warning NaN Detected in row 15481 of 292363
# Warning NaN Detected in row 5817 of 292363
# Warning NaN Detected in row 5952 of 292363
# Warning NaN Detected in row 16242 of 292363
# Warning NaN Detected in row 169971 of 292363
# Warning NaN Detected in row 47207 of 292363
# Warning NaN Detected in row 78084 of 292363
# Warning NaN Detected in row 100559 of 292363
# Warning NaN Detected in row 39929 of 292363
# Warning NaN Detected in row 276057 of 292363
# Warning NaN Detected in row 92113 of 292363
# Warning NaN Detected in row 10497 of 292363
# Warning NaN Detected in row 10528 of 292363
# Warning NaN Detected in row 20788 of 292363
# Warning NaN Detected in row 10553 of 292363
# Warning NaN Detected in row 10492 of 292363
# Warning NaN Detected in row 30957 of 292363
# Warning NaN Detected in row 51435 of 292363
# Warning NaN Detected in row 30980 of 292363
# Warning NaN Detected in row 30973 of 292363
# Warning NaN Detected in row 30977 of 292363
# Warning NaN Detected in row 103229 of 292363
# Warning NaN Detected in row 93217 of 292363
# Warning NaN Detected in row 175097 of 292363
# Warning NaN Detected in row 134687 of 292363
# Warning NaN Detected in row 196519 of 292363
# Warning NaN Detected in row 32752 of 292363
# Warning NaN Detected in row 247671 of 292363
# Warning NaN Detected in row 239302 of 292363
# Warning NaN Detected in row 278540 of 292363
# Warning NaN Detected in row 27003 of 292363
# Warning NaN Detected in row 27296 of 292363
# Warning NaN Detected in row 88985 of 292363
# Warning NaN Detected in row 120106 of 292363
# Warning NaN Detected in row 209 of 292363
# Warning NaN Detected in row 204 of 292363
# Warning NaN Detected in row 20739 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 10553 of 292363
# Warning NaN Detected in row 20777 of 292363
# Warning NaN Detected in row 61726 of 292363
# Warning NaN Detected in row 41224 of 292363
# Warning NaN Detected in row 575 of 292363
# Warning NaN Detected in row 41761 of 292363
# Warning NaN Detected in row 41816 of 292363
# Warning NaN Detected in row 63882 of 292363
# Warning NaN Detected in row 13120 of 292363
# Warning NaN Detected in row 54941 of 292363
# Warning NaN Detected in row 57778 of 292363
# Warning NaN Detected in row 212153 of 292363
# Warning NaN Detected in row 68984 of 292363
# Warning NaN Detected in row 161 of 292363
# Warning NaN Detected in row 10520 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 20784 of 292363
# Warning NaN Detected in row 31007 of 292363
# Warning NaN Detected in row 82206 of 292363
# Warning NaN Detected in row 72008 of 292363
# Warning NaN Detected in row 41440 of 292363
# Warning NaN Detected in row 206005 of 292363
# Warning NaN Detected in row 43162 of 292363
# Warning NaN Detected in row 65497 of 292363
# Warning NaN Detected in row 171327 of 292363
# Warning NaN Detected in row 28480 of 292363
# Warning NaN Detected in row 8309 of 292363
# Warning NaN Detected in row 275602 of 292363
# Warning NaN Detected in row 50587 of 292363
# Warning NaN Detected in row 256 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 20756 of 292363
# Warning NaN Detected in row 51435 of 292363
# Warning NaN Detected in row 51459 of 292363
# Warning NaN Detected in row 61735 of 292363
# Warning NaN Detected in row 143629 of 292363
# Warning NaN Detected in row 11756 of 292363
# Warning NaN Detected in row 12133 of 292363
# Warning NaN Detected in row 53229 of 292363
# Warning NaN Detected in row 104874 of 292363
# Warning NaN Detected in row 47086 of 292363
# Warning NaN Detected in row 17784 of 292363
# Warning NaN Detected in row 10497 of 292363
# Warning NaN Detected in row 248 of 292363
# Warning NaN Detected in row 10421 of 292363
# Warning NaN Detected in row 292 of 292363
# Warning NaN Detected in row 20777 of 292363
# Warning NaN Detected in row 20756 of 292363
# Warning NaN Detected in row 41205 of 292363
# Warning NaN Detected in row 112908 of 292363
# Warning NaN Detected in row 112885 of 292363
# Warning NaN Detected in row 116722 of 292363
# Warning NaN Detected in row 181 of 292363
# Warning NaN Detected in row 291 of 292363
# Warning NaN Detected in row 10553 of 292363
# Warning NaN Detected in row 30957 of 292363
# Warning NaN Detected in row 20772 of 292363
# Warning NaN Detected in row 20765 of 292363
# Warning NaN Detected in row 55498 of 292363
# Warning NaN Detected in row 15439 of 292363
# Warning NaN Detected in row 5245 of 292363
# Warning NaN Detected in row 78819 of 292363
# Warning NaN Detected in row 38334 of 292363
# Warning NaN Detected in row 60897 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 20755 of 292363
# Warning NaN Detected in row 30999 of 292363
# Warning NaN Detected in row 41224 of 292363
# Warning NaN Detected in row 72623 of 292363
# Warning NaN Detected in row 62462 of 292363
# Warning NaN Detected in row 104364 of 292363
# Warning NaN Detected in row 26644 of 292363
# Warning NaN Detected in row 49070 of 292363
# Warning NaN Detected in row 10413 of 292363
# Warning NaN Detected in row 10553 of 292363
# Warning NaN Detected in row 30986 of 292363
# Warning NaN Detected in row 10504 of 292363
# Warning NaN Detected in row 21498 of 292363
# Warning NaN Detected in row 55668 of 292363
# Warning NaN Detected in row 8309 of 292363
# Warning NaN Detected in row 250 of 292363
# Warning NaN Detected in row 51461 of 292363
# Warning NaN Detected in row 156479 of 292363
# Warning NaN Detected in row 6352 of 292363
# Warning NaN Detected in row 79806 of 292363
# Warning NaN Detected in row 8858 of 292363
# Warning NaN Detected in row 29603 of 292363
# Warning NaN Detected in row 221 of 292363
# Warning NaN Detected in row 270 of 292363
# Warning NaN Detected in row 174336 of 292363
# Warning NaN Detected in row 25237 of 292363
# Warning NaN Detected in row 67549 of 292363
# Warning NaN Detected in row 171 of 292363
# Warning NaN Detected in row 41160 of 292363
# Warning NaN Detected in row 21876 of 292363
# Warning NaN Detected in row 126159 of 292363
# Warning NaN Detected in row 147485 of 292363
# Warning NaN Detected in row 45434 of 292363
# Warning NaN Detected in row 69224 of 292363
# Warning NaN Detected in row 18590 of 292363
# Warning NaN Detected in row 100815 of 292363
# [I 2026-01-30 12:05:41,156] Trial 15 finished with value: 0.13636529567094358 and parameters: {'p': 0.12422404133762173}. Best is trial 11 with value: 0.15389283625134473.
# Warning NaN Detected in row 302 of 292363
# Warning NaN Detected in row 10494 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 20736 of 292363
# Warning NaN Detected in row 124425 of 292363
# Warning NaN Detected in row 37135 of 292363
# Warning NaN Detected in row 67972 of 292363
# Warning NaN Detected in row 16816 of 292363
# Warning NaN Detected in row 277 of 292363
# Warning NaN Detected in row 10520 of 292363
# Warning NaN Detected in row 253 of 292363
# Warning NaN Detected in row 64558 of 292363
# Warning NaN Detected in row 46075 of 292363
# Warning NaN Detected in row 117906 of 292363
# Warning NaN Detected in row 26444 of 292363
# [I 2026-01-30 12:06:26,586] Trial 16 finished with value: 0.14144831396653526 and parameters: {'p': 0.1440733558007744}. Best is trial 11 with value: 0.15389283625134473.
# [I 2026-01-30 12:06:27,308] Trial 17 finished with value: 0.16445197183219615 and parameters: {'p': 0.3200297249072065}. Best is trial 17 with value: 0.16445197183219615.
# [I 2026-01-30 12:06:30,181] Trial 18 finished with value: 0.00790366358894014 and parameters: {'p': 1.4826345150802687}. Best is trial 17 with value: 0.16445197183219615.
# [I 2026-01-30 12:06:31,833] Trial 19 finished with value: 0.1621389483598752 and parameters: {'p': 0.3561350679055588}. Best is trial 17 with value: 0.16445197183219615.
#           Algorithm                       Strategy  Best Val NDCG@20  \
# 13  ALS_factors=100                           bm25          0.171900
# 16  ALS_factors=100                     confidence          0.169925
# 19  ALS_factors=100                            pmi          0.165601
# 23  ALS_factors=100                     power_lift          0.164452
# 14  ALS_factors=100                          tfidf          0.161872
# 17  ALS_factors=100                          power          0.159287
# 22  ALS_factors=100             sigmoid_propensity          0.153111
# 20  ALS_factors=100            robust_user_centric          0.152840
# 15  ALS_factors=100                            log          0.147436
# 12  ALS_factors=100                   no_weighting          0.131322
# 1    ALS_factors=10                           bm25          0.114610
# 2    ALS_factors=10                          tfidf          0.114631
# 4    ALS_factors=10                     confidence          0.114474
# 5    ALS_factors=10                          power          0.112400
# 8    ALS_factors=10            robust_user_centric          0.103396
# 7    ALS_factors=10                            pmi          0.103243
# 3    ALS_factors=10                            log          0.102109
# 10   ALS_factors=10             sigmoid_propensity          0.101126
# 11   ALS_factors=10                     power_lift          0.099558
# 0    ALS_factors=10                   no_weighting          0.098082
# 21  ALS_factors=100  robust_user_centric_weight_v2          0.086504
# 9    ALS_factors=10  robust_user_centric_weight_v2          0.076294
# 18  ALS_factors=100                     normalized          0.062507
# 6    ALS_factors=10                     normalized          0.050129
#
#     Test NDCG@20  Test Precision@20  Final Train Time (s)  \
# 13      0.193160           0.252240             11.137091
# 16      0.189744           0.250750             11.147264
# 19      0.185581           0.240786             11.131036
# 23      0.183018           0.238844             11.150032
# 14      0.179705           0.242950             11.146544
# 17      0.178433           0.235119             11.150032
# 22      0.174393           0.227104             11.128924
# 20      0.173146           0.225228             10.704933
# 15      0.167481           0.217905             11.140960
# 12      0.142881           0.204102             11.130598
# 1       0.124624           0.168903              4.174777
# 2       0.124477           0.169742              4.194253
# 4       0.124321           0.170267              4.209464
# 5       0.122256           0.165936              4.175077
# 8       0.112715           0.151360              4.113441
# 7       0.111911           0.151696              4.183029
# 3       0.111352           0.149873              4.155737
# 10      0.109871           0.148840              4.186923
# 11      0.107839           0.147069              4.197246
# 0       0.105054           0.149948              4.097863
# 21      0.099963           0.135608             10.705075
# 9       0.088514           0.121681              4.124685
# 18      0.069045           0.097674             11.141204
# 6       0.055152           0.080327              4.197005
#
#                                           Best Params
# 13  {'bm25_k1': 3.6915452916512734, 'bm25_b': 0.80...
# 16                  {'conf_alpha': 1.449770352422187}
# 19                                                 {}
# 23                          {'p': 0.3200297249072065}
# 14                                                 {}
# 17                    {'power_p': 0.5623046594177248}
# 22  {'p': 0.2279499441848788, 'beta': 0.9773243639...
# 20                {'scale_factor': 9.971762914520497}
# 15                                                 {}
# 12                                                 {}
# 1   {'bm25_k1': 9.387383629695933, 'bm25_b': 0.003...
# 2                                                  {}
# 4                  {'conf_alpha': 3.4723751724861236}
# 5                     {'power_p': 0.6904827002362887}
# 8                 {'scale_factor': 9.983769963713478}
# 7                                                  {}
# 3                                                  {}
# 10  {'p': 1.3407464432528267, 'beta': 0.9993857006...
# 11                         {'p': 0.25456267182413783}
# 0                                                  {}
# 21  {'lower_q': 43.2178033186353, 'upper_q': 55.22...
# 9   {'lower_q': 6.629831898087994, 'upper_q': 55.1...
# 18                                                 {}
# 6                                                  {}

# %%
import glob

all_results = []
# Match any CSV in the result folder
for f in glob.glob(f"{results_folder}/*.csv"):
    all_results.append(pd.read_csv(f))

if all_results:
    experiment_results = pd.concat(all_results)
    experiment_results = experiment_results.sort_values("Test NDCG@20", ascending=False)
    experiment_results.to_csv(results_filename, index=False)
else:
    print("No results found.")

experiment_results
