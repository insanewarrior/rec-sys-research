# %%
import numpy as np
import pandas as pd
import optuna
from scipy.sparse import csr_matrix
from weighting_strategies import (
    bm25_weight, tfidf_weight, normalized_weight,
    log_weight, confidence_weight, power_weight,
    pmi_weight, robust_user_centric_weight, sigmoid_propensity_weight, power_lift_weight, robust_user_centric_weight_v2
)
from implicit.als import AlternatingLeastSquares
from implicit.evaluation import train_test_split, precision_at_k, ndcg_at_k

import cornac

# %%
import sys
import os

# Add the parent directory to sys.path to resolve imports from sibling directories
sys.path.append(os.path.abspath(".."))

from utils.sparse import transform_dataframe_to_sparse

# %%
movielens_df = (
    pd.DataFrame(
        data=cornac.datasets.movielens.load_feedback(variant="100K"),
        columns=['user_id', 'item_id', 'target']
    )
    .loc[:, ['user_id', 'item_id', 'target']]
    .dropna()
)
movielens_df['user_id'].nunique(), movielens_df['item_id'].nunique(), movielens_df.shape[0]
# Out:
# (943, 1682, 100000)

# %%
user_item_matrix, user_mapping, item_mapping = transform_dataframe_to_sparse(
    movielens_df, row_field='user_id', col_field='item_id', data_field='target'
)


train_val_mat, test_mat = train_test_split(user_item_matrix, train_percentage=0.9, random_state=42)
train_mat, val_mat = train_test_split(train_val_mat, train_percentage=0.9, random_state=42)

print(f"Train Shape: {train_mat.shape}, Val Shape: {val_mat.shape}, Test Shape: {test_mat.shape}")
# Out:
# Train Shape: (943, 1682), Val Shape: (943, 1682), Test Shape: (943, 1682)

# %%
results_folder = "results/movielens_100k"
results_filename = "movielens_100k_experiment_results.csv"

import time

def run_hyperparameter_optimization(
    train_mat: csr_matrix,
    val_mat: csr_matrix,
    train_val_mat: csr_matrix,
    test_mat: csr_matrix,
    weighting_strategy: str,
    algorithm: str,
    n_trials: int = 20,
    output_dir: str = None,
) -> pd.DataFrame:
    results = []
    algorithms = {
        "ALS_factors=10": lambda: AlternatingLeastSquares(factors=10, random_state=42),
        "ALS_factors=100": lambda: AlternatingLeastSquares(factors=100, random_state=42),
    }
    strategies = [
        "no_weighting",
        "bm25",
        "tfidf",
        "log", 
        "confidence",
        "power",
        "normalized",
        "pmi",
        "robust_user_centric",
        "robust_user_centric_weight_v2",
        "sigmoid_propensity",
        "power_lift"
    ]
    if weighting_strategy not in strategies:
        raise ValueError(f"Weighting strategy '{weighting_strategy}' is not recognized.")
    strategy = weighting_strategy

    if algorithm not in algorithms:
        raise ValueError(f"Algorithm '{algorithm}' is not recognized.")
    algo_name = algorithm
    AlgoFactory = algorithms[algorithm]

    print(f"Running optimization for {algo_name} with {strategy}...")

    def get_weighted_matrix(matrix, params):
        weighted = matrix.copy()
        if strategy == "bm25":
            weighted = bm25_weight(weighted, K1=params.get("bm25_k1"), B=params.get("bm25_b"))
        elif strategy == "confidence":
            weighted = confidence_weight(weighted, alpha=params.get("conf_alpha"))
        elif strategy == "power":
            weighted = power_weight(weighted, p=params.get("power_p"))
        elif strategy == "tfidf":
            weighted = tfidf_weight(weighted)
        elif strategy == "log":
            weighted = log_weight(weighted)
        elif strategy == "normalized":
            weighted = normalized_weight(weighted)
        elif strategy == "pmi":
            weighted = pmi_weight(weighted)
        elif strategy == "robust_user_centric":
            weighted = robust_user_centric_weight(weighted, scale_factor=params.get("scale_factor"))
        elif strategy == "sigmoid_propensity":
            weighted = sigmoid_propensity_weight(weighted, p=params.get("p"), beta=params.get("beta"))
        elif strategy == "power_lift":
            weighted = power_lift_weight(weighted, p=params.get("p"))
        elif strategy == "robust_user_centric_weight_v2":
            weighted = robust_user_centric_weight_v2(weighted, lower_q=params.get("lower_q"), upper_q=params.get("upper_q"))
        return weighted

    def objective(trial):
        params = {}
        # Suggest weighting strategy parameters
        if strategy == "bm25":
            params["bm25_k1"] = trial.suggest_float("bm25_k1", 0.1, 1000)
            params["bm25_b"] = trial.suggest_float("bm25_b", 0.0, 1.0)
        elif strategy == "confidence":
            params["conf_alpha"] = trial.suggest_float("conf_alpha", 1.0, 150.0)
        elif strategy == "power":
            params["power_p"] = trial.suggest_float("power_p", 0.1, 1.5)
        elif strategy == "robust_user_centric":
            params["scale_factor"] = trial.suggest_float("scale_factor", 0.1, 10.0)
        elif strategy == "robust_user_centric_weight_v2":
            params["lower_q"] = trial.suggest_float("lower_q", 5.0, 45.0)
            params["upper_q"] = trial.suggest_float("upper_q", 55.0, 95.0)
        elif strategy == "sigmoid_propensity":
            params["p"] = trial.suggest_float("p", 0.1, 5.0)
            params["beta"] = trial.suggest_float("beta", 0.0, 1.0)
        elif strategy == "power_lift":
            params["p"] = trial.suggest_float("p", 0.1, 1.5)
        weighted_train = get_weighted_matrix(train_mat, params)
        
        # Train Model
        model = AlgoFactory()
        model.fit(weighted_train, show_progress=False)

        # Evaluate on Validation Set
        return ndcg_at_k(model, train_mat, val_mat, K=20, show_progress=False)

    # Optimize only if strategy has parameters
    current_trials = n_trials if strategy in ["bm25", "confidence", "power", "robust_user_centric", "robust_user_centric_weight_v2", "sigmoid_propensity", "power_lift"] else 1
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=current_trials, n_jobs=-1)

    # --- Final Retraining & Testing ---
    # Use best params to weight the full train_val matrix
    best_params = study.best_params
    weighted_train_val = get_weighted_matrix(train_val_mat, best_params)

    # Train Final Model
    final_model = AlgoFactory()
    
    start_time = time.time()
    final_model.fit(weighted_train_val, show_progress=False)
    end_time = time.time()
    
    # Evaluate on Test Set
    test_ndcg_10 = ndcg_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    test_precision_10 = precision_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    test_ndcg_20 = ndcg_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)
    test_precision_20 = precision_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)

    results.append({
        "Algorithm": algo_name,
        "Strategy": strategy,
        "Number of Optimization Trials": current_trials,
        "Best Val NDCG@20": study.best_value,
        "Test NDCG@10": test_ndcg_10,
        "Test NDCG@20": test_ndcg_20,
        "Test Precision@10": test_precision_10,
        "Test Precision@20": test_precision_20,
        "Final Train Time (s)": end_time - start_time,
        "Best Params": best_params
    })

    if output_dir:
        output_path = os.path.join(output_dir, f"{algo_name}_{strategy}_results.csv")
        pd.DataFrame(results).to_csv(output_path, index=False)
    return pd.DataFrame(results)

# %%
if not os.path.exists(results_folder):
    os.makedirs(results_folder)

# Execution of all experiments
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="confidence", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="confidence", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-29 21:35:49,832] A new study created in memory with name: no-name-768b3392-56c4-480e-897d-8c5116b7b2c9
# Running optimization for ALS_factors=10 with no_weighting...
# [I 2026-01-29 21:35:50,087] Trial 0 finished with value: 0.27244925287930244 and parameters: {}. Best is trial 0 with value: 0.27244925287930244.
# [I 2026-01-29 21:35:50,128] A new study created in memory with name: no-name-f5db5fc9-e47a-4c01-a08c-57c7816623e8
# [I 2026-01-29 21:35:50,249] Trial 0 finished with value: 0.2550847356281346 and parameters: {'bm25_k1': 392.9630961200425, 'bm25_b': 0.20702281961533286}. Best is trial 0 with value: 0.2550847356281346.
# [I 2026-01-29 21:35:50,257] Trial 1 finished with value: 0.25914799539540434 and parameters: {'bm25_k1': 18.49902926772266, 'bm25_b': 0.7483218884291787}. Best is trial 1 with value: 0.25914799539540434.
# Running optimization for ALS_factors=10 with bm25...
# [I 2026-01-29 21:35:50,426] Trial 3 finished with value: 0.25441476754844666 and parameters: {'bm25_k1': 997.9611788813592, 'bm25_b': 0.6954266746749062}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:50,441] Trial 2 finished with value: 0.2551876705787217 and parameters: {'bm25_k1': 382.11347123530504, 'bm25_b': 0.5964279163182016}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:50,608] Trial 5 finished with value: 0.25478032825910524 and parameters: {'bm25_k1': 360.1119500875812, 'bm25_b': 0.48011264799868814}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:50,633] Trial 4 finished with value: 0.254138725201777 and parameters: {'bm25_k1': 348.91783013800216, 'bm25_b': 0.2657594477163353}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:50,727] Trial 6 finished with value: 0.25069574461272587 and parameters: {'bm25_k1': 687.0021561733502, 'bm25_b': 0.03312977932847816}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:50,907] Trial 7 finished with value: 0.2517556377064911 and parameters: {'bm25_k1': 104.51185691121654, 'bm25_b': 0.9586999236147001}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,031] Trial 8 finished with value: 0.25509377867793054 and parameters: {'bm25_k1': 649.6305858420734, 'bm25_b': 0.5970471346410912}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,056] Trial 9 finished with value: 0.25127981550329054 and parameters: {'bm25_k1': 813.3489998933171, 'bm25_b': 0.8679623365141454}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,226] Trial 10 finished with value: 0.25302982686617936 and parameters: {'bm25_k1': 370.6536244833142, 'bm25_b': 0.8353548410862015}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,258] Trial 11 finished with value: 0.25521794919686336 and parameters: {'bm25_k1': 943.9504488024531, 'bm25_b': 0.6679605685610045}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,355] Trial 12 finished with value: 0.25397730208081765 and parameters: {'bm25_k1': 178.82023514044064, 'bm25_b': 0.41325929047465293}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,434] Trial 13 finished with value: 0.2570745577469534 and parameters: {'bm25_k1': 34.866802348424926, 'bm25_b': 0.7829086887454293}. Best is trial 1 with value: 0.25914799539540434.
# [I 2026-01-29 21:35:51,522] Trial 14 finished with value: 0.26022797908927503 and parameters: {'bm25_k1': 10.924518246974912, 'bm25_b': 0.4798737170027617}. Best is trial 14 with value: 0.26022797908927503.
# [I 2026-01-29 21:35:51,624] Trial 15 finished with value: 0.25712836294289926 and parameters: {'bm25_k1': 40.544099407980525, 'bm25_b': 0.7391358590092082}. Best is trial 14 with value: 0.26022797908927503.
# [I 2026-01-29 21:35:51,737] Trial 16 finished with value: 0.25924378097573175 and parameters: {'bm25_k1': 15.993849555606168, 'bm25_b': 0.7288855973614674}. Best is trial 14 with value: 0.26022797908927503.
# [I 2026-01-29 21:35:51,923] Trial 18 finished with value: 0.2539988567539059 and parameters: {'bm25_k1': 200.89992048426583, 'bm25_b': 0.37841579287680777}. Best is trial 14 with value: 0.26022797908927503.
# [I 2026-01-29 21:35:51,924] Trial 17 finished with value: 0.2545985250086225 and parameters: {'bm25_k1': 52.850613078642596, 'bm25_b': 0.7919492339547796}. Best is trial 14 with value: 0.26022797908927503.
# [I 2026-01-29 21:35:52,017] Trial 19 finished with value: 0.25403265407599745 and parameters: {'bm25_k1': 211.5418924139707, 'bm25_b': 0.3936967411043766}. Best is trial 14 with value: 0.26022797908927503.
# [I 2026-01-29 21:35:52,091] A new study created in memory with name: no-name-c38e6de1-5e55-4c12-a01f-825d22cdaac9
# [I 2026-01-29 21:35:52,187] Trial 0 finished with value: 0.25842547423840395 and parameters: {}. Best is trial 0 with value: 0.25842547423840395.
# [I 2026-01-29 21:35:52,291] A new study created in memory with name: no-name-fef6976d-7a89-46db-98c2-e571eefbdd46
# Running optimization for ALS_factors=10 with tfidf...
# Running optimization for ALS_factors=10 with log...
# [I 2026-01-29 21:35:52,386] Trial 0 finished with value: 0.2748564171886328 and parameters: {}. Best is trial 0 with value: 0.2748564171886328.
# [I 2026-01-29 21:35:52,472] A new study created in memory with name: no-name-37ff4c44-8ab5-46f6-907a-0bd78ee5228b
# Running optimization for ALS_factors=10 with confidence...
# [I 2026-01-29 21:35:52,679] Trial 3 finished with value: 0.09415663429745394 and parameters: {'conf_alpha': 61.53015979933998}. Best is trial 3 with value: 0.09415663429745394.
# [I 2026-01-29 21:35:52,679] Trial 0 finished with value: 0.10500642340775568 and parameters: {'conf_alpha': 47.88322692730908}. Best is trial 0 with value: 0.10500642340775568.
# [I 2026-01-29 21:35:52,852] Trial 2 finished with value: 0.24532508831293245 and parameters: {'conf_alpha': 2.420960109474791}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:52,863] Trial 1 finished with value: 0.10052639050218767 and parameters: {'conf_alpha': 52.63691864172937}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,047] Trial 4 finished with value: 0.06900719795424501 and parameters: {'conf_alpha': 124.52046796786814}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,184] Trial 5 finished with value: 0.13148626914410907 and parameters: {'conf_alpha': 30.573702421268052}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,186] Trial 7 finished with value: 0.07467360264149579 and parameters: {'conf_alpha': 105.59706770372232}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,298] Trial 6 finished with value: 0.06806267032218909 and parameters: {'conf_alpha': 136.7830222524398}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,406] Trial 8 finished with value: 0.2067867785462278 and parameters: {'conf_alpha': 7.52787226164683}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,509] Trial 10 finished with value: 0.06813912599837586 and parameters: {'conf_alpha': 129.6601316727912}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,642] Trial 9 finished with value: 0.1361290492563609 and parameters: {'conf_alpha': 28.75619771416857}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,663] Trial 11 finished with value: 0.07570408465849778 and parameters: {'conf_alpha': 104.02947359598555}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,764] Trial 12 finished with value: 0.18805468496907388 and parameters: {'conf_alpha': 10.746827878910857}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,921] Trial 13 finished with value: 0.23409706534435606 and parameters: {'conf_alpha': 3.841707404943427}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:53,944] Trial 14 finished with value: 0.18944758449265495 and parameters: {'conf_alpha': 10.289064056814315}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:54,030] Trial 15 finished with value: 0.2093420062094751 and parameters: {'conf_alpha': 7.032874353492674}. Best is trial 2 with value: 0.24532508831293245.
# [I 2026-01-29 21:35:54,130] Trial 16 finished with value: 0.2532756330706738 and parameters: {'conf_alpha': 1.753950823420519}. Best is trial 16 with value: 0.2532756330706738.
# [I 2026-01-29 21:35:54,222] Trial 17 finished with value: 0.2606519044093769 and parameters: {'conf_alpha': 1.1958441973755038}. Best is trial 17 with value: 0.2606519044093769.
# [I 2026-01-29 21:35:54,317] Trial 18 finished with value: 0.08454452730338585 and parameters: {'conf_alpha': 77.59424135555146}. Best is trial 17 with value: 0.2606519044093769.
# [I 2026-01-29 21:35:54,409] Trial 19 finished with value: 0.08434439912580569 and parameters: {'conf_alpha': 77.49241287780919}. Best is trial 17 with value: 0.2606519044093769.
# [I 2026-01-29 21:35:54,506] A new study created in memory with name: no-name-ac2695ea-0fe7-4de4-837a-e887d573e996
# [I 2026-01-29 21:35:54,636] Trial 0 finished with value: 0.27596859825659364 and parameters: {'power_p': 0.4716586774892113}. Best is trial 0 with value: 0.27596859825659364.
# Running optimization for ALS_factors=10 with power...
# [I 2026-01-29 21:35:54,794] Trial 1 finished with value: 0.2720824512833477 and parameters: {'power_p': 1.0900200199655208}. Best is trial 0 with value: 0.27596859825659364.
# [I 2026-01-29 21:35:54,804] Trial 2 finished with value: 0.26905564381191116 and parameters: {'power_p': 1.2959640146802678}. Best is trial 0 with value: 0.27596859825659364.
# [I 2026-01-29 21:35:54,813] Trial 3 finished with value: 0.2754136571799179 and parameters: {'power_p': 0.6659779423757933}. Best is trial 0 with value: 0.27596859825659364.
# [I 2026-01-29 21:35:54,926] Trial 4 finished with value: 0.2687064054794161 and parameters: {'power_p': 1.386592060858165}. Best is trial 0 with value: 0.27596859825659364.
# [I 2026-01-29 21:35:55,110] Trial 5 finished with value: 0.27653881536448477 and parameters: {'power_p': 0.5876105555196055}. Best is trial 5 with value: 0.27653881536448477.
# [I 2026-01-29 21:35:55,117] Trial 7 finished with value: 0.2742886051719168 and parameters: {'power_p': 0.8423687900012309}. Best is trial 5 with value: 0.27653881536448477.
# [I 2026-01-29 21:35:55,125] Trial 6 finished with value: 0.2759586826082891 and parameters: {'power_p': 0.64225514294242}. Best is trial 5 with value: 0.27653881536448477.
# [I 2026-01-29 21:35:55,233] Trial 8 finished with value: 0.27147231894700846 and parameters: {'power_p': 1.2465149993370326}. Best is trial 5 with value: 0.27653881536448477.
# [I 2026-01-29 21:35:55,421] Trial 11 finished with value: 0.2739670200575871 and parameters: {'power_p': 0.8474163890470798}. Best is trial 5 with value: 0.27653881536448477.
# [I 2026-01-29 21:35:55,436] Trial 9 finished with value: 0.2768607787159655 and parameters: {'power_p': 0.5504693184151779}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:55,537] Trial 10 finished with value: 0.27438603292216224 and parameters: {'power_p': 0.7330330201257297}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:55,702] Trial 12 finished with value: 0.27298534949861797 and parameters: {'power_p': 0.9700022860442595}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:55,739] Trial 13 finished with value: 0.2738343140819869 and parameters: {'power_p': 0.16938534676954864}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:55,901] Trial 14 finished with value: 0.2738594069295902 and parameters: {'power_p': 0.13670666738900072}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:55,909] Trial 15 finished with value: 0.27438430295506355 and parameters: {'power_p': 0.24172197356852354}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:56,012] Trial 16 finished with value: 0.2733094784743841 and parameters: {'power_p': 0.15563599333785177}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:56,182] Trial 17 finished with value: 0.27410426470657906 and parameters: {'power_p': 0.3604410096562209}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:56,192] Trial 18 finished with value: 0.2751616176506834 and parameters: {'power_p': 0.41596185826499776}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:56,289] Trial 19 finished with value: 0.27518099776872723 and parameters: {'power_p': 0.4318275374932926}. Best is trial 9 with value: 0.2768607787159655.
# [I 2026-01-29 21:35:56,461] A new study created in memory with name: no-name-87dcc6fd-45eb-406b-8d8d-68214e0e6b45
# [I 2026-01-29 21:35:56,503] Trial 0 finished with value: 0.21043799472094057 and parameters: {}. Best is trial 0 with value: 0.21043799472094057.
# [I 2026-01-29 21:35:56,554] A new study created in memory with name: no-name-25f82bf0-04c4-4c47-a6fc-3cc860451f95
# [I 2026-01-29 21:35:56,652] Trial 0 finished with value: 0.2651063679466082 and parameters: {}. Best is trial 0 with value: 0.2651063679466082.
# Running optimization for ALS_factors=10 with normalized...
# Running optimization for ALS_factors=10 with pmi...
# [I 2026-01-29 21:35:56,746] A new study created in memory with name: no-name-32907444-5b40-4596-89b9-acdb243f8810
# Running optimization for ALS_factors=10 with robust_user_centric...
# [I 2026-01-29 21:35:57,816] Trial 0 finished with value: 0.2712777655851746 and parameters: {'scale_factor': 2.6444562181974063}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:57,858] Trial 3 finished with value: 0.26281002642050155 and parameters: {'scale_factor': 1.1996727976998802}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:58,014] Trial 2 finished with value: 0.2680459527436834 and parameters: {'scale_factor': 5.6423885014627375}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:58,027] Trial 1 finished with value: 0.2659875698886756 and parameters: {'scale_factor': 8.014799310281573}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:59,046] Trial 5 finished with value: 0.27123550961241494 and parameters: {'scale_factor': 2.6862717026586673}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:59,057] Trial 7 finished with value: 0.2687460340676553 and parameters: {'scale_factor': 6.4714600697688685}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:59,161] Trial 4 finished with value: 0.26844214449197507 and parameters: {'scale_factor': 6.568169900459266}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:35:59,328] Trial 6 finished with value: 0.26773919623103676 and parameters: {'scale_factor': 5.739772665361268}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:36:00,326] Trial 8 finished with value: 0.26766636281570716 and parameters: {'scale_factor': 6.743271349337643}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:36:00,349] Trial 9 finished with value: 0.2679894545136164 and parameters: {'scale_factor': 5.806734231468648}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:36:00,441] Trial 11 finished with value: 0.27052524526495225 and parameters: {'scale_factor': 5.054629836009417}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:36:00,534] Trial 10 finished with value: 0.2646368465932588 and parameters: {'scale_factor': 9.869971848368866}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:36:01,512] Trial 12 finished with value: 0.27047051699674807 and parameters: {'scale_factor': 2.505164933143158}. Best is trial 0 with value: 0.2712777655851746.
# [I 2026-01-29 21:36:01,541] Trial 13 finished with value: 0.2712873711456153 and parameters: {'scale_factor': 2.7478481616873065}. Best is trial 13 with value: 0.2712873711456153.
# [I 2026-01-29 21:36:01,623] Trial 15 finished with value: 0.270335015916619 and parameters: {'scale_factor': 2.333284995387637}. Best is trial 13 with value: 0.2712873711456153.
# [I 2026-01-29 21:36:01,723] Trial 14 finished with value: 0.2706487959664237 and parameters: {'scale_factor': 2.4767370315256554}. Best is trial 13 with value: 0.2712873711456153.
# [I 2026-01-29 21:36:02,695] Trial 16 finished with value: 0.2720764508507793 and parameters: {'scale_factor': 2.8983133438111786}. Best is trial 16 with value: 0.2720764508507793.
# [I 2026-01-29 21:36:02,722] Trial 18 finished with value: 0.27031521137516834 and parameters: {'scale_factor': 3.5442790759592335}. Best is trial 16 with value: 0.2720764508507793.
# [I 2026-01-29 21:36:02,806] Trial 17 finished with value: 0.271093167765879 and parameters: {'scale_factor': 3.4653982276518644}. Best is trial 16 with value: 0.2720764508507793.
# [I 2026-01-29 21:36:02,899] Trial 19 finished with value: 0.22851168080687428 and parameters: {'scale_factor': 0.22835449734620816}. Best is trial 16 with value: 0.2720764508507793.
# [I 2026-01-29 21:36:03,131] A new study created in memory with name: no-name-d7bbd4d7-6d9d-4fa3-a331-31a8de758f2d
# Running optimization for ALS_factors=10 with robust_user_centric_weight_v2...
# [I 2026-01-29 21:36:04,126] Trial 2 finished with value: 0.26064123626996744 and parameters: {'lower_q': 36.8932476986903, 'upper_q': 78.99836030844055}. Best is trial 2 with value: 0.26064123626996744.
# [I 2026-01-29 21:36:04,143] Trial 1 finished with value: 0.2602171763377271 and parameters: {'lower_q': 14.651865144590257, 'upper_q': 67.67631586053496}. Best is trial 2 with value: 0.26064123626996744.
# [I 2026-01-29 21:36:04,237] Trial 0 finished with value: 0.26187782354462424 and parameters: {'lower_q': 14.514990360593224, 'upper_q': 78.27859918211037}. Best is trial 0 with value: 0.26187782354462424.
# [I 2026-01-29 21:36:04,345] Trial 3 finished with value: 0.2617475194277545 and parameters: {'lower_q': 15.336870119033525, 'upper_q': 75.9781621423968}. Best is trial 0 with value: 0.26187782354462424.
# [I 2026-01-29 21:36:05,287] Trial 5 finished with value: 0.25916354264691255 and parameters: {'lower_q': 9.812835894182669, 'upper_q': 62.62008641796305}. Best is trial 0 with value: 0.26187782354462424.
# [I 2026-01-29 21:36:05,328] Trial 4 finished with value: 0.26024376264947774 and parameters: {'lower_q': 25.49746869368653, 'upper_q': 57.64457844429282}. Best is trial 0 with value: 0.26187782354462424.
# [I 2026-01-29 21:36:05,403] Trial 6 finished with value: 0.2611268117907584 and parameters: {'lower_q': 30.0553553535457, 'upper_q': 62.977455875436846}. Best is trial 0 with value: 0.26187782354462424.
# [I 2026-01-29 21:36:05,491] Trial 7 finished with value: 0.2621170710856803 and parameters: {'lower_q': 25.593427902822775, 'upper_q': 91.50105302276955}. Best is trial 7 with value: 0.2621170710856803.
# [I 2026-01-29 21:36:06,460] Trial 8 finished with value: 0.2586418401329749 and parameters: {'lower_q': 31.822811579554088, 'upper_q': 61.82863535841301}. Best is trial 7 with value: 0.2621170710856803.
# [I 2026-01-29 21:36:06,566] Trial 11 finished with value: 0.25906336020527937 and parameters: {'lower_q': 20.644325281622837, 'upper_q': 73.1255913227962}. Best is trial 7 with value: 0.2621170710856803.
# [I 2026-01-29 21:36:06,572] Trial 10 finished with value: 0.26167460002805576 and parameters: {'lower_q': 18.81870211756589, 'upper_q': 78.3945414798623}. Best is trial 7 with value: 0.2621170710856803.
# [I 2026-01-29 21:36:06,579] Trial 9 finished with value: 0.2610420976890188 and parameters: {'lower_q': 23.705122649602902, 'upper_q': 91.26954271536117}. Best is trial 7 with value: 0.2621170710856803.
# [I 2026-01-29 21:36:07,533] Trial 12 finished with value: 0.26211268911318564 and parameters: {'lower_q': 18.101422287095094, 'upper_q': 87.90105918238788}. Best is trial 7 with value: 0.2621170710856803.
# [I 2026-01-29 21:36:07,634] Trial 14 finished with value: 0.2625568380363692 and parameters: {'lower_q': 5.0548436661024745, 'upper_q': 94.50426159871384}. Best is trial 14 with value: 0.2625568380363692.
# [I 2026-01-29 21:36:07,643] Trial 15 finished with value: 0.2619178063037359 and parameters: {'lower_q': 7.3406455821399845, 'upper_q': 94.88307668001343}. Best is trial 14 with value: 0.2625568380363692.
# [I 2026-01-29 21:36:07,745] Trial 13 finished with value: 0.26298504794889777 and parameters: {'lower_q': 5.46199511595303, 'upper_q': 93.76510944056116}. Best is trial 13 with value: 0.26298504794889777.
# [I 2026-01-29 21:36:08,671] Trial 16 finished with value: 0.2631015480930152 and parameters: {'lower_q': 6.24671093300206, 'upper_q': 92.59301558430829}. Best is trial 16 with value: 0.2631015480930152.
# [I 2026-01-29 21:36:08,776] Trial 17 finished with value: 0.2589807251869725 and parameters: {'lower_q': 44.455760059607925, 'upper_q': 87.02133820346772}. Best is trial 16 with value: 0.2631015480930152.
# [I 2026-01-29 21:36:08,782] Trial 18 finished with value: 0.26013681438673125 and parameters: {'lower_q': 42.406028150904646, 'upper_q': 86.95530670621864}. Best is trial 16 with value: 0.2631015480930152.
# [I 2026-01-29 21:36:08,883] Trial 19 finished with value: 0.26305087323596216 and parameters: {'lower_q': 7.219460283661824, 'upper_q': 84.47118545654052}. Best is trial 16 with value: 0.2631015480930152.
# [I 2026-01-29 21:36:09,116] A new study created in memory with name: no-name-e8047c00-6ccc-4d2c-9d10-2fa9e550db57
# [I 2026-01-29 21:36:09,242] Trial 2 finished with value: 0.26859761077576894 and parameters: {'p': 4.2404308603012835, 'beta': 0.7092436567302812}. Best is trial 2 with value: 0.26859761077576894.
# [I 2026-01-29 21:36:09,247] Trial 0 finished with value: 0.26693152545425297 and parameters: {'p': 2.5515444075064804, 'beta': 0.2285608950689385}. Best is trial 2 with value: 0.26859761077576894.
# [I 2026-01-29 21:36:09,261] Trial 3 finished with value: 0.27012652225731015 and parameters: {'p': 2.931960053531159, 'beta': 0.9956822649430634}. Best is trial 3 with value: 0.27012652225731015.
# [I 2026-01-29 21:36:09,261] Trial 1 finished with value: 0.27200828800145277 and parameters: {'p': 1.6231537368745288, 'beta': 0.9465533858095561}. Best is trial 1 with value: 0.27200828800145277.
# Running optimization for ALS_factors=10 with sigmoid_propensity...
# [I 2026-01-29 21:36:09,385] Trial 5 finished with value: 0.2712850512090783 and parameters: {'p': 0.6712183816042632, 'beta': 0.5680663513485265}. Best is trial 1 with value: 0.27200828800145277.
# [I 2026-01-29 21:36:09,576] Trial 4 finished with value: 0.2679033708916786 and parameters: {'p': 4.62774348222985, 'beta': 0.7233697712987768}. Best is trial 1 with value: 0.27200828800145277.
# [I 2026-01-29 21:36:09,584] Trial 7 finished with value: 0.2680582659428842 and parameters: {'p': 2.4808171058513713, 'beta': 0.2782292085744993}. Best is trial 1 with value: 0.27200828800145277.
# [I 2026-01-29 21:36:09,592] Trial 6 finished with value: 0.2722512431790095 and parameters: {'p': 2.5426792784636576, 'beta': 0.5896496071314119}. Best is trial 6 with value: 0.2722512431790095.
# [I 2026-01-29 21:36:09,709] Trial 8 finished with value: 0.26290187607776305 and parameters: {'p': 4.80996985007589, 'beta': 0.06796408065284398}. Best is trial 6 with value: 0.2722512431790095.
# [I 2026-01-29 21:36:09,891] Trial 10 finished with value: 0.26364331294662413 and parameters: {'p': 4.080900370689625, 'beta': 0.030971520529822216}. Best is trial 6 with value: 0.2722512431790095.
# [I 2026-01-29 21:36:09,901] Trial 11 finished with value: 0.26454229012304387 and parameters: {'p': 3.1231841058158856, 'beta': 0.10832969983082019}. Best is trial 6 with value: 0.2722512431790095.
# [I 2026-01-29 21:36:09,912] Trial 9 finished with value: 0.27190797504711 and parameters: {'p': 2.4279220090123417, 'beta': 0.9300262208153985}. Best is trial 6 with value: 0.2722512431790095.
# [I 2026-01-29 21:36:10,031] Trial 13 finished with value: 0.2697501655871696 and parameters: {'p': 0.38337161182473345, 'beta': 0.4396862965763012}. Best is trial 6 with value: 0.2722512431790095.
# [I 2026-01-29 21:36:10,210] Trial 14 finished with value: 0.272407519602782 and parameters: {'p': 1.2323312512448599, 'beta': 0.4739450793926621}. Best is trial 14 with value: 0.272407519602782.
# [I 2026-01-29 21:36:10,225] Trial 12 finished with value: 0.2702105238237282 and parameters: {'p': 3.1681673723956245, 'beta': 0.8102688766381632}. Best is trial 14 with value: 0.272407519602782.
# [I 2026-01-29 21:36:10,398] Trial 15 finished with value: 0.2720820849926673 and parameters: {'p': 1.4352674253766196, 'beta': 0.45350409967874844}. Best is trial 14 with value: 0.272407519602782.
# [I 2026-01-29 21:36:10,509] Trial 16 finished with value: 0.273223653488504 and parameters: {'p': 1.418860645455753, 'beta': 0.7341644431211422}. Best is trial 16 with value: 0.273223653488504.
# [I 2026-01-29 21:36:10,528] Trial 17 finished with value: 0.2733478975672254 and parameters: {'p': 1.4536144029374636, 'beta': 0.5097121957977787}. Best is trial 17 with value: 0.2733478975672254.
# [I 2026-01-29 21:36:10,708] Trial 19 finished with value: 0.2736073171167622 and parameters: {'p': 1.40152528826798, 'beta': 0.5683930129014587}. Best is trial 19 with value: 0.2736073171167622.
# [I 2026-01-29 21:36:10,718] Trial 18 finished with value: 0.2729774600261619 and parameters: {'p': 1.3415786452332683, 'beta': 0.4877834057032666}. Best is trial 19 with value: 0.2736073171167622.
# [I 2026-01-29 21:36:10,810] A new study created in memory with name: no-name-c01c86b6-237f-44ed-8b48-6c9d0a5a0480
# [I 2026-01-29 21:36:10,983] Trial 0 finished with value: 0.1502100682886096 and parameters: {'p': 1.2204177145988093}. Best is trial 0 with value: 0.1502100682886096.
# [I 2026-01-29 21:36:10,995] Trial 2 finished with value: 0.26077725664679985 and parameters: {'p': 0.5864838506618875}. Best is trial 2 with value: 0.26077725664679985.
# Running optimization for ALS_factors=10 with power_lift...
# [I 2026-01-29 21:36:11,164] Trial 1 finished with value: 0.27456912179253123 and parameters: {'p': 0.13902328182015336}. Best is trial 1 with value: 0.27456912179253123.
# [I 2026-01-29 21:36:11,173] Trial 3 finished with value: 0.275096944280977 and parameters: {'p': 0.20298154336881027}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,341] Trial 5 finished with value: 0.2569837338043629 and parameters: {'p': 0.6177303041200047}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,355] Trial 4 finished with value: 0.16803302303037174 and parameters: {'p': 1.1233494065746912}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,521] Trial 6 finished with value: 0.12735551742295206 and parameters: {'p': 1.337033567573489}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,538] Trial 7 finished with value: 0.2582476670148731 and parameters: {'p': 0.6071344452533265}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,655] Trial 8 finished with value: 0.1371569216475997 and parameters: {'p': 1.2846012269990148}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,803] Trial 10 finished with value: 0.2739619156058848 and parameters: {'p': 0.10450827274572172}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,817] Trial 11 finished with value: 0.1364061447253773 and parameters: {'p': 1.2879384338066813}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,818] Trial 9 finished with value: 0.25290881756732114 and parameters: {'p': 0.6431991824924299}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:11,931] Trial 12 finished with value: 0.11659756332588836 and parameters: {'p': 1.406221258975793}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,122] Trial 13 finished with value: 0.27397342960999505 and parameters: {'p': 0.10328594644045488}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,132] Trial 15 finished with value: 0.2743675294040008 and parameters: {'p': 0.13489823066622297}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,306] Trial 14 finished with value: 0.2736281360524743 and parameters: {'p': 0.10139780246868185}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,413] Trial 16 finished with value: 0.2742820319731388 and parameters: {'p': 0.1122507433451524}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,517] Trial 18 finished with value: 0.2725277403852619 and parameters: {'p': 0.3702158850655619}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,527] Trial 17 finished with value: 0.27259110281548976 and parameters: {'p': 0.3756067165071496}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,625] Trial 19 finished with value: 0.27433774923728454 and parameters: {'p': 0.3371331906118361}. Best is trial 3 with value: 0.275096944280977.
# [I 2026-01-29 21:36:12,795] A new study created in memory with name: no-name-8f8d2abb-eebf-4a8b-b98b-e69f0e76f8e8
# [I 2026-01-29 21:36:12,870] Trial 0 finished with value: 0.21629627544191743 and parameters: {}. Best is trial 0 with value: 0.21629627544191743.
# [I 2026-01-29 21:36:12,959] A new study created in memory with name: no-name-97e5b5b5-4af9-4f8d-b188-68d2ad9708ac
# Running optimization for ALS_factors=100 with no_weighting...
# Running optimization for ALS_factors=100 with bm25...
# [I 2026-01-29 21:36:13,210] Trial 2 finished with value: 0.1962296204455114 and parameters: {'bm25_k1': 177.51490727488851, 'bm25_b': 0.895770186073001}. Best is trial 2 with value: 0.1962296204455114.
# [I 2026-01-29 21:36:13,217] Trial 3 finished with value: 0.20410427851102889 and parameters: {'bm25_k1': 367.16800832826516, 'bm25_b': 0.42004196262833027}. Best is trial 3 with value: 0.20410427851102889.
# [I 2026-01-29 21:36:13,227] Trial 0 finished with value: 0.20487104388630745 and parameters: {'bm25_k1': 250.5554320950748, 'bm25_b': 0.3791608995473471}. Best is trial 0 with value: 0.20487104388630745.
# [I 2026-01-29 21:36:13,236] Trial 1 finished with value: 0.20503957534210954 and parameters: {'bm25_k1': 929.0896949855402, 'bm25_b': 0.29348730055408645}. Best is trial 1 with value: 0.20503957534210954.
# [I 2026-01-29 21:36:13,492] Trial 4 finished with value: 0.19964041130355376 and parameters: {'bm25_k1': 928.3371651975382, 'bm25_b': 0.5902475768187397}. Best is trial 1 with value: 0.20503957534210954.
# [I 2026-01-29 21:36:13,594] Trial 5 finished with value: 0.19912894149284435 and parameters: {'bm25_k1': 504.80044393384276, 'bm25_b': 0.6467201849729945}. Best is trial 1 with value: 0.20503957534210954.
# [I 2026-01-29 21:36:13,676] Trial 6 finished with value: 0.19672181549704784 and parameters: {'bm25_k1': 313.763668600606, 'bm25_b': 0.8395303848690027}. Best is trial 1 with value: 0.20503957534210954.
# [I 2026-01-29 21:36:13,693] Trial 7 finished with value: 0.19612018856705465 and parameters: {'bm25_k1': 965.6730123118641, 'bm25_b': 0.9579124325810279}. Best is trial 1 with value: 0.20503957534210954.
# [I 2026-01-29 21:36:13,936] Trial 8 finished with value: 0.21386217559497467 and parameters: {'bm25_k1': 115.1831161458346, 'bm25_b': 0.02673013180613293}. Best is trial 8 with value: 0.21386217559497467.
# [I 2026-01-29 21:36:14,041] Trial 9 finished with value: 0.2003718853038211 and parameters: {'bm25_k1': 100.8498013790034, 'bm25_b': 0.5714801307998905}. Best is trial 8 with value: 0.21386217559497467.
# [I 2026-01-29 21:36:14,055] Trial 10 finished with value: 0.20459221829395144 and parameters: {'bm25_k1': 597.9186477094861, 'bm25_b': 0.40668258567335036}. Best is trial 8 with value: 0.21386217559497467.
# [I 2026-01-29 21:36:14,064] Trial 11 finished with value: 0.2089855912258781 and parameters: {'bm25_k1': 395.41662765768797, 'bm25_b': 0.11681798597526549}. Best is trial 8 with value: 0.21386217559497467.
# [I 2026-01-29 21:36:14,320] Trial 13 finished with value: 0.21450269658248744 and parameters: {'bm25_k1': 596.7931262555614, 'bm25_b': 0.020502520952904214}. Best is trial 13 with value: 0.21450269658248744.
# [I 2026-01-29 21:36:14,423] Trial 14 finished with value: 0.21326648413911287 and parameters: {'bm25_k1': 16.312256175874268, 'bm25_b': 0.02764692324582669}. Best is trial 13 with value: 0.21450269658248744.
# [I 2026-01-29 21:36:14,436] Trial 12 finished with value: 0.19598716072416716 and parameters: {'bm25_k1': 131.65782575635794, 'bm25_b': 0.9608604811615379}. Best is trial 13 with value: 0.21450269658248744.
# [I 2026-01-29 21:36:14,453] Trial 15 finished with value: 0.21453368578989165 and parameters: {'bm25_k1': 18.250742736854136, 'bm25_b': 0.007842924451971427}. Best is trial 15 with value: 0.21453368578989165.
# [I 2026-01-29 21:36:14,707] Trial 18 finished with value: 0.20714501288620146 and parameters: {'bm25_k1': 717.0480395682199, 'bm25_b': 0.19415187310109264}. Best is trial 15 with value: 0.21453368578989165.
# [I 2026-01-29 21:36:14,817] Trial 19 finished with value: 0.20725233033692633 and parameters: {'bm25_k1': 723.5862893102953, 'bm25_b': 0.19589079992812294}. Best is trial 15 with value: 0.21453368578989165.
# [I 2026-01-29 21:36:14,824] Trial 17 finished with value: 0.20689177444369466 and parameters: {'bm25_k1': 751.842165646813, 'bm25_b': 0.18800598581202002}. Best is trial 15 with value: 0.21453368578989165.
# [I 2026-01-29 21:36:14,831] Trial 16 finished with value: 0.20706697281981506 and parameters: {'bm25_k1': 731.5901080953711, 'bm25_b': 0.1910442064249048}. Best is trial 15 with value: 0.21453368578989165.
# [I 2026-01-29 21:36:14,924] A new study created in memory with name: no-name-7e2be959-714f-495d-8648-ac7e0321a22f
# Running optimization for ALS_factors=100 with tfidf...
# [I 2026-01-29 21:36:15,136] Trial 0 finished with value: 0.21583692741900962 and parameters: {}. Best is trial 0 with value: 0.21583692741900962.
# [I 2026-01-29 21:36:15,224] A new study created in memory with name: no-name-a033cd6e-c96a-4e60-a0f3-5dae3c02139e
# [I 2026-01-29 21:36:15,304] Trial 0 finished with value: 0.21607614798573896 and parameters: {}. Best is trial 0 with value: 0.21607614798573896.
# [I 2026-01-29 21:36:15,392] A new study created in memory with name: no-name-e11b2f4a-9918-4e48-8047-52dbb0371a09
# Running optimization for ALS_factors=100 with log...
# Running optimization for ALS_factors=100 with confidence...
# [I 2026-01-29 21:36:15,650] Trial 0 finished with value: 0.16508622623033764 and parameters: {'conf_alpha': 63.3598069974504}. Best is trial 0 with value: 0.16508622623033764.
# [I 2026-01-29 21:36:15,658] Trial 1 finished with value: 0.1468716472992936 and parameters: {'conf_alpha': 103.28303202469351}. Best is trial 0 with value: 0.16508622623033764.
# [I 2026-01-29 21:36:15,669] Trial 2 finished with value: 0.13896739723668375 and parameters: {'conf_alpha': 133.81888500693643}. Best is trial 0 with value: 0.16508622623033764.
# [I 2026-01-29 21:36:15,839] Trial 3 finished with value: 0.16836836160238874 and parameters: {'conf_alpha': 59.25325476044488}. Best is trial 3 with value: 0.16836836160238874.
# [I 2026-01-29 21:36:16,077] Trial 5 finished with value: 0.15491059531207443 and parameters: {'conf_alpha': 87.10004008777787}. Best is trial 3 with value: 0.16836836160238874.
# [I 2026-01-29 21:36:16,087] Trial 4 finished with value: 0.137698770496789 and parameters: {'conf_alpha': 137.44829771044277}. Best is trial 3 with value: 0.16836836160238874.
# [I 2026-01-29 21:36:16,260] Trial 6 finished with value: 0.1765439566506961 and parameters: {'conf_alpha': 46.63967232976849}. Best is trial 6 with value: 0.1765439566506961.
# [I 2026-01-29 21:36:16,269] Trial 7 finished with value: 0.18035865571246554 and parameters: {'conf_alpha': 43.06861992659215}. Best is trial 7 with value: 0.18035865571246554.
# [I 2026-01-29 21:36:16,506] Trial 9 finished with value: 0.1755943261235091 and parameters: {'conf_alpha': 49.06132506081685}. Best is trial 7 with value: 0.18035865571246554.
# [I 2026-01-29 21:36:16,521] Trial 8 finished with value: 0.15229545575416983 and parameters: {'conf_alpha': 93.15350913874586}. Best is trial 7 with value: 0.18035865571246554.
# [I 2026-01-29 21:36:16,623] Trial 10 finished with value: 0.21543890121022363 and parameters: {'conf_alpha': 3.820934382090537}. Best is trial 10 with value: 0.21543890121022363.
# [I 2026-01-29 21:36:16,794] Trial 11 finished with value: 0.1764045958035952 and parameters: {'conf_alpha': 47.01987285744931}. Best is trial 10 with value: 0.21543890121022363.
# [I 2026-01-29 21:36:17,026] Trial 12 finished with value: 0.20239019834121513 and parameters: {'conf_alpha': 19.701935947711608}. Best is trial 10 with value: 0.21543890121022363.
# [I 2026-01-29 21:36:17,135] Trial 14 finished with value: 0.21261639416397884 and parameters: {'conf_alpha': 5.129866660409341}. Best is trial 10 with value: 0.21543890121022363.
# [I 2026-01-29 21:36:17,141] Trial 13 finished with value: 0.21631809522016718 and parameters: {'conf_alpha': 2.752224153286548}. Best is trial 13 with value: 0.21631809522016718.
# [I 2026-01-29 21:36:17,278] Trial 15 finished with value: 0.21540355579890214 and parameters: {'conf_alpha': 3.108821212183372}. Best is trial 13 with value: 0.21631809522016718.
# [I 2026-01-29 21:36:17,531] Trial 19 finished with value: 0.19982412866309998 and parameters: {'conf_alpha': 24.12822713648399}. Best is trial 13 with value: 0.21631809522016718.
# [I 2026-01-29 21:36:17,538] Trial 17 finished with value: 0.2140143658733682 and parameters: {'conf_alpha': 4.008531580643336}. Best is trial 13 with value: 0.21631809522016718.
# [I 2026-01-29 21:36:17,538] Trial 16 finished with value: 0.21770030687004144 and parameters: {'conf_alpha': 1.2660279933834926}. Best is trial 16 with value: 0.21770030687004144.
# [I 2026-01-29 21:36:17,727] Trial 18 finished with value: 0.2157753869298217 and parameters: {'conf_alpha': 3.034310098807905}. Best is trial 16 with value: 0.21770030687004144.
# [I 2026-01-29 21:36:17,821] A new study created in memory with name: no-name-8be34820-29dc-4f8a-a2a1-2a9d85740389
# Running optimization for ALS_factors=100 with power...
# [I 2026-01-29 21:36:18,077] Trial 0 finished with value: 0.21692548805057385 and parameters: {'power_p': 1.0227201923681022}. Best is trial 0 with value: 0.21692548805057385.
# [I 2026-01-29 21:36:18,258] Trial 2 finished with value: 0.21762481316697546 and parameters: {'power_p': 1.2734523622342635}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,273] Trial 1 finished with value: 0.2167945661889386 and parameters: {'power_p': 0.4506954565129444}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,288] Trial 3 finished with value: 0.21386561831521178 and parameters: {'power_p': 0.2436862302325138}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,559] Trial 4 finished with value: 0.21625676995017237 and parameters: {'power_p': 0.6092999040500637}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,582] Trial 7 finished with value: 0.21610147325886578 and parameters: {'power_p': 0.51425691048556}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,680] Trial 6 finished with value: 0.21617223075749328 and parameters: {'power_p': 0.5597732516003088}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,700] Trial 5 finished with value: 0.21531658782618893 and parameters: {'power_p': 0.8069589951659647}. Best is trial 2 with value: 0.21762481316697546.
# [I 2026-01-29 21:36:18,950] Trial 9 finished with value: 0.2182471817543794 and parameters: {'power_p': 1.167833685385926}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:18,972] Trial 8 finished with value: 0.21601833387781835 and parameters: {'power_p': 0.5938595382927143}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:18,972] Trial 11 finished with value: 0.2166384468671184 and parameters: {'power_p': 0.37457882337226145}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,066] Trial 10 finished with value: 0.21632709357431404 and parameters: {'power_p': 1.0372225764522465}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,308] Trial 12 finished with value: 0.21604681938026246 and parameters: {'power_p': 0.36075504075021436}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,414] Trial 13 finished with value: 0.2162604841873699 and parameters: {'power_p': 1.4534876017149354}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,434] Trial 14 finished with value: 0.21553578517454017 and parameters: {'power_p': 1.394626349637785}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,434] Trial 15 finished with value: 0.21614859406799397 and parameters: {'power_p': 1.4560111694811768}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,688] Trial 16 finished with value: 0.21590483975736724 and parameters: {'power_p': 1.4171261390202492}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,699] Trial 17 finished with value: 0.21581300702577824 and parameters: {'power_p': 1.432648645201021}. Best is trial 9 with value: 0.2182471817543794.
# [I 2026-01-29 21:36:19,705] Trial 18 finished with value: 0.2188496819967192 and parameters: {'power_p': 1.2204511828522826}. Best is trial 18 with value: 0.2188496819967192.
# [I 2026-01-29 21:36:19,799] Trial 19 finished with value: 0.21879685749143585 and parameters: {'power_p': 1.2197618941623223}. Best is trial 18 with value: 0.2188496819967192.
# [I 2026-01-29 21:36:20,108] A new study created in memory with name: no-name-adda5fc6-0fb7-4075-ac6a-61b15c0760bb
# [I 2026-01-29 21:36:20,175] Trial 0 finished with value: 0.1277877666024402 and parameters: {}. Best is trial 0 with value: 0.1277877666024402.
# [I 2026-01-29 21:36:20,263] A new study created in memory with name: no-name-4005c185-9bda-48f2-9360-fd7acda8f36d
# Running optimization for ALS_factors=100 with normalized...
# Running optimization for ALS_factors=100 with pmi...
# [I 2026-01-29 21:36:20,342] Trial 0 finished with value: 0.19111085700305178 and parameters: {}. Best is trial 0 with value: 0.19111085700305178.
# [I 2026-01-29 21:36:20,431] A new study created in memory with name: no-name-6d923ad1-7c01-48f1-aa90-4a55253a4c57
# Running optimization for ALS_factors=100 with robust_user_centric...
# [I 2026-01-29 21:36:21,562] Trial 3 finished with value: 0.20431562959598393 and parameters: {'scale_factor': 2.008183389769658}. Best is trial 3 with value: 0.20431562959598393.
# [I 2026-01-29 21:36:21,570] Trial 1 finished with value: 0.21171537592866346 and parameters: {'scale_factor': 4.418970079933107}. Best is trial 1 with value: 0.21171537592866346.
# [I 2026-01-29 21:36:21,680] Trial 2 finished with value: 0.18875410790747546 and parameters: {'scale_factor': 0.8736277486550135}. Best is trial 1 with value: 0.21171537592866346.
# [I 2026-01-29 21:36:21,857] Trial 0 finished with value: 0.2085470139734176 and parameters: {'scale_factor': 2.394833802702738}. Best is trial 1 with value: 0.21171537592866346.
# [I 2026-01-29 21:36:22,953] Trial 4 finished with value: 0.21108261153875335 and parameters: {'scale_factor': 4.895088359609936}. Best is trial 1 with value: 0.21171537592866346.
# [I 2026-01-29 21:36:22,972] Trial 5 finished with value: 0.21145486635638536 and parameters: {'scale_factor': 6.2217407115231875}. Best is trial 1 with value: 0.21171537592866346.
# [I 2026-01-29 21:36:23,071] Trial 7 finished with value: 0.2143092683846352 and parameters: {'scale_factor': 7.92487027329883}. Best is trial 7 with value: 0.2143092683846352.
# [I 2026-01-29 21:36:23,171] Trial 6 finished with value: 0.21204914238409908 and parameters: {'scale_factor': 5.396697836980992}. Best is trial 7 with value: 0.2143092683846352.
# [I 2026-01-29 21:36:24,220] Trial 8 finished with value: 0.21427798370835086 and parameters: {'scale_factor': 7.966207645010659}. Best is trial 7 with value: 0.2143092683846352.
# [I 2026-01-29 21:36:24,236] Trial 9 finished with value: 0.21189333411485567 and parameters: {'scale_factor': 5.926985370315519}. Best is trial 7 with value: 0.2143092683846352.
# [I 2026-01-29 21:36:24,330] Trial 11 finished with value: 0.20263021277400342 and parameters: {'scale_factor': 1.7136874308485341}. Best is trial 7 with value: 0.2143092683846352.
# [I 2026-01-29 21:36:24,437] Trial 10 finished with value: 0.2119165078058313 and parameters: {'scale_factor': 5.998458904010634}. Best is trial 7 with value: 0.2143092683846352.
# [I 2026-01-29 21:36:25,464] Trial 13 finished with value: 0.21449525859913224 and parameters: {'scale_factor': 9.932181522407426}. Best is trial 13 with value: 0.21449525859913224.
# [I 2026-01-29 21:36:25,586] Trial 12 finished with value: 0.21033892625654735 and parameters: {'scale_factor': 2.606079063835794}. Best is trial 13 with value: 0.21449525859913224.
# [I 2026-01-29 21:36:25,689] Trial 14 finished with value: 0.2148499861969598 and parameters: {'scale_factor': 9.659237650682254}. Best is trial 14 with value: 0.2148499861969598.
# [I 2026-01-29 21:36:25,713] Trial 15 finished with value: 0.2147920154476759 and parameters: {'scale_factor': 9.471054425606212}. Best is trial 14 with value: 0.2148499861969598.
# [I 2026-01-29 21:36:26,628] Trial 16 finished with value: 0.2146649425369915 and parameters: {'scale_factor': 9.962096772012995}. Best is trial 14 with value: 0.2148499861969598.
# [I 2026-01-29 21:36:26,774] Trial 17 finished with value: 0.21481818845751433 and parameters: {'scale_factor': 9.91266538449825}. Best is trial 14 with value: 0.2148499861969598.
# [I 2026-01-29 21:36:26,793] Trial 19 finished with value: 0.215062476823161 and parameters: {'scale_factor': 9.791121397919685}. Best is trial 19 with value: 0.215062476823161.
# [I 2026-01-29 21:36:26,883] Trial 18 finished with value: 0.21460414964496413 and parameters: {'scale_factor': 9.952412505536287}. Best is trial 19 with value: 0.215062476823161.
# [I 2026-01-29 21:36:27,158] A new study created in memory with name: no-name-8641b840-514f-4b18-b3dc-adc9b5b0e65c
# Running optimization for ALS_factors=100 with robust_user_centric_weight_v2...
# [I 2026-01-29 21:36:28,486] Trial 3 finished with value: 0.19590423571447374 and parameters: {'lower_q': 30.069096915779863, 'upper_q': 83.53069777740404}. Best is trial 3 with value: 0.19590423571447374.
# [I 2026-01-29 21:36:28,588] Trial 0 finished with value: 0.18670428669399255 and parameters: {'lower_q': 41.35173363165335, 'upper_q': 73.88283518818308}. Best is trial 3 with value: 0.19590423571447374.
# [I 2026-01-29 21:36:28,608] Trial 2 finished with value: 0.19883123411864595 and parameters: {'lower_q': 19.523713314443093, 'upper_q': 84.42780094904067}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:28,703] Trial 1 finished with value: 0.19056978491848084 and parameters: {'lower_q': 34.65764703263888, 'upper_q': 67.50116677912648}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:29,774] Trial 4 finished with value: 0.19253017269186548 and parameters: {'lower_q': 11.825564859246981, 'upper_q': 55.66130916254886}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:29,800] Trial 6 finished with value: 0.19766232501578324 and parameters: {'lower_q': 15.132625101792264, 'upper_q': 85.69490866237977}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:29,977] Trial 5 finished with value: 0.19576796539955385 and parameters: {'lower_q': 13.579671191335926, 'upper_q': 64.32041707852667}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:29,992] Trial 7 finished with value: 0.19433658738623436 and parameters: {'lower_q': 20.16928476322882, 'upper_q': 76.55762919604206}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:31,030] Trial 8 finished with value: 0.195243118852618 and parameters: {'lower_q': 6.431266824075261, 'upper_q': 63.41994325720871}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:31,096] Trial 10 finished with value: 0.19661830181012716 and parameters: {'lower_q': 12.59779285592263, 'upper_q': 93.97995823302108}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:31,144] Trial 9 finished with value: 0.19260487025422235 and parameters: {'lower_q': 40.43716254953501, 'upper_q': 81.87565275328794}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:31,242] Trial 11 finished with value: 0.19801599094665331 and parameters: {'lower_q': 21.30211652948903, 'upper_q': 93.60212161541568}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:32,205] Trial 12 finished with value: 0.19071947374136053 and parameters: {'lower_q': 24.66526480821067, 'upper_q': 73.3750599442707}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:32,294] Trial 14 finished with value: 0.19821134370851173 and parameters: {'lower_q': 21.944853684475213, 'upper_q': 92.67155768724865}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:32,357] Trial 15 finished with value: 0.1963255305243354 and parameters: {'lower_q': 24.102473833788782, 'upper_q': 94.19945355007049}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:32,419] Trial 13 finished with value: 0.1965519446667474 and parameters: {'lower_q': 23.76873257860661, 'upper_q': 93.25986318819184}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:33,216] Trial 16 finished with value: 0.19716352445775753 and parameters: {'lower_q': 22.53323557776353, 'upper_q': 94.24821905835677}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:33,422] Trial 18 finished with value: 0.19395546376286807 and parameters: {'lower_q': 30.496349177141916, 'upper_q': 88.07635173946916}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:33,525] Trial 17 finished with value: 0.19317454544578477 and parameters: {'lower_q': 29.571970957959415, 'upper_q': 89.12674979477035}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:33,537] Trial 19 finished with value: 0.19263424279440824 and parameters: {'lower_q': 29.416876503474853, 'upper_q': 88.74505003349195}. Best is trial 2 with value: 0.19883123411864595.
# [I 2026-01-29 21:36:33,804] A new study created in memory with name: no-name-20292428-be44-415a-9018-1841a1844c8a
# Running optimization for ALS_factors=100 with sigmoid_propensity...
# [I 2026-01-29 21:36:34,045] Trial 3 finished with value: 0.21978194131601553 and parameters: {'p': 1.267129304001736, 'beta': 0.9081640847987025}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,062] Trial 1 finished with value: 0.21629484572171764 and parameters: {'p': 2.337177107420177, 'beta': 0.5505157521025191}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,071] Trial 0 finished with value: 0.2184135609869795 and parameters: {'p': 1.4472188847245229, 'beta': 0.7282328023555357}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,072] Trial 2 finished with value: 0.19951102407902513 and parameters: {'p': 1.754583261209572, 'beta': 0.05339150693109784}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,326] Trial 4 finished with value: 0.2085639456465716 and parameters: {'p': 4.498423599870919, 'beta': 0.5092912850902908}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,427] Trial 5 finished with value: 0.21762684497251628 and parameters: {'p': 0.6435888489167937, 'beta': 0.5626693307072658}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,508] Trial 7 finished with value: 0.214544808163126 and parameters: {'p': 0.9688172683668738, 'beta': 0.41345133291918845}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,522] Trial 6 finished with value: 0.21436162587121282 and parameters: {'p': 0.13837437546222114, 'beta': 0.3203638757902586}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,771] Trial 8 finished with value: 0.20266502650014234 and parameters: {'p': 4.630494587108258, 'beta': 0.29412925018032443}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,797] Trial 10 finished with value: 0.21816933014858184 and parameters: {'p': 1.2565381952137002, 'beta': 0.6513564401092241}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,800] Trial 9 finished with value: 0.1873354437273959 and parameters: {'p': 4.74544359841821, 'beta': 0.09255669320187832}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:34,802] Trial 11 finished with value: 0.21853212091612334 and parameters: {'p': 1.7265488440832026, 'beta': 0.915800661191336}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,065] Trial 14 finished with value: 0.21543995939685712 and parameters: {'p': 3.281539010852212, 'beta': 0.9857823382777282}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,167] Trial 15 finished with value: 0.21421744506999005 and parameters: {'p': 3.361942578124709, 'beta': 0.9727220108723779}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,177] Trial 13 finished with value: 0.21493030437095648 and parameters: {'p': 3.187092768911993, 'beta': 0.9537595304481127}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,184] Trial 12 finished with value: 0.21369134877614215 and parameters: {'p': 3.544373479511266, 'beta': 0.9892904777748585}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,440] Trial 16 finished with value: 0.21448386250246473 and parameters: {'p': 2.7920487291722136, 'beta': 0.9077999073914201}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,548] Trial 17 finished with value: 0.21841718250828773 and parameters: {'p': 2.175848430178404, 'beta': 0.7671884105451958}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,563] Trial 18 finished with value: 0.2165090430364532 and parameters: {'p': 2.457352579481732, 'beta': 0.8042795148219221}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,563] Trial 19 finished with value: 0.21756341213648617 and parameters: {'p': 2.1161661370329607, 'beta': 0.7968942831246963}. Best is trial 3 with value: 0.21978194131601553.
# [I 2026-01-29 21:36:35,655] A new study created in memory with name: no-name-a936591d-fb43-4e51-9131-7700c460c706
# Running optimization for ALS_factors=100 with power_lift...
# [I 2026-01-29 21:36:35,905] Trial 0 finished with value: 0.19491544361222762 and parameters: {'p': 1.0028780566704256}. Best is trial 0 with value: 0.19491544361222762.
# [I 2026-01-29 21:36:36,013] Trial 1 finished with value: 0.2124158633050557 and parameters: {'p': 0.253216302866053}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,121] Trial 2 finished with value: 0.20738866968265482 and parameters: {'p': 0.4657381146829297}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,131] Trial 3 finished with value: 0.19555704400855548 and parameters: {'p': 1.070329076645179}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,375] Trial 5 finished with value: 0.18499684180119594 and parameters: {'p': 1.451454831506804}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,478] Trial 4 finished with value: 0.19525502772577927 and parameters: {'p': 1.159018357297566}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,563] Trial 6 finished with value: 0.19533497800178923 and parameters: {'p': 0.8248144546123783}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,579] Trial 7 finished with value: 0.1966007311454669 and parameters: {'p': 1.1248898598281964}. Best is trial 1 with value: 0.2124158633050557.
# [I 2026-01-29 21:36:36,828] Trial 9 finished with value: 0.2124951070246933 and parameters: {'p': 0.22587517353987646}. Best is trial 9 with value: 0.2124951070246933.
# [I 2026-01-29 21:36:36,931] Trial 8 finished with value: 0.19655654290938138 and parameters: {'p': 0.8044794320643323}. Best is trial 9 with value: 0.2124951070246933.
# [I 2026-01-29 21:36:37,019] Trial 10 finished with value: 0.21204791049077654 and parameters: {'p': 0.1673074347200123}. Best is trial 9 with value: 0.2124951070246933.
# [I 2026-01-29 21:36:37,036] Trial 11 finished with value: 0.19510915679837978 and parameters: {'p': 0.9263558992935557}. Best is trial 9 with value: 0.2124951070246933.
# [I 2026-01-29 21:36:37,287] Trial 12 finished with value: 0.2121242454073805 and parameters: {'p': 0.15043381607711898}. Best is trial 9 with value: 0.2124951070246933.
# [I 2026-01-29 21:36:37,391] Trial 13 finished with value: 0.21274395808762636 and parameters: {'p': 0.20796751947501094}. Best is trial 13 with value: 0.21274395808762636.
# [I 2026-01-29 21:36:37,408] Trial 15 finished with value: 0.21199880841529078 and parameters: {'p': 0.1818941997773521}. Best is trial 13 with value: 0.21274395808762636.
# [I 2026-01-29 21:36:37,408] Trial 14 finished with value: 0.2133856707340885 and parameters: {'p': 0.12474322411945926}. Best is trial 14 with value: 0.2133856707340885.
# [I 2026-01-29 21:36:37,668] Trial 16 finished with value: 0.20896592872442504 and parameters: {'p': 0.4494478670925449}. Best is trial 14 with value: 0.2133856707340885.
# [I 2026-01-29 21:36:37,771] Trial 18 finished with value: 0.20235189670942488 and parameters: {'p': 0.5361874481973967}. Best is trial 14 with value: 0.2133856707340885.
# [I 2026-01-29 21:36:37,778] Trial 19 finished with value: 0.2069111479978065 and parameters: {'p': 0.4722143173022282}. Best is trial 14 with value: 0.2133856707340885.
# [I 2026-01-29 21:36:37,789] Trial 17 finished with value: 0.20591029643289607 and parameters: {'p': 0.48057436207414783}. Best is trial 14 with value: 0.2133856707340885.
#           Algorithm                       Strategy  Best Val NDCG@20  \
# 11   ALS_factors=10                     power_lift          0.275097
# 7    ALS_factors=10                            pmi          0.265106
# 5    ALS_factors=10                          power          0.276861
# 3    ALS_factors=10                            log          0.274856
# 10   ALS_factors=10             sigmoid_propensity          0.273607
# 0    ALS_factors=10                   no_weighting          0.272449
# 8    ALS_factors=10            robust_user_centric          0.272076
# 1    ALS_factors=10                           bm25          0.260228
# 2    ALS_factors=10                          tfidf          0.258425
# 4    ALS_factors=10                     confidence          0.260652
# 9    ALS_factors=10  robust_user_centric_weight_v2          0.263102
# 22  ALS_factors=100             sigmoid_propensity          0.219782
# 12  ALS_factors=100                   no_weighting          0.216296
# 17  ALS_factors=100                          power          0.218850
# 20  ALS_factors=100            robust_user_centric          0.215062
# 15  ALS_factors=100                            log          0.216076
# 23  ALS_factors=100                     power_lift          0.213386
# 16  ALS_factors=100                     confidence          0.217700
# 13  ALS_factors=100                           bm25          0.214534
# 14  ALS_factors=100                          tfidf          0.215837
# 6    ALS_factors=10                     normalized          0.210438
# 21  ALS_factors=100  robust_user_centric_weight_v2          0.198831
# 19  ALS_factors=100                            pmi          0.191111
# 18  ALS_factors=100                     normalized          0.127788
#
#     Test NDCG@20  Test Precision@20  Final Train Time (s)  \
# 11      0.339081           0.373401              0.029398
# 7       0.332565           0.358479              0.030410
# 5       0.331789           0.372335              0.030452
# 3       0.330926           0.370914              0.032584
# 10      0.330089           0.370914              0.030450
# 0       0.329265           0.367480              0.030377
# 8       0.327652           0.367598              0.030441
# 1       0.324415           0.358835              0.034649
# 2       0.322167           0.356111              0.033605
# 4       0.321578           0.355045              0.029398
# 9       0.318217           0.361322              0.030456
# 22      0.283013           0.288607              0.065059
# 12      0.281058           0.287305              0.068235
# 17      0.280844           0.289792              0.066409
# 20      0.278648           0.287778              0.065090
# 15      0.276273           0.282331              0.067911
# 23      0.274196           0.282686              0.066486
# 16      0.273133           0.281502              0.068242
# 13      0.273110           0.285410              0.065072
# 14      0.271991           0.281739              0.065095
# 6       0.271310           0.307556              0.030448
# 21      0.250356           0.261369              0.065098
# 19      0.246793           0.254737              0.067848
# 18      0.174454           0.210919              0.066144
#
#                                           Best Params
# 11                         {'p': 0.20298154336881027}
# 7                                                  {}
# 5                     {'power_p': 0.5504693184151779}
# 3                                                  {}
# 10  {'p': 1.40152528826798, 'beta': 0.568393012901...
# 0                                                  {}
# 8                {'scale_factor': 2.8983133438111786}
# 1   {'bm25_k1': 10.924518246974912, 'bm25_b': 0.47...
# 2                                                  {}
# 4                  {'conf_alpha': 1.1958441973755038}
# 9   {'lower_q': 6.24671093300206, 'upper_q': 92.59...
# 22  {'p': 1.267129304001736, 'beta': 0.90816408479...
# 12                                                 {}
# 17                    {'power_p': 1.2204511828522826}
# 20                {'scale_factor': 9.791121397919685}
# 15                                                 {}
# 23                         {'p': 0.12474322411945926}
# 16                 {'conf_alpha': 1.2660279933834926}
# 13  {'bm25_k1': 18.250742736854136, 'bm25_b': 0.00...
# 14                                                 {}
# 6                                                  {}
# 21  {'lower_q': 19.523713314443093, 'upper_q': 84....
# 19                                                 {}
# 18                                                 {}

# %%
import glob

all_results = []
# Match any CSV in the result folder
for f in glob.glob(f"{results_folder}/*.csv"):
    all_results.append(pd.read_csv(f))

if all_results:
    experiment_results = pd.concat(all_results)
    experiment_results = experiment_results.sort_values("Test NDCG@20", ascending=False)
    experiment_results.to_csv(results_filename, index=False)
else:
    print("No results found.")

experiment_results
