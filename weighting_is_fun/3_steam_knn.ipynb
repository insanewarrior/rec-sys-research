# %%
import numpy as np
import pandas as pd
import optuna
from scipy.sparse import csr_matrix
from weighting_strategies import (
    bm25_weight, tfidf_weight, normalized_weight,
    log_weight, confidence_weight, power_weight,
    pmi_weight, robust_user_centric_weight, sigmoid_propensity_weight, power_lift_weight, robust_user_centric_weight_v2
)
from implicit.nearest_neighbours import CosineRecommender
from implicit.evaluation import train_test_split, precision_at_k, ndcg_at_k

import cornac

# %%
import sys
import os

# Add the parent directory to sys.path to resolve imports from sibling directories
sys.path.append(os.path.abspath(".."))

from utils.sparse import transform_dataframe_to_sparse

# %%
steam_df = (
    pd.read_csv(
        "/home/coder/projects/rec-sys-research/data/steam/steam_recommendations.csv",
        usecols=['user_id', 'app_id', 'hours'],
    )
    .loc[:, ['user_id', 'app_id', 'hours']]
    .drop_duplicates()
    .dropna()
    .rename(columns={'app_id': 'item_id', 'hours': 'target'})
)
steam_df['user_id'].nunique(), steam_df['item_id'].nunique(), steam_df.shape[0]
# Out:
# (13781059, 37610, 41154773)

# %%
unique_users = steam_df['user_id'].unique()
keep_ratio = 0.2
sampled_users = np.random.choice(unique_users, size=int(len(unique_users) * keep_ratio), replace=False)
steam_df = steam_df[steam_df['user_id'].isin(sampled_users)]

steam_df['user_id'].nunique(), steam_df['item_id'].nunique(), steam_df.shape[0]
# Out:
# (2756211, 34923, 8221106)

# %%
user_item_matrix, user_mapping, item_mapping = transform_dataframe_to_sparse(
    steam_df, row_field='user_id', col_field='item_id', data_field='target'
)


train_val_mat, test_mat = train_test_split(user_item_matrix, train_percentage=0.9, random_state=42)
train_mat, val_mat = train_test_split(train_val_mat, train_percentage=0.9, random_state=42)

print(f"Train Shape: {train_mat.shape}, Val Shape: {val_mat.shape}, Test Shape: {test_mat.shape}")
# Out:
# Train Shape: (2756211, 34923), Val Shape: (2756211, 34923), Test Shape: (2756211, 34923)

# %%
results_folder = "results/steam_knn"
results_filename = "steam_knn_results.csv"

import time

def run_hyperparameter_optimization(
    train_mat: csr_matrix,
    val_mat: csr_matrix,
    train_val_mat: csr_matrix,
    test_mat: csr_matrix,
    weighting_strategy: str,
    algorithm: str,
    n_trials: int = 20,
    output_dir: str = None,
) -> pd.DataFrame:
    results = []
    algorithms = {
        "KNN_k=20": lambda: CosineRecommender(K=20),
        "KNN_k=100": lambda: CosineRecommender(K=100),
    }
    strategies = [
        "no_weighting",
        "bm25",
        "tfidf",
        "log", 
        "confidence",
        "power",
        "normalized",
        "pmi",
        "robust_user_centric",
        "robust_user_centric_weight_v2",
        "sigmoid_propensity",
        "power_lift"
    ]
    if weighting_strategy not in strategies:
        raise ValueError(f"Weighting strategy '{weighting_strategy}' is not recognized.")
    strategy = weighting_strategy

    if algorithm not in algorithms:
        raise ValueError(f"Algorithm '{algorithm}' is not recognized.")
    algo_name = algorithm
    AlgoFactory = algorithms[algorithm]

    print(f"Running optimization for {algo_name} with {strategy}...")

    def get_weighted_matrix(matrix, params):
        weighted = matrix.copy()
        if strategy == "bm25":
            weighted = bm25_weight(weighted, K1=params.get("bm25_k1"), B=params.get("bm25_b"))
        elif strategy == "confidence":
            weighted = confidence_weight(weighted, alpha=params.get("conf_alpha"))
        elif strategy == "power":
            weighted = power_weight(weighted, p=params.get("power_p"))
        elif strategy == "tfidf":
            weighted = tfidf_weight(weighted)
        elif strategy == "log":
            weighted = log_weight(weighted)
        elif strategy == "normalized":
            weighted = normalized_weight(weighted)
        elif strategy == "pmi":
            weighted = pmi_weight(weighted)
        elif strategy == "robust_user_centric":
            weighted = robust_user_centric_weight(weighted, scale_factor=params.get("scale_factor"))
        elif strategy == "sigmoid_propensity":
            weighted = sigmoid_propensity_weight(weighted, p=params.get("p"), beta=params.get("beta"))
        elif strategy == "power_lift":
            weighted = power_lift_weight(weighted, p=params.get("p"))
        elif strategy == "robust_user_centric_weight_v2":
            weighted = robust_user_centric_weight_v2(weighted, lower_q=params.get("lower_q"), upper_q=params.get("upper_q"))
        return weighted

    def objective(trial):
        params = {}
        # Suggest weighting strategy parameters
        if strategy == "bm25":
            params["bm25_k1"] = trial.suggest_float("bm25_k1", 0.1, 1000)
            params["bm25_b"] = trial.suggest_float("bm25_b", 0.0, 1.0)
        elif strategy == "confidence":
            params["conf_alpha"] = trial.suggest_float("conf_alpha", 1.0, 150.0)
        elif strategy == "power":
            params["power_p"] = trial.suggest_float("power_p", 0.1, 1.5)
        elif strategy == "robust_user_centric":
            params["scale_factor"] = trial.suggest_float("scale_factor", 0.1, 10.0)
        elif strategy == "robust_user_centric_weight_v2":
            params["lower_q"] = trial.suggest_float("lower_q", 5.0, 45.0)
            params["upper_q"] = trial.suggest_float("upper_q", 55.0, 95.0)
        elif strategy == "sigmoid_propensity":
            params["p"] = trial.suggest_float("p", 0.1, 5.0)
            params["beta"] = trial.suggest_float("beta", 0.0, 1.0)
        elif strategy == "power_lift":
            params["p"] = trial.suggest_float("p", 0.1, 1.5)
        weighted_train = get_weighted_matrix(train_mat, params)

        # Train Model
        model = AlgoFactory()
        model.fit(weighted_train, show_progress=False)

        # Evaluate on Validation Set
        return ndcg_at_k(model, train_mat, val_mat, K=20, show_progress=False)

    # Optimize only if strategy has parameters
    current_trials = n_trials if strategy in ["bm25", "confidence", "power", "robust_user_centric", "robust_user_centric_weight_v2", "sigmoid_propensity", "power_lift"] else 1
    study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=current_trials, n_jobs=-1)

    # --- Final Retraining & Testing ---
    # Use best params to weight the full train_val matrix
    best_params = study.best_params
    weighted_train_val = get_weighted_matrix(train_val_mat, best_params)

    # Train Final Model
    final_model = AlgoFactory()
    
    start_time = time.time()
    final_model.fit(weighted_train_val, show_progress=False)
    end_time = time.time()
    
    # Evaluate on Test Set
    test_ndcg_10 = ndcg_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    test_precision_10 = precision_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    test_ndcg_20 = ndcg_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)
    test_precision_20 = precision_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)

    results.append({
        "Algorithm": algo_name,
        "Strategy": strategy,
        "Number of Optimization Trials": current_trials,
        "Best Val NDCG@20": study.best_value,
        "Test NDCG@10": test_ndcg_10,
        "Test NDCG@20": test_ndcg_20,
        "Test Precision@10": test_precision_10,
        "Test Precision@20": test_precision_20,
        "Final Train Time (s)": end_time - start_time,
        "Best Params": best_params
    })

    if output_dir:
        output_path = os.path.join(output_dir, f"{algo_name}_{strategy}_results.csv")
        pd.DataFrame(results).to_csv(output_path, index=False)
    return pd.DataFrame(results)

# %%
if not os.path.exists(results_folder):
    os.makedirs(results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 20:57:13,081] A new study created in memory with name: no-name-4018c675-c844-416d-a827-7c51ce14e200
# Running optimization for KNN_k=20 with no_weighting...
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.060346364974975586 seconds
#   warnings.warn(
# [I 2026-02-08 20:57:48,601] Trial 0 finished with value: 0.022315868292687932 and parameters: {}. Best is trial 0 with value: 0.022315868292687932.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.06082320213317871 seconds
#   warnings.warn(
#   Algorithm      Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20  no_weighting                              1          0.022316
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.022292      0.026283           0.035798            0.05061
#
#    Final Train Time (s) Best Params
# 0              0.762561          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 21:00:22,650] A new study created in memory with name: no-name-018f04eb-1fc1-41cb-89a6-2521c51eb6bc
# Running optimization for KNN_k=20 with bm25...
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.07793045043945312 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08258485794067383 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08127021789550781 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.0901041030883789 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09140348434448242 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09181761741638184 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09139633178710938 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08809185028076172 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.10231685638427734 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08680009841918945 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08917713165283203 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.10002827644348145 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.10429739952087402 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.10843634605407715 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.11740827560424805 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.11311483383178711 seconds
#   warnings.warn(
# [I 2026-02-08 21:13:19,151] Trial 3 finished with value: 0.023037339534957107 and parameters: {'bm25_k1': 665.4144343657177, 'bm25_b': 0.7893638556798601}. Best is trial 3 with value: 0.023037339534957107.
# [I 2026-02-08 21:13:19,426] Trial 12 finished with value: 0.03180185529494313 and parameters: {'bm25_k1': 676.5458042216974, 'bm25_b': 0.21172095877384534}. Best is trial 12 with value: 0.03180185529494313.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05703020095825195 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.06174063682556152 seconds
#   warnings.warn(
# [I 2026-02-08 21:13:20,867] Trial 13 finished with value: 0.03428503437493566 and parameters: {'bm25_k1': 362.2190137117366, 'bm25_b': 0.24735720048872978}. Best is trial 13 with value: 0.03428503437493566.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05666017532348633 seconds
#   warnings.warn(
# [I 2026-02-08 21:13:23,906] Trial 1 finished with value: 0.02220871916040659 and parameters: {'bm25_k1': 590.1487655426472, 'bm25_b': 0.8561350101835346}. Best is trial 13 with value: 0.03428503437493566.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.06600403785705566 seconds
#   warnings.warn(
# [I 2026-02-08 21:13:28,588] Trial 4 finished with value: 0.029849832034617094 and parameters: {'bm25_k1': 850.3637417619482, 'bm25_b': 0.2698896701065756}. Best is trial 13 with value: 0.03428503437493566.
# [I 2026-02-08 21:13:30,800] Trial 8 finished with value: 0.03378772877087963 and parameters: {'bm25_k1': 327.9721288418022, 'bm25_b': 0.3178616886306319}. Best is trial 13 with value: 0.03428503437493566.
# [I 2026-02-08 21:13:31,790] Trial 2 finished with value: 0.017280402936439045 and parameters: {'bm25_k1': 726.9898596989765, 'bm25_b': 0.9808032562447117}. Best is trial 13 with value: 0.03428503437493566.
# [I 2026-02-08 21:13:31,872] Trial 7 finished with value: 0.02883080447317471 and parameters: {'bm25_k1': 327.22535975486124, 'bm25_b': 0.6597739671164533}. Best is trial 13 with value: 0.03428503437493566.
# [I 2026-02-08 21:13:32,859] Trial 9 finished with value: 0.024475146858878315 and parameters: {'bm25_k1': 590.1083238097485, 'bm25_b': 0.7406221887904149}. Best is trial 13 with value: 0.03428503437493566.
# [I 2026-02-08 21:13:33,376] Trial 5 finished with value: 0.03900542113393303 and parameters: {'bm25_k1': 199.86389709930225, 'bm25_b': 0.006906201361294939}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:13:33,672] Trial 6 finished with value: 0.01901013412475274 and parameters: {'bm25_k1': 795.4228655627832, 'bm25_b': 0.931287374563627}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:13:34,098] Trial 11 finished with value: 0.03623458356476971 and parameters: {'bm25_k1': 408.729446271029, 'bm25_b': 0.0549697317417448}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:13:35,131] Trial 10 finished with value: 0.0293165525403728 and parameters: {'bm25_k1': 252.00734653212112, 'bm25_b': 0.7384260434652941}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:13:35,153] Trial 0 finished with value: 0.03301215777649661 and parameters: {'bm25_k1': 470.66551206977243, 'bm25_b': 0.24395421119579508}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:13:36,909] Trial 15 finished with value: 0.03513534449717988 and parameters: {'bm25_k1': 378.5175825192746, 'bm25_b': 0.17658329704551157}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:13:37,073] Trial 14 finished with value: 0.03124008884489833 and parameters: {'bm25_k1': 300.33834346430615, 'bm25_b': 0.5351784039284184}. Best is trial 5 with value: 0.03900542113393303.
# [I 2026-02-08 21:16:39,264] Trial 16 finished with value: 0.047995097651819675 and parameters: {'bm25_k1': 5.70943264168309, 'bm25_b': 0.6801386808846791}. Best is trial 16 with value: 0.047995097651819675.
# [I 2026-02-08 21:16:41,391] Trial 19 finished with value: 0.034330943539123644 and parameters: {'bm25_k1': 555.7954153521422, 'bm25_b': 0.10212429502598996}. Best is trial 16 with value: 0.047995097651819675.
# [I 2026-02-08 21:16:44,854] Trial 18 finished with value: 0.03443377229813865 and parameters: {'bm25_k1': 222.29423264530257, 'bm25_b': 0.43846300325832044}. Best is trial 16 with value: 0.047995097651819675.
# [I 2026-02-08 21:16:45,397] Trial 17 finished with value: 0.02554134439631391 and parameters: {'bm25_k1': 841.0549766681044, 'bm25_b': 0.5698828962084626}. Best is trial 16 with value: 0.047995097651819675.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.050817251205444336 seconds
#   warnings.warn(
#   Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20     bm25                             20          0.047995
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.043466      0.052271           0.074397           0.107907
#
#    Final Train Time (s)                                        Best Params
# 0              0.703722  {'bm25_k1': 5.70943264168309, 'bm25_b': 0.6801...

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 21:30:48,056] A new study created in memory with name: no-name-5fc16871-5ed5-45b9-ae1a-17c20c080d17
# Running optimization for KNN_k=20 with tfidf...
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05669355392456055 seconds
#   warnings.warn(
# [I 2026-02-08 21:31:24,833] Trial 0 finished with value: 0.03940907499912941 and parameters: {}. Best is trial 0 with value: 0.03940907499912941.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.051790714263916016 seconds
#   warnings.warn(
#   Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20    tfidf                              1          0.039409
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0       0.03685      0.044045           0.062813           0.090411
#
#    Final Train Time (s) Best Params
# 0              0.743291          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 21:34:01,614] A new study created in memory with name: no-name-6a56625c-f643-47cf-af10-c93a92fd9862
# Running optimization for KNN_k=20 with log...
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05656576156616211 seconds
#   warnings.warn(
# [I 2026-02-08 21:34:38,016] Trial 0 finished with value: 0.04454237791769868 and parameters: {}. Best is trial 0 with value: 0.04454237791769868.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05148482322692871 seconds
#   warnings.warn(
#   Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20      log                              1          0.044542
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.040929      0.048828           0.069961           0.100757
#
#    Final Train Time (s) Best Params
# 0              0.694295          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="confidence", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 21:37:15,895] A new study created in memory with name: no-name-392c79d4-a0a0-426e-94f5-761a672518c9
# Running optimization for KNN_k=20 with confidence...
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.07833337783813477 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09340381622314453 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.10043144226074219 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09682440757751465 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09272646903991699 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.10214042663574219 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09868168830871582 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09920430183410645 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09011340141296387 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09019207954406738 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.12491655349731445 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09711909294128418 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09562301635742188 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09350204467773438 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08127212524414062 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08223271369934082 seconds
#   warnings.warn(
# [I 2026-02-08 21:50:15,411] Trial 0 finished with value: 0.04585265074584159 and parameters: {'conf_alpha': 106.92631807853583}. Best is trial 0 with value: 0.04585265074584159.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.057326316833496094 seconds
#   warnings.warn(
# [I 2026-02-08 21:50:26,125] Trial 2 finished with value: 0.045853714683484294 and parameters: {'conf_alpha': 71.9736299556975}. Best is trial 2 with value: 0.045853714683484294.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.054865121841430664 seconds
#   warnings.warn(
# [I 2026-02-08 21:50:27,623] Trial 15 finished with value: 0.04585454511904639 and parameters: {'conf_alpha': 44.20800607354046}. Best is trial 15 with value: 0.04585454511904639.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.06870269775390625 seconds
#   warnings.warn(
# [I 2026-02-08 21:50:30,396] Trial 8 finished with value: 0.04588111162951468 and parameters: {'conf_alpha': 9.722986878770948}. Best is trial 8 with value: 0.04588111162951468.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05931878089904785 seconds
#   warnings.warn(
# [I 2026-02-08 21:50:33,425] Trial 4 finished with value: 0.04585250184183873 and parameters: {'conf_alpha': 146.89043946176227}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:35,282] Trial 5 finished with value: 0.04585371987993375 and parameters: {'conf_alpha': 58.35771008435203}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:36,040] Trial 13 finished with value: 0.045852505175105446 and parameters: {'conf_alpha': 126.02037300220718}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:36,087] Trial 9 finished with value: 0.04585250184183873 and parameters: {'conf_alpha': 144.4496826431128}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:36,200] Trial 6 finished with value: 0.04585416022520255 and parameters: {'conf_alpha': 57.24230377323223}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:36,952] Trial 14 finished with value: 0.045855737088381296 and parameters: {'conf_alpha': 36.40687123789236}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:37,046] Trial 7 finished with value: 0.04585371987993375 and parameters: {'conf_alpha': 58.81648043706121}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:37,180] Trial 10 finished with value: 0.04585402474672296 and parameters: {'conf_alpha': 49.40726961995869}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:37,399] Trial 3 finished with value: 0.04585366637618654 and parameters: {'conf_alpha': 81.48621287779945}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:37,427] Trial 12 finished with value: 0.04587334258473264 and parameters: {'conf_alpha': 13.85835269732114}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:39,308] Trial 11 finished with value: 0.04585366149043215 and parameters: {'conf_alpha': 76.25972116176175}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:50:39,709] Trial 1 finished with value: 0.045852499489714135 and parameters: {'conf_alpha': 137.74726443648353}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:53:40,578] Trial 18 finished with value: 0.045852675610915106 and parameters: {'conf_alpha': 99.88226812095742}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:53:43,460] Trial 17 finished with value: 0.04585366149043215 and parameters: {'conf_alpha': 77.78115289565359}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:53:43,639] Trial 16 finished with value: 0.04585250184183873 and parameters: {'conf_alpha': 141.3073458975488}. Best is trial 8 with value: 0.04588111162951468.
# [I 2026-02-08 21:53:44,435] Trial 19 finished with value: 0.045854037416353396 and parameters: {'conf_alpha': 48.794027865884026}. Best is trial 8 with value: 0.04588111162951468.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.050852298736572266 seconds
#   warnings.warn(
#   Algorithm    Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20  confidence                             20          0.045881
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.042271      0.050608           0.071883           0.103768
#
#    Final Train Time (s)                        Best Params
# 0              0.690609  {'conf_alpha': 9.722986878770948}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 21:56:21,074] A new study created in memory with name: no-name-32b105bb-fa5e-4df3-a3bf-ccbb05204d89
# Running optimization for KNN_k=20 with power...
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.07841944694519043 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09192705154418945 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09568548202514648 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09334778785705566 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.0956735610961914 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09180545806884766 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09037518501281738 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08000946044921875 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08611464500427246 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09607052803039551 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09431672096252441 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09560966491699219 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09332418441772461 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.09389019012451172 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.08760738372802734 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.0834500789642334 seconds
#   warnings.warn(
# [I 2026-02-08 22:09:18,711] Trial 14 finished with value: 0.03339700292044895 and parameters: {'power_p': 0.6820831134842941}. Best is trial 14 with value: 0.03339700292044895.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.07108378410339355 seconds
#   warnings.warn(
# [I 2026-02-08 22:09:22,619] Trial 1 finished with value: 0.016437978647781154 and parameters: {'power_p': 1.2878674566786075}. Best is trial 14 with value: 0.03339700292044895.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.07793998718261719 seconds
#   warnings.warn(
# [I 2026-02-08 22:09:23,946] Trial 8 finished with value: 0.013659466626793355 and parameters: {'power_p': 1.4649598358988682}. Best is trial 14 with value: 0.03339700292044895.
# [I 2026-02-08 22:09:24,209] Trial 10 finished with value: 0.014564330102794712 and parameters: {'power_p': 1.3993346603295296}. Best is trial 14 with value: 0.03339700292044895.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.06817364692687988 seconds
#   warnings.warn(
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.07317972183227539 seconds
#   warnings.warn(
# [I 2026-02-08 22:09:25,171] Trial 12 finished with value: 0.03545887416040226 and parameters: {'power_p': 0.6059527831733574}. Best is trial 12 with value: 0.03545887416040226.
# [I 2026-02-08 22:09:27,611] Trial 7 finished with value: 0.024618413782296344 and parameters: {'power_p': 0.9472096353319671}. Best is trial 12 with value: 0.03545887416040226.
# [I 2026-02-08 22:09:28,245] Trial 4 finished with value: 0.04602532144791505 and parameters: {'power_p': 0.11935928797919947}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:30,826] Trial 11 finished with value: 0.043985511701078804 and parameters: {'power_p': 0.2639796690800467}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:33,275] Trial 15 finished with value: 0.016916022740935656 and parameters: {'power_p': 1.2640526255083295}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:33,401] Trial 5 finished with value: 0.030661896996302975 and parameters: {'power_p': 0.7667400210859072}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:35,285] Trial 3 finished with value: 0.034504087088580306 and parameters: {'power_p': 0.6595310712309009}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:35,287] Trial 2 finished with value: 0.04544874880690634 and parameters: {'power_p': 0.20606812026766957}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:37,116] Trial 6 finished with value: 0.039140759782996803 and parameters: {'power_p': 0.5164741731511554}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:39,345] Trial 0 finished with value: 0.0153090228924402 and parameters: {'power_p': 1.3585321624097235}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:43,732] Trial 9 finished with value: 0.01549009764315555 and parameters: {'power_p': 1.3476268973730072}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:09:49,790] Trial 13 finished with value: 0.03602562174686004 and parameters: {'power_p': 0.5989639428719674}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:12:44,986] Trial 19 finished with value: 0.01431438948523418 and parameters: {'power_p': 1.4177095469117476}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:12:45,713] Trial 17 finished with value: 0.04267741231932531 and parameters: {'power_p': 0.3352060933471399}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:12:46,468] Trial 16 finished with value: 0.025116030659280534 and parameters: {'power_p': 0.9284815240471984}. Best is trial 4 with value: 0.04602532144791505.
# [I 2026-02-08 22:12:46,504] Trial 18 finished with value: 0.01480090144017606 and parameters: {'power_p': 1.3850628742475917}. Best is trial 4 with value: 0.04602532144791505.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.05203700065612793 seconds
#   warnings.warn(
#   Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20    power                             20          0.046025
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.041837      0.050159           0.071557           0.103683
#
#    Final Train Time (s)                       Best Params
# 0              0.696797  {'power_p': 0.11935928797919947}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 22:15:22,622] A new study created in memory with name: no-name-8e8d494f-0a2f-48e4-ada5-9cfec0a64a5c
# Running optimization for KNN_k=20 with normalized...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:39: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.0470583438873291 seconds
#   warnings.warn(
# [I 2026-02-08 22:15:58,439] Trial 0 finished with value: 0.004930852450007813 and parameters: {}. Best is trial 0 with value: 0.004930852450007813.
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.050667762756347656 seconds
#   warnings.warn(
#   Algorithm    Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  KNN_k=20  normalized                              1          0.004931
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.005854      0.005162           0.009406           0.009787
#
#    Final Train Time (s) Best Params
# 0              0.686958          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-02-08 22:18:32,579] A new study created in memory with name: no-name-7fc33c48-8206-44ee-8cd3-745b7e0e0ae2
# Running optimization for KNN_k=20 with pmi...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:155: RuntimeWarning: divide by zero encountered in log
#   pmi = log((X.data * N) / denominator) # we could use np.power(X.data, p) instead of log for a softer effect
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/nearest_neighbours.py:233: RuntimeWarning: invalid value encountered in divide
#   X.data = X.data / sqrt(bincount(X.row, X.data**2))[X.row]
# /home/coder/.pyenv/versions/3.12.10/lib/python3.12/site-packages/implicit/utils.py:164: ParameterWarning: Method expects CSR input, and was passed coo_matrix instead. Converting to CSR took 0.04764437675476074 seconds
#   warnings.warn(

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="KNN_k=20", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="confidence", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="KNN_k=100", n_trials=20, output_dir=results_folder)

# %%
import glob

all_results = []
# Match any CSV in the result folder
for f in glob.glob(f"{results_folder}/*.csv"):
    all_results.append(pd.read_csv(f))

if all_results:
    experiment_results = pd.concat(all_results)
    experiment_results = experiment_results.sort_values("Test NDCG@20", ascending=False)
    experiment_results.to_csv(results_filename, index=False)
else:
    print("No results found.")

experiment_results
# Out:
#    Algorithm                       Strategy  Number of Optimization Trials  \
# 0  KNN_k=100                     power_lift                             20
# 0  KNN_k=100                           bm25                             20
# 0  KNN_k=100                            pmi                              1
# 0   KNN_k=20                            pmi                              1
# 0   KNN_k=20                           bm25                             20
# 0   KNN_k=20                     normalized                              1
# 0   KNN_k=20                     power_lift                             20
# 0  KNN_k=100                     normalized                              1
# 0   KNN_k=20            robust_user_centric                             20
# 0   KNN_k=20  robust_user_centric_weight_v2                             20
# 0   KNN_k=20                          power                             20
# 0   KNN_k=20                            log                              1
# 0   KNN_k=20                          tfidf                              1
# 0   KNN_k=20                   no_weighting                              1
# 0   KNN_k=20                     confidence                             20
# 0   KNN_k=20             sigmoid_propensity                             20
# 0  KNN_k=100  robust_user_centric_weight_v2                             20
# 0  KNN_k=100            robust_user_centric                             20
# 0  KNN_k=100                     confidence                             20
# 0  KNN_k=100                            log                              1
# 0  KNN_k=100                   no_weighting                              1
# 0  KNN_k=100                          tfidf                              1
# 0  KNN_k=100                          power                             20
# 0  KNN_k=100             sigmoid_propensity                             20
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.252733      0.297673      0.314228           0.307439
# 0          0.251625      0.293014      0.309850           0.304140
# 0          0.248729      0.294830      0.309707           0.311397
# 0          0.248759      0.284989      0.301401           0.304965
# 0          0.250745      0.287349      0.300805           0.303810
# 0          0.247134      0.283596      0.298867           0.301666
# 0          0.246454      0.283755      0.298380           0.296388
# 0          0.241655      0.279204      0.295025           0.287152
# 0          0.229796      0.270866      0.285502           0.289461
# 0          0.235247      0.269902      0.284681           0.288471
# 0          0.234443      0.268403      0.283895           0.287317
# 0          0.234245      0.268971      0.283892           0.288141
# 0          0.234610      0.267980      0.283676           0.286492
# 0          0.233736      0.267649      0.283587           0.287811
# 0          0.234762      0.268589      0.283542           0.288141
# 0          0.234007      0.269108      0.283410           0.288966
# 0          0.223226      0.257590      0.267439           0.264556
# 0          0.219065      0.255533      0.265849           0.263236
# 0          0.219214      0.253918      0.265348           0.262246
# 0          0.218951      0.253354      0.265168           0.261917
# 0          0.218642      0.254108      0.265007           0.263071
# 0          0.218701      0.254346      0.265000           0.262741
# 0          0.220329      0.254452      0.264948           0.263731
# 0          0.219166      0.252285      0.261865           0.260762
#
#    Test Precision@20  Final Train Time (s)  \
# 0           0.334320              0.028892
# 0           0.330886              0.028216
# 0           0.335505              0.028297
# 0           0.332662              0.019414
# 0           0.328754              0.019425
# 0           0.331715              0.019569
# 0           0.324609              0.020371
# 0           0.313240              0.027931
# 0           0.318806              0.019487
# 0           0.318333              0.020085
# 0           0.318096              0.019508
# 0           0.317622              0.020064
# 0           0.317622              0.023715
# 0           0.319398              0.021264
# 0           0.317504              0.019218
# 0           0.317622              0.019647
# 0           0.286949              0.047773
# 0           0.286594              0.031745
# 0           0.288252              0.029165
# 0           0.288134              0.028520
# 0           0.288015              0.031892
# 0           0.287305              0.042669
# 0           0.287778              0.047320
# 0           0.281975              0.029310
#
#                                          Best Params
# 0                          {'p': 1.1627526935071715}
# 0  {'bm25_k1': 338.7558204049336, 'bm25_b': 0.996...
# 0                                                 {}
# 0                                                 {}
# 0  {'bm25_k1': 843.4301155557006, 'bm25_b': 0.763...
# 0                                                 {}
# 0                           {'p': 0.874576236478479}
# 0                                                 {}
# 0               {'scale_factor': 2.6717703265899693}
# 0  {'lower_q': 13.009637863954161, 'upper_q': 57....
# 0                     {'power_p': 0.507006817593925}
# 0                                                 {}
# 0                                                 {}
# 0                                                 {}
# 0                  {'conf_alpha': 55.13187607675897}
# 0  {'p': 1.0751860580401422, 'beta': 0.0450192037...
# 0  {'lower_q': 11.265479498276028, 'upper_q': 56....
# 0                {'scale_factor': 4.261308278397727}
# 0                 {'conf_alpha': 17.627894967793516}
# 0                                                 {}
# 0                                                 {}
# 0                                                 {}
# 0                    {'power_p': 0.6384267877860578}
# 0  {'p': 0.2836829624877627, 'beta': 0.5821600768...
