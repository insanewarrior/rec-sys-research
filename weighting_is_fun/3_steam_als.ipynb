# %%
import numpy as np
import pandas as pd
import optuna
from scipy.sparse import csr_matrix
from weighting_strategies import (
    bm25_weight, tfidf_weight, normalized_weight,
    log_weight, log_idf_weight, power_weight,
    pmi_weight, robust_user_centric_weight, sigmoid_propensity_weight, power_lift_weight, robust_user_centric_weight_v2
)
from implicit.als import AlternatingLeastSquares
from implicit.evaluation import train_test_split, ranking_metrics_at_k

import cornac

# %%
import sys
import os

# Add the parent directory to sys.path to resolve imports from sibling directories
sys.path.append(os.path.abspath(".."))

from utils.sparse import transform_dataframe_to_sparse

# %%
steam_df = (
    pd.read_csv(
        "/home/coder/projects/rec-sys-research/data/steam/steam_recommendations.csv",
        usecols=['user_id', 'app_id', 'hours'],
    )
    .loc[:, ['user_id', 'app_id', 'hours']]
    .drop_duplicates()
    .dropna()
    .rename(columns={'app_id': 'item_id', 'hours': 'target'})
)
steam_df['user_id'].nunique(), steam_df['item_id'].nunique(), steam_df.shape[0]
# Out:
# (13781059, 37610, 41154773)

# %%
user_item_matrix, user_mapping, item_mapping = transform_dataframe_to_sparse(
    steam_df, row_field='user_id', col_field='item_id', data_field='target'
)


train_val_mat, test_mat = train_test_split(user_item_matrix, train_percentage=0.9, random_state=42)
train_mat, val_mat = train_test_split(train_val_mat, train_percentage=0.9, random_state=42)

print(f"Train Shape: {train_mat.shape}, Val Shape: {val_mat.shape}, Test Shape: {test_mat.shape}")
# Out:
# Train Shape: (13781059, 37610), Val Shape: (13781059, 37610), Test Shape: (13781059, 37610)

# %%
results_folder = "results/steam_als"
results_filename = "steam_als_results.csv"

import time

def run_hyperparameter_optimization(
    train_mat: csr_matrix,
    val_mat: csr_matrix,
    train_val_mat: csr_matrix,
    test_mat: csr_matrix,
    weighting_strategy: str,
    algorithm: str,
    n_trials: int = 20,
    output_dir: str = None,
) -> pd.DataFrame:
    results = []
    algorithms = {
        "ALS_factors=10": lambda: AlternatingLeastSquares(factors=10, regularization=10, random_state=42),
        "ALS_factors=100": lambda: AlternatingLeastSquares(factors=100, regularization=10, random_state=42),
    }
    strategies = [
        "no_weighting",
        "bm25",
        "tfidf",
        "log", 
        "log_idf",
        "power",
        "normalized",
        "pmi",
        "robust_user_centric",
        "robust_user_centric_weight_v2",
        "sigmoid_propensity",
        "power_lift"
    ]
    if weighting_strategy not in strategies:
        raise ValueError(f"Weighting strategy '{weighting_strategy}' is not recognized.")
    strategy = weighting_strategy

    if algorithm not in algorithms:
        raise ValueError(f"Algorithm '{algorithm}' is not recognized.")
    algo_name = algorithm
    AlgoFactory = algorithms[algorithm]

    print(f"Running optimization for {algo_name} with {strategy}...")

    def get_weighted_matrix(matrix, params):
        weighted = matrix.copy()
        if strategy == "bm25":
            weighted = bm25_weight(weighted, K1=params.get("bm25_k1"), B=params.get("bm25_b"))
        elif strategy == "log_idf":
            weighted = log_idf_weight(weighted, alpha=params.get("conf_alpha"))
        elif strategy == "power":
            weighted = power_weight(weighted, p=params.get("power_p"))
        elif strategy == "tfidf":
            weighted = tfidf_weight(weighted)
        elif strategy == "log":
            weighted = log_weight(weighted)
        elif strategy == "normalized":
            weighted = normalized_weight(weighted)
        elif strategy == "pmi":
            weighted = pmi_weight(weighted)
        elif strategy == "robust_user_centric":
            weighted = robust_user_centric_weight(weighted, scale_factor=params.get("scale_factor"))
        elif strategy == "sigmoid_propensity":
            weighted = sigmoid_propensity_weight(weighted, p=params.get("p"), beta=params.get("beta"))
        elif strategy == "power_lift":
            weighted = power_lift_weight(weighted, p=params.get("p"))
        elif strategy == "robust_user_centric_weight_v2":
            weighted = robust_user_centric_weight_v2(weighted, lower_q=params.get("lower_q"), upper_q=params.get("upper_q"))
        return weighted

    def objective(trial):
        params = {}
        # Suggest weighting strategy parameters
        if strategy == "bm25":
            params["bm25_k1"] = trial.suggest_float("bm25_k1", 0.1, 1000)
            params["bm25_b"] = trial.suggest_float("bm25_b", 0.0, 1.0)
        elif strategy == "log_idf":
            params["conf_alpha"] = trial.suggest_float("conf_alpha", 1.0, 150.0)
        elif strategy == "power":
            params["power_p"] = trial.suggest_float("power_p", 0.1, 1.5)
        elif strategy == "robust_user_centric":
            params["scale_factor"] = trial.suggest_float("scale_factor", 0.1, 10.0)
        elif strategy == "robust_user_centric_weight_v2":
            params["lower_q"] = trial.suggest_float("lower_q", 5.0, 45.0)
            params["upper_q"] = trial.suggest_float("upper_q", 55.0, 95.0)
        elif strategy == "sigmoid_propensity":
            params["p"] = trial.suggest_float("p", 0.1, 5.0)
            params["beta"] = trial.suggest_float("beta", 0.0, 1.0)
        elif strategy == "power_lift":
            params["p"] = trial.suggest_float("p", 0.1, 1.5)
        weighted_train = get_weighted_matrix(train_mat, params)
        
        # Train Model
        model = AlgoFactory()
        model.fit(weighted_train, show_progress=False)

        # Evaluate on Validation Set
        return ranking_metrics_at_k(model, train_mat, val_mat, K=20, show_progress=False)['ndcg']

    # Optimize only if strategy has parameters
    current_trials = n_trials if strategy in ["bm25", "log_idf", "power", "robust_user_centric", "robust_user_centric_weight_v2", "sigmoid_propensity", "power_lift"] else 1
    study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=current_trials, n_jobs=-1)

    # --- Final Retraining & Testing ---
    # Use best params to weight the full train_val matrix
    best_params = study.best_params
    weighted_train_val = get_weighted_matrix(train_val_mat, best_params)

    # Train Final Model
    final_model = AlgoFactory()
    
    start_time = time.time()
    final_model.fit(weighted_train_val, show_progress=False)
    end_time = time.time()
    
    # Evaluate on Test Set
    metrics_at_10 = ranking_metrics_at_k(final_model, train_val_mat, test_mat, K=10, show_progress=False)
    metrics_at_20 = ranking_metrics_at_k(final_model, train_val_mat, test_mat, K=20, show_progress=False)

    results.append({
        "Algorithm": algo_name,
        "Strategy": strategy,
        "Number of Optimization Trials": current_trials,
        "Best Val NDCG@20": study.best_value,
        "Test NDCG@10": metrics_at_10['ndcg'],
        "Test NDCG@20": metrics_at_20['ndcg'],
        "Test Precision@10": metrics_at_10['precision'],
        "Test Precision@20": metrics_at_20['precision'],
        "Final Train Time (s)": end_time - start_time,
        "Best Params": best_params
    })

    if output_dir:
        output_path = os.path.join(output_dir, f"{algo_name}_{strategy}_results.csv")
        pd.DataFrame(results).to_csv(output_path, index=False)
    return pd.DataFrame(results)

# %%
if not os.path.exists(results_folder):
    os.makedirs(results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 15:39:29,376] A new study created in memory with name: no-name-9192945e-1a52-4b46-a873-2c9b0fadc627
# Running optimization for ALS_factors=10 with no_weighting...
# [I 2026-01-30 15:39:51,926] Trial 0 finished with value: 0.03824927046174752 and parameters: {}. Best is trial 0 with value: 0.03824927046174752.
#         Algorithm      Strategy  Number of Optimization Trials  \
# 0  ALS_factors=10  no_weighting                              1
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.038249      0.030247      0.040574           0.056035
#
#    Test Precision@20  Final Train Time (s) Best Params
# 0           0.093654             14.714479          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="no_weighting", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 15:40:43,978] A new study created in memory with name: no-name-39af1d71-0195-4593-a483-f426cd09ca55
# Running optimization for ALS_factors=100 with no_weighting...
# [I 2026-01-30 15:41:43,351] Trial 0 finished with value: 0.04569430417941584 and parameters: {}. Best is trial 0 with value: 0.04569430417941584.
#          Algorithm      Strategy  Number of Optimization Trials  \
# 0  ALS_factors=100  no_weighting                              1
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.045694       0.03699      0.046245           0.065501
#
#    Test Precision@20  Final Train Time (s) Best Params
# 0            0.10069             52.191789          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 15:43:26,592] A new study created in memory with name: no-name-6669479c-9792-42ba-bfe9-a4713081bdfa
# Running optimization for ALS_factors=10 with bm25...
# [I 2026-01-30 15:44:52,802] Trial 0 finished with value: 0.041667996073901106 and parameters: {'bm25_k1': 496.0887822875346, 'bm25_b': 0.8611074987417343}. Best is trial 0 with value: 0.041667996073901106.
# [I 2026-01-30 15:44:52,880] Trial 2 finished with value: 0.03593618570460748 and parameters: {'bm25_k1': 776.1985693542257, 'bm25_b': 0.12324435392286648}. Best is trial 0 with value: 0.041667996073901106.
# [I 2026-01-30 15:44:52,906] Trial 3 finished with value: 0.04159174268959521 and parameters: {'bm25_k1': 581.4437568935733, 'bm25_b': 0.8274505606126228}. Best is trial 0 with value: 0.041667996073901106.
# [I 2026-01-30 15:44:52,922] Trial 1 finished with value: 0.042359809396355134 and parameters: {'bm25_k1': 179.37519632146103, 'bm25_b': 0.4967744784684035}. Best is trial 1 with value: 0.042359809396355134.
# [I 2026-01-30 15:46:18,516] Trial 4 finished with value: 0.03948946073692226 and parameters: {'bm25_k1': 623.2600267280279, 'bm25_b': 0.3566237615915543}. Best is trial 1 with value: 0.042359809396355134.
# [I 2026-01-30 15:46:18,556] Trial 5 finished with value: 0.04465595616593843 and parameters: {'bm25_k1': 94.31600134898208, 'bm25_b': 0.8244119356883416}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:46:18,652] Trial 7 finished with value: 0.04135640088176115 and parameters: {'bm25_k1': 498.95339121489457, 'bm25_b': 0.6213570894099343}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:46:18,710] Trial 6 finished with value: 0.03831861020339576 and parameters: {'bm25_k1': 354.29611472618245, 'bm25_b': 0.188597681108021}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:47:43,844] Trial 10 finished with value: 0.04145710932919958 and parameters: {'bm25_k1': 747.9777417302546, 'bm25_b': 0.783275341197472}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:47:43,863] Trial 9 finished with value: 0.04357694960321669 and parameters: {'bm25_k1': 139.16227112426697, 'bm25_b': 0.7076460031833773}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:47:43,863] Trial 8 finished with value: 0.03824936087175465 and parameters: {'bm25_k1': 387.98963538380303, 'bm25_b': 0.1970586294521569}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:47:43,914] Trial 11 finished with value: 0.03667908792615546 and parameters: {'bm25_k1': 244.69104971570187, 'bm25_b': 0.016718719344829602}. Best is trial 5 with value: 0.04465595616593843.
# [I 2026-01-30 15:49:09,365] Trial 13 finished with value: 0.048528860022631876 and parameters: {'bm25_k1': 25.88804696135449, 'bm25_b': 0.9982390919876568}. Best is trial 13 with value: 0.048528860022631876.
# [I 2026-01-30 15:49:09,405] Trial 14 finished with value: 0.04494719729842367 and parameters: {'bm25_k1': 83.8211638983884, 'bm25_b': 0.6636442964226285}. Best is trial 13 with value: 0.048528860022631876.
# [I 2026-01-30 15:49:09,505] Trial 12 finished with value: 0.04652868934622755 and parameters: {'bm25_k1': 47.03825608031309, 'bm25_b': 0.9878081408395829}. Best is trial 13 with value: 0.048528860022631876.
# [I 2026-01-30 15:49:09,538] Trial 15 finished with value: 0.05154912760173307 and parameters: {'bm25_k1': 8.987623449536017, 'bm25_b': 0.9546212775425689}. Best is trial 15 with value: 0.05154912760173307.
# [I 2026-01-30 15:50:34,633] Trial 19 finished with value: 0.04061920727769147 and parameters: {'bm25_k1': 930.9731404207428, 'bm25_b': 0.9914567660294376}. Best is trial 15 with value: 0.05154912760173307.
# [I 2026-01-30 15:50:34,666] Trial 16 finished with value: 0.05255430321421928 and parameters: {'bm25_k1': 4.207673145032096, 'bm25_b': 0.990098179081567}. Best is trial 16 with value: 0.05255430321421928.
# [I 2026-01-30 15:50:34,679] Trial 17 finished with value: 0.05218172739008587 and parameters: {'bm25_k1': 5.907461002431887, 'bm25_b': 0.989104961531663}. Best is trial 16 with value: 0.05255430321421928.
# [I 2026-01-30 15:50:34,716] Trial 18 finished with value: 0.04113474670801566 and parameters: {'bm25_k1': 976.5572965389142, 'bm25_b': 0.920873264110131}. Best is trial 16 with value: 0.05255430321421928.
#         Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=10     bm25                             20          0.052554
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.043694      0.056092            0.07879           0.124467
#
#    Final Train Time (s)                                        Best Params
# 0             14.996163  {'bm25_k1': 4.207673145032096, 'bm25_b': 0.990...

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="bm25", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 21:16:37,432] A new study created in memory with name: no-name-7cbda211-732f-4ffe-bdbb-90a83adb7c92
# Running optimization for ALS_factors=100 with bm25...
# [I 2026-01-30 21:17:36,196] Trial 0 finished with value: 0.0327591199298915 and parameters: {'bm25_k1': 477.9571640077998, 'bm25_b': 0.18198696882652543}. Best is trial 0 with value: 0.0327591199298915.
# [I 2026-01-30 21:18:35,264] Trial 1 finished with value: 0.03942975655628422 and parameters: {'bm25_k1': 567.0176501347212, 'bm25_b': 0.26623926019029454}. Best is trial 1 with value: 0.03942975655628422.
# [I 2026-01-30 21:19:34,189] Trial 2 finished with value: 0.038322482293737775 and parameters: {'bm25_k1': 536.6005444147751, 'bm25_b': 0.75595350858687}. Best is trial 1 with value: 0.03942975655628422.
# [I 2026-01-30 21:20:33,413] Trial 3 finished with value: 0.045099505196489885 and parameters: {'bm25_k1': 316.3234843884074, 'bm25_b': 0.42739603037885443}. Best is trial 3 with value: 0.045099505196489885.
# Warning NaN Detected in row 362269 of 13781059
# Warning NaN Detected in row 661967 of 13781059
# [I 2026-01-30 21:21:32,201] Trial 4 finished with value: 0.03961619130269501 and parameters: {'bm25_k1': 612.7450836616656, 'bm25_b': 0.7615843602069128}. Best is trial 3 with value: 0.045099505196489885.
# [I 2026-01-30 21:22:31,174] Trial 5 finished with value: 0.029386076019762453 and parameters: {'bm25_k1': 433.1723895419889, 'bm25_b': 0.5521661254618896}. Best is trial 3 with value: 0.045099505196489885.
# [I 2026-01-30 21:23:30,099] Trial 6 finished with value: 0.030573405538264656 and parameters: {'bm25_k1': 676.0849204939974, 'bm25_b': 0.16573605863253993}. Best is trial 3 with value: 0.045099505196489885.
# [I 2026-01-30 21:24:29,072] Trial 7 finished with value: 0.03363582000173788 and parameters: {'bm25_k1': 740.2608930112854, 'bm25_b': 0.26168582890531067}. Best is trial 3 with value: 0.045099505196489885.
# [I 2026-01-30 21:25:27,744] Trial 8 finished with value: 0.03547211659903023 and parameters: {'bm25_k1': 310.38121213278066, 'bm25_b': 0.42784055942860133}. Best is trial 3 with value: 0.045099505196489885.
# [I 2026-01-30 21:26:26,410] Trial 9 finished with value: 0.03926258653124694 and parameters: {'bm25_k1': 456.62865093029325, 'bm25_b': 0.6849210552064564}. Best is trial 3 with value: 0.045099505196489885.
# [I 2026-01-30 21:27:25,028] Trial 10 finished with value: 0.04829035604265891 and parameters: {'bm25_k1': 37.60960125179889, 'bm25_b': 0.0027036313227741804}. Best is trial 10 with value: 0.04829035604265891.
# [I 2026-01-30 21:28:23,656] Trial 11 finished with value: 0.040974984290807905 and parameters: {'bm25_k1': 65.18627789546179, 'bm25_b': 0.009075924703440652}. Best is trial 10 with value: 0.04829035604265891.
# [I 2026-01-30 21:29:22,521] Trial 12 finished with value: 0.06076606499238145 and parameters: {'bm25_k1': 3.464734272938415, 'bm25_b': 0.9732576342003244}. Best is trial 12 with value: 0.06076606499238145.
# [I 2026-01-30 21:30:21,250] Trial 13 finished with value: 0.054115026544225245 and parameters: {'bm25_k1': 19.73224343187411, 'bm25_b': 0.9595700152120015}. Best is trial 12 with value: 0.06076606499238145.
# Warning NaN Detected in row 119547 of 13781059
# [I 2026-01-30 21:31:20,016] Trial 14 finished with value: 0.04361176293907011 and parameters: {'bm25_k1': 988.9956532161812, 'bm25_b': 0.9531234442922418}. Best is trial 12 with value: 0.06076606499238145.
# [I 2026-01-30 21:32:18,686] Trial 15 finished with value: 0.03841868132754067 and parameters: {'bm25_k1': 187.26924137455597, 'bm25_b': 0.9963828016352553}. Best is trial 12 with value: 0.06076606499238145.
# [I 2026-01-30 21:33:17,596] Trial 16 finished with value: 0.04429568203576435 and parameters: {'bm25_k1': 158.38206393097866, 'bm25_b': 0.8842940923610091}. Best is trial 12 with value: 0.06076606499238145.
# [I 2026-01-30 21:34:16,287] Trial 17 finished with value: 0.055206594586966126 and parameters: {'bm25_k1': 21.217090299597036, 'bm25_b': 0.8409407371182303}. Best is trial 12 with value: 0.06076606499238145.
# Warning NaN Detected in row 316 of 37610
# [I 2026-01-30 21:35:15,033] Trial 18 finished with value: 0.0401675617763036 and parameters: {'bm25_k1': 220.43419241967703, 'bm25_b': 0.8011068871958604}. Best is trial 12 with value: 0.06076606499238145.
# [I 2026-01-30 21:36:13,770] Trial 19 finished with value: 0.040799266430780086 and parameters: {'bm25_k1': 119.48846670939363, 'bm25_b': 0.6370385681710332}. Best is trial 12 with value: 0.06076606499238145.
#          Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=100     bm25                             20          0.060766
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.054619      0.065655           0.093985           0.136512
#
#    Final Train Time (s)                                        Best Params
# 0             49.606564  {'bm25_k1': 3.464734272938415, 'bm25_b': 0.973...

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 15:55:22,157] A new study created in memory with name: no-name-dcbd23b8-4538-4e65-ab84-915b4f5d200c
# Running optimization for ALS_factors=10 with tfidf...
# [I 2026-01-30 15:55:45,821] Trial 0 finished with value: 0.04796588820864551 and parameters: {}. Best is trial 0 with value: 0.04796588820864551.
#         Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=10    tfidf                              1          0.047966
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.039133      0.050901           0.071277           0.114584
#
#    Final Train Time (s) Best Params
# 0             14.837221          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="tfidf", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 15:56:54,790] A new study created in memory with name: no-name-f0d47129-f80a-4df6-90f8-131ec553ce09
# Running optimization for ALS_factors=100 with tfidf...
# [I 2026-01-30 15:57:55,770] Trial 0 finished with value: 0.054623041268643 and parameters: {}. Best is trial 0 with value: 0.054623041268643.
#          Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=100    tfidf                              1          0.054623
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.050008       0.06076           0.086595           0.128038
#
#    Final Train Time (s) Best Params
# 0              52.58611          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 15:59:39,525] A new study created in memory with name: no-name-6f916aca-d9f0-46cc-939d-ad07c81bdfdd
# Running optimization for ALS_factors=10 with log...
# [I 2026-01-30 16:00:03,123] Trial 0 finished with value: 0.045315447507524156 and parameters: {}. Best is trial 0 with value: 0.045315447507524156.
#         Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=10      log                              1          0.045315
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.037112      0.048103           0.065989           0.105739
#
#    Final Train Time (s) Best Params
# 0             15.070171          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 16:00:56,500] A new study created in memory with name: no-name-045bbfdb-6b6e-4eab-b814-d3705f7abbf9
# Running optimization for ALS_factors=100 with log...
# [I 2026-01-30 16:01:58,169] Trial 0 finished with value: 0.04906792757327218 and parameters: {}. Best is trial 0 with value: 0.04906792757327218.
#          Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=100      log                              1          0.049068
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.032056       0.04019           0.055392           0.086068
#
#    Final Train Time (s) Best Params
# 0             53.062292          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log_idf", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 16:03:42,284] A new study created in memory with name: no-name-2cb791f2-62ca-4289-a6ca-53af2b44160a
# Running optimization for ALS_factors=10 with log_idf...
# [I 2026-01-30 16:05:07,577] Trial 0 finished with value: 0.023363435766378015 and parameters: {'conf_alpha': 95.27044339546991}. Best is trial 0 with value: 0.023363435766378015.
# [I 2026-01-30 16:05:07,735] Trial 1 finished with value: 0.022855189065980996 and parameters: {'conf_alpha': 102.55136155499844}. Best is trial 0 with value: 0.023363435766378015.
# [I 2026-01-30 16:05:07,757] Trial 3 finished with value: 0.022918585068671907 and parameters: {'conf_alpha': 101.70064672395974}. Best is trial 0 with value: 0.023363435766378015.
# [I 2026-01-30 16:05:07,794] Trial 2 finished with value: 0.027551004638078323 and parameters: {'conf_alpha': 54.91068308786028}. Best is trial 2 with value: 0.027551004638078323.
# [I 2026-01-30 16:06:32,057] Trial 4 finished with value: 0.021824907324303994 and parameters: {'conf_alpha': 120.08890011270547}. Best is trial 2 with value: 0.027551004638078323.
# [I 2026-01-30 16:06:32,085] Trial 6 finished with value: 0.03353680666146343 and parameters: {'conf_alpha': 28.09610311174237}. Best is trial 6 with value: 0.03353680666146343.
# [I 2026-01-30 16:06:32,113] Trial 7 finished with value: 0.04701638543334983 and parameters: {'conf_alpha': 5.761335206589632}. Best is trial 7 with value: 0.04701638543334983.
# [I 2026-01-30 16:06:32,142] Trial 5 finished with value: 0.030051606454904824 and parameters: {'conf_alpha': 41.27454389876602}. Best is trial 7 with value: 0.04701638543334983.
# [I 2026-01-30 16:07:56,542] Trial 8 finished with value: 0.020795274430038188 and parameters: {'conf_alpha': 142.27098457311}. Best is trial 7 with value: 0.04701638543334983.
# [I 2026-01-30 16:07:56,579] Trial 10 finished with value: 0.020811365165696916 and parameters: {'conf_alpha': 141.77136619995218}. Best is trial 7 with value: 0.04701638543334983.
# [I 2026-01-30 16:07:56,593] Trial 9 finished with value: 0.022690874006536164 and parameters: {'conf_alpha': 104.79909213962148}. Best is trial 7 with value: 0.04701638543334983.
# [I 2026-01-30 16:07:56,650] Trial 11 finished with value: 0.02600509783188808 and parameters: {'conf_alpha': 66.52170247084456}. Best is trial 7 with value: 0.04701638543334983.
# [I 2026-01-30 16:09:21,213] Trial 13 finished with value: 0.050363566755280705 and parameters: {'conf_alpha': 2.8795624777716218}. Best is trial 13 with value: 0.050363566755280705.
# [I 2026-01-30 16:09:21,226] Trial 12 finished with value: 0.03604301683900133 and parameters: {'conf_alpha': 21.516465271036814}. Best is trial 13 with value: 0.050363566755280705.
# [I 2026-01-30 16:09:21,331] Trial 14 finished with value: 0.050574063244034705 and parameters: {'conf_alpha': 2.7052621584068817}. Best is trial 14 with value: 0.050574063244034705.
# [I 2026-01-30 16:09:21,351] Trial 15 finished with value: 0.047030543369097594 and parameters: {'conf_alpha': 5.748920007074556}. Best is trial 14 with value: 0.050574063244034705.
# [I 2026-01-30 16:10:45,930] Trial 17 finished with value: 0.044330182594356 and parameters: {'conf_alpha': 8.42701973677091}. Best is trial 14 with value: 0.050574063244034705.
# [I 2026-01-30 16:10:45,946] Trial 16 finished with value: 0.043879091786447263 and parameters: {'conf_alpha': 8.94530297000958}. Best is trial 14 with value: 0.050574063244034705.
# [I 2026-01-30 16:10:45,968] Trial 18 finished with value: 0.047325764405688635 and parameters: {'conf_alpha': 5.4807498804458}. Best is trial 14 with value: 0.050574063244034705.
# [I 2026-01-30 16:10:45,984] Trial 19 finished with value: 0.033799702090204393 and parameters: {'conf_alpha': 27.329794593415915}. Best is trial 14 with value: 0.050574063244034705.
#         Algorithm    Strategy  Number of Optimization Trials  \
# 0  ALS_factors=10  log_idf                             20
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.050574      0.041375      0.053683           0.075378
#
#    Test Precision@20  Final Train Time (s)                         Best Params
# 0           0.120844             14.992001  {'conf_alpha': 2.7052621584068817}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="log_idf", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 21:37:52,379] A new study created in memory with name: no-name-e48d3814-c211-4b88-aae7-12a5f7cd8449
# Running optimization for ALS_factors=100 with log_idf...
# [I 2026-01-30 21:38:50,638] Trial 0 finished with value: 0.016766720583370757 and parameters: {'conf_alpha': 99.35065085484638}. Best is trial 0 with value: 0.016766720583370757.
# [I 2026-01-30 21:39:48,910] Trial 1 finished with value: 0.01900090933243443 and parameters: {'conf_alpha': 73.48284136026886}. Best is trial 1 with value: 0.01900090933243443.
# [I 2026-01-30 21:40:47,159] Trial 2 finished with value: 0.018496323200194172 and parameters: {'conf_alpha': 92.96930500929183}. Best is trial 1 with value: 0.01900090933243443.
# Warning NaN Detected in row 1297287 of 13781059
# [I 2026-01-30 21:41:45,380] Trial 3 finished with value: 0.016443948597773726 and parameters: {'conf_alpha': 111.78669665395817}. Best is trial 1 with value: 0.01900090933243443.
# [I 2026-01-30 21:42:43,579] Trial 4 finished with value: 0.018524874804148297 and parameters: {'conf_alpha': 101.90033796511676}. Best is trial 1 with value: 0.01900090933243443.
# Warning NaN Detected in row 22 of 37610
# [I 2026-01-30 21:43:41,772] Trial 5 finished with value: 0.0157230886968202 and parameters: {'conf_alpha': 135.05147689903697}. Best is trial 1 with value: 0.01900090933243443.
# Warning NaN Detected in row 316 of 37610
# [I 2026-01-30 21:44:39,961] Trial 6 finished with value: 0.020367110251144183 and parameters: {'conf_alpha': 51.63449752110568}. Best is trial 6 with value: 0.020367110251144183.
# [I 2026-01-30 21:45:38,171] Trial 7 finished with value: 0.0212714451214372 and parameters: {'conf_alpha': 65.75375205918432}. Best is trial 7 with value: 0.0212714451214372.
# [I 2026-01-30 21:46:36,405] Trial 8 finished with value: 0.022232125582345216 and parameters: {'conf_alpha': 19.87771347920511}. Best is trial 8 with value: 0.022232125582345216.
# Warning NaN Detected in row 530136 of 13781059
# [I 2026-01-30 21:47:34,636] Trial 9 finished with value: 0.016850826498160266 and parameters: {'conf_alpha': 124.4644735516791}. Best is trial 8 with value: 0.022232125582345216.
# [I 2026-01-30 21:48:32,838] Trial 10 finished with value: 0.05919544242066093 and parameters: {'conf_alpha': 1.4332196930253005}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:49:31,099] Trial 11 finished with value: 0.04791436597588239 and parameters: {'conf_alpha': 3.162695707574189}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:50:29,321] Trial 12 finished with value: 0.04197264533739763 and parameters: {'conf_alpha': 4.961306458612306}. Best is trial 10 with value: 0.05919544242066093.
# Warning NaN Detected in row 88693 of 13781059
# [I 2026-01-30 21:51:27,624] Trial 13 finished with value: 0.02637229852981141 and parameters: {'conf_alpha': 28.131238314086744}. Best is trial 10 with value: 0.05919544242066093.
# Warning NaN Detected in row 316 of 37610
# Warning NaN Detected in row 316 of 37610
# [I 2026-01-30 21:52:25,913] Trial 14 finished with value: 0.021665361025225285 and parameters: {'conf_alpha': 39.473439515081196}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:53:24,135] Trial 15 finished with value: 0.057445479228438914 and parameters: {'conf_alpha': 1.0450116201501345}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:54:22,385] Trial 16 finished with value: 0.03391424814313465 and parameters: {'conf_alpha': 20.932770932874934}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:55:20,641] Trial 17 finished with value: 0.019889644822474777 and parameters: {'conf_alpha': 46.37743836932448}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:56:18,805] Trial 18 finished with value: 0.045570813688514795 and parameters: {'conf_alpha': 2.8117340738288923}. Best is trial 10 with value: 0.05919544242066093.
# [I 2026-01-30 21:57:16,997] Trial 19 finished with value: 0.01926314312603989 and parameters: {'conf_alpha': 60.12820316489069}. Best is trial 10 with value: 0.05919544242066093.
#          Algorithm    Strategy  Number of Optimization Trials  \
# 0  ALS_factors=100  log_idf                             20
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.059195      0.050841      0.061604           0.087671
#
#    Test Precision@20  Final Train Time (s)                         Best Params
# 0           0.129272             49.558887  {'conf_alpha': 1.4332196930253005}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 16:14:47,061] A new study created in memory with name: no-name-7e25088b-6809-406d-b9b3-44087f723a52
# Running optimization for ALS_factors=10 with power...
# [I 2026-01-30 16:16:10,416] Trial 1 finished with value: 0.04442033076963947 and parameters: {'power_p': 0.7318014462482192}. Best is trial 1 with value: 0.04442033076963947.
# [I 2026-01-30 16:16:10,477] Trial 3 finished with value: 0.04349645105292983 and parameters: {'power_p': 0.1868452846876548}. Best is trial 1 with value: 0.04442033076963947.
# [I 2026-01-30 16:16:10,515] Trial 0 finished with value: 0.037662666073793885 and parameters: {'power_p': 1.0177939413539965}. Best is trial 1 with value: 0.04442033076963947.
# [I 2026-01-30 16:16:10,581] Trial 2 finished with value: 0.04518755172504818 and parameters: {'power_p': 0.6026050749276384}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:17:33,812] Trial 5 finished with value: 0.04353197917107197 and parameters: {'power_p': 0.19083780674618975}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:17:33,815] Trial 4 finished with value: 0.04440154359264878 and parameters: {'power_p': 0.30618095861684735}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:17:33,826] Trial 7 finished with value: 0.04417445881662956 and parameters: {'power_p': 0.2653958285861143}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:17:33,845] Trial 6 finished with value: 0.04471439830728506 and parameters: {'power_p': 0.7007018201107894}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:18:57,605] Trial 9 finished with value: 0.021903033799061934 and parameters: {'power_p': 1.4342581927960807}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:18:57,639] Trial 11 finished with value: 0.04448822899697041 and parameters: {'power_p': 0.7244824849284006}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:18:57,676] Trial 8 finished with value: 0.04145204000787373 and parameters: {'power_p': 0.889434274697914}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:18:57,693] Trial 10 finished with value: 0.020264526072763023 and parameters: {'power_p': 1.483524456446136}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:20:21,184] Trial 12 finished with value: 0.040946150235647225 and parameters: {'power_p': 0.9095171526093597}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:20:21,422] Trial 13 finished with value: 0.03588474345833911 and parameters: {'power_p': 1.068120910767226}. Best is trial 2 with value: 0.04518755172504818.
# [I 2026-01-30 16:20:21,456] Trial 14 finished with value: 0.04518813904089546 and parameters: {'power_p': 0.5202310101513943}. Best is trial 14 with value: 0.04518813904089546.
# [I 2026-01-30 16:20:21,472] Trial 15 finished with value: 0.04525236307560718 and parameters: {'power_p': 0.5524939769068045}. Best is trial 15 with value: 0.04525236307560718.
# [I 2026-01-30 16:21:44,811] Trial 18 finished with value: 0.04508117621695904 and parameters: {'power_p': 0.47468923072445895}. Best is trial 15 with value: 0.04525236307560718.
# [I 2026-01-30 16:21:44,882] Trial 16 finished with value: 0.045221988962538436 and parameters: {'power_p': 0.5722181646255075}. Best is trial 15 with value: 0.04525236307560718.
# [I 2026-01-30 16:21:44,895] Trial 19 finished with value: 0.04499578070192176 and parameters: {'power_p': 0.4501015256143499}. Best is trial 15 with value: 0.04525236307560718.
# [I 2026-01-30 16:21:44,944] Trial 17 finished with value: 0.04519275031889904 and parameters: {'power_p': 0.5209896446629827}. Best is trial 15 with value: 0.04525236307560718.
#         Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=10    power                             20          0.045252
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.037303      0.048092           0.065969           0.104961
#
#    Final Train Time (s)                      Best Params
# 0             14.987071  {'power_p': 0.5524939769068045}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 21:58:54,649] A new study created in memory with name: no-name-b7e25bd0-401f-4579-b19c-ba42155bbff9
# Running optimization for ALS_factors=100 with power...
# [I 2026-01-30 21:59:52,587] Trial 0 finished with value: 0.04468890958144243 and parameters: {'power_p': 0.9409933106816465}. Best is trial 0 with value: 0.04468890958144243.
# [I 2026-01-30 22:00:50,600] Trial 1 finished with value: 0.043489281837584735 and parameters: {'power_p': 1.0563110238961442}. Best is trial 0 with value: 0.04468890958144243.
# [I 2026-01-30 22:01:48,536] Trial 2 finished with value: 0.04815851319864208 and parameters: {'power_p': 0.872547395830662}. Best is trial 2 with value: 0.04815851319864208.
# [I 2026-01-30 22:02:46,411] Trial 3 finished with value: 0.049156812594798864 and parameters: {'power_p': 0.924359758731717}. Best is trial 3 with value: 0.049156812594798864.
# [I 2026-01-30 22:03:44,291] Trial 4 finished with value: 0.052567242496524225 and parameters: {'power_p': 0.5725744009704944}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:04:42,136] Trial 5 finished with value: 0.046628012494856534 and parameters: {'power_p': 0.27911911087055385}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:05:40,090] Trial 6 finished with value: 0.04867065661009226 and parameters: {'power_p': 0.34573124076364903}. Best is trial 4 with value: 0.052567242496524225.
# Warning NaN Detected in row 1079882 of 13781059
# [I 2026-01-30 22:06:38,036] Trial 7 finished with value: 0.029435264261666306 and parameters: {'power_p': 1.4293775013976697}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:07:35,878] Trial 8 finished with value: 0.05236744203318813 and parameters: {'power_p': 0.6046019664217197}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:08:33,739] Trial 9 finished with value: 0.04106964890919388 and parameters: {'power_p': 1.0453155825750875}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:09:31,612] Trial 10 finished with value: 0.05214023497975154 and parameters: {'power_p': 0.5838924250753191}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:10:29,545] Trial 11 finished with value: 0.05121208303065599 and parameters: {'power_p': 0.5493180976828171}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:11:27,464] Trial 12 finished with value: 0.03910884682027885 and parameters: {'power_p': 0.10263437576034218}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:12:25,350] Trial 13 finished with value: 0.05181297547777363 and parameters: {'power_p': 0.6553628141649795}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:13:23,253] Trial 14 finished with value: 0.05050532610770835 and parameters: {'power_p': 0.41766727713361}. Best is trial 4 with value: 0.052567242496524225.
# [I 2026-01-30 22:14:21,156] Trial 15 finished with value: 0.05320497828619826 and parameters: {'power_p': 0.7138199050943289}. Best is trial 15 with value: 0.05320497828619826.
# [I 2026-01-30 22:15:19,131] Trial 16 finished with value: 0.03138957164869335 and parameters: {'power_p': 1.2458128155045385}. Best is trial 15 with value: 0.05320497828619826.
# [I 2026-01-30 22:16:17,075] Trial 17 finished with value: 0.050098147550483044 and parameters: {'power_p': 0.7662139269541606}. Best is trial 15 with value: 0.05320497828619826.
# [I 2026-01-30 22:17:14,981] Trial 18 finished with value: 0.053048609726338014 and parameters: {'power_p': 0.7361727882452659}. Best is trial 15 with value: 0.05320497828619826.
# [I 2026-01-30 22:18:12,888] Trial 19 finished with value: 0.0519295642827619 and parameters: {'power_p': 0.7574023388183251}. Best is trial 15 with value: 0.05320497828619826.
#          Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=100    power                             20          0.053205
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.046338      0.056201           0.080263           0.117913
#
#    Final Train Time (s)                      Best Params
# 0             49.611519  {'power_p': 0.7138199050943289}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="normalized", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 16:26:36,670] A new study created in memory with name: no-name-63dbe312-e6d8-49eb-8263-2c6dd0c63d1e
# Running optimization for ALS_factors=10 with pmi...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:155: RuntimeWarning: divide by zero encountered in log
#   pmi = log((X.data * N) / denominator) # we could use np.power(X.data, p) instead of log for a softer effect
# [I 2026-01-30 16:27:01,290] Trial 0 finished with value: 0.04769436467070988 and parameters: {}. Best is trial 0 with value: 0.04769436467070988.
#         Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=10      pmi                              1          0.047694
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.039062      0.050912           0.071159           0.114757
#
#    Final Train Time (s) Best Params
# 0             14.978303          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="pmi", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 22:22:26,451] A new study created in memory with name: no-name-eb87e8f4-8608-4d4b-aef8-b8cb04323497
# Running optimization for ALS_factors=100 with pmi...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:155: RuntimeWarning: divide by zero encountered in log
#   pmi = log((X.data * N) / denominator) # we could use np.power(X.data, p) instead of log for a softer effect
# [I 2026-01-30 22:23:25,515] Trial 0 finished with value: 0.05844964324480874 and parameters: {}. Best is trial 0 with value: 0.05844964324480874.
#          Algorithm Strategy  Number of Optimization Trials  Best Val NDCG@20  \
# 0  ALS_factors=100      pmi                              1           0.05845
#
#    Test NDCG@10  Test NDCG@20  Test Precision@10  Test Precision@20  \
# 0      0.052168      0.062659           0.089908           0.130247
#
#    Final Train Time (s) Best Params
# 0             49.521188          {}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 16:27:55,757] A new study created in memory with name: no-name-bba63f14-62ca-467b-824f-07e657d4ee4b
# Running optimization for ALS_factors=10 with robust_user_centric...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:294: RuntimeWarning: overflow encountered in exp
#   weights = 1 / (1 + np.exp(-z_scores))
# [I 2026-01-30 16:29:28,333] Trial 1 finished with value: 0.04377872886579006 and parameters: {'scale_factor': 3.232190798581721}. Best is trial 1 with value: 0.04377872886579006.
# [I 2026-01-30 16:29:28,420] Trial 0 finished with value: 0.03284957446168678 and parameters: {'scale_factor': 1.286277092846803}. Best is trial 1 with value: 0.04377872886579006.
# [I 2026-01-30 16:29:28,466] Trial 2 finished with value: 0.0310802257942641 and parameters: {'scale_factor': 1.0204997309814483}. Best is trial 1 with value: 0.04377872886579006.
# [I 2026-01-30 16:29:28,590] Trial 3 finished with value: 0.039298627980381036 and parameters: {'scale_factor': 1.8894673789759455}. Best is trial 1 with value: 0.04377872886579006.
# [I 2026-01-30 16:31:00,894] Trial 4 finished with value: 0.03282415243492771 and parameters: {'scale_factor': 1.2213033181763802}. Best is trial 1 with value: 0.04377872886579006.
# [I 2026-01-30 16:31:00,973] Trial 5 finished with value: 0.04694584668895279 and parameters: {'scale_factor': 7.546073817656403}. Best is trial 5 with value: 0.04694584668895279.
# [I 2026-01-30 16:31:01,021] Trial 6 finished with value: 0.029145295622277557 and parameters: {'scale_factor': 0.6597932816914646}. Best is trial 5 with value: 0.04694584668895279.
# [I 2026-01-30 16:31:01,202] Trial 7 finished with value: 0.03040721627881934 and parameters: {'scale_factor': 0.9063544929104702}. Best is trial 5 with value: 0.04694584668895279.
# [I 2026-01-30 16:32:33,473] Trial 9 finished with value: 0.044795848804659 and parameters: {'scale_factor': 4.23155290314067}. Best is trial 5 with value: 0.04694584668895279.
# [I 2026-01-30 16:32:33,506] Trial 8 finished with value: 0.047793458049861515 and parameters: {'scale_factor': 9.813478493358517}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:32:33,569] Trial 10 finished with value: 0.044685358102558276 and parameters: {'scale_factor': 4.087434252710918}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:32:33,639] Trial 11 finished with value: 0.03767364820462927 and parameters: {'scale_factor': 1.6491857224293187}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:34:05,841] Trial 13 finished with value: 0.0477639550687197 and parameters: {'scale_factor': 9.679748240148143}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:34:05,886] Trial 14 finished with value: 0.04765564747379965 and parameters: {'scale_factor': 9.299489122163115}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:34:05,924] Trial 12 finished with value: 0.045988566529333995 and parameters: {'scale_factor': 5.918933858614745}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:34:06,179] Trial 15 finished with value: 0.0476733754406973 and parameters: {'scale_factor': 9.374420991963454}. Best is trial 8 with value: 0.047793458049861515.
# [I 2026-01-30 16:35:38,592] Trial 18 finished with value: 0.047809668780869834 and parameters: {'scale_factor': 9.856619980539566}. Best is trial 18 with value: 0.047809668780869834.
# [I 2026-01-30 16:35:38,635] Trial 17 finished with value: 0.04762246871614737 and parameters: {'scale_factor': 9.175057950197976}. Best is trial 18 with value: 0.047809668780869834.
# [I 2026-01-30 16:35:38,713] Trial 16 finished with value: 0.0478194045549947 and parameters: {'scale_factor': 9.879081226043372}. Best is trial 16 with value: 0.0478194045549947.
# [I 2026-01-30 16:35:38,905] Trial 19 finished with value: 0.04711347997264156 and parameters: {'scale_factor': 7.8775930111494405}. Best is trial 16 with value: 0.0478194045549947.
#         Algorithm             Strategy  Number of Optimization Trials  \
# 0  ALS_factors=10  robust_user_centric                             20
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.047819      0.039118      0.050901           0.070622
#
#    Test Precision@20  Final Train Time (s)  \
# 0           0.113674             14.950878
#
#                            Best Params
# 0  {'scale_factor': 9.879081226043372}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 22:25:03,957] A new study created in memory with name: no-name-9285cb2d-f9ef-4460-995c-4bda86ec0186
# Running optimization for ALS_factors=100 with robust_user_centric...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:294: RuntimeWarning: overflow encountered in exp
#   weights = 1 / (1 + np.exp(-z_scores))
# [I 2026-01-30 22:26:07,901] Trial 0 finished with value: 0.05257084127908052 and parameters: {'scale_factor': 9.14084552337091}. Best is trial 0 with value: 0.05257084127908052.
# [I 2026-01-30 22:27:11,877] Trial 1 finished with value: 0.04445954292187609 and parameters: {'scale_factor': 4.096684427636314}. Best is trial 0 with value: 0.05257084127908052.
# [I 2026-01-30 22:28:15,722] Trial 2 finished with value: 0.03752616591850959 and parameters: {'scale_factor': 2.2460404400693648}. Best is trial 0 with value: 0.05257084127908052.
# [I 2026-01-30 22:29:19,528] Trial 3 finished with value: 0.05296912550901698 and parameters: {'scale_factor': 9.458622911916773}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:30:24,245] Trial 4 finished with value: 0.050601679887730976 and parameters: {'scale_factor': 7.1921305042484205}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:31:28,429] Trial 5 finished with value: 0.03486108340377295 and parameters: {'scale_factor': 1.0373504979370491}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:32:32,498] Trial 6 finished with value: 0.04879215261447749 and parameters: {'scale_factor': 5.70328689916783}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:33:36,524] Trial 7 finished with value: 0.03870709550579428 and parameters: {'scale_factor': 2.520721930358438}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:34:40,506] Trial 8 finished with value: 0.047041119900959806 and parameters: {'scale_factor': 5.044752288262098}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:35:44,552] Trial 9 finished with value: 0.051755910531561936 and parameters: {'scale_factor': 8.056496858936747}. Best is trial 3 with value: 0.05296912550901698.
# [I 2026-01-30 22:36:48,758] Trial 10 finished with value: 0.05299065403773524 and parameters: {'scale_factor': 9.581609933689803}. Best is trial 10 with value: 0.05299065403773524.
# [I 2026-01-30 22:37:52,713] Trial 11 finished with value: 0.0533036704768556 and parameters: {'scale_factor': 9.976651717233675}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:38:56,625] Trial 12 finished with value: 0.053025298253234696 and parameters: {'scale_factor': 9.704867293339063}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:40:00,455] Trial 13 finished with value: 0.050703809633028146 and parameters: {'scale_factor': 7.257551730787288}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:41:04,319] Trial 14 finished with value: 0.052113716205122465 and parameters: {'scale_factor': 8.329983193369555}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:42:08,095] Trial 15 finished with value: 0.05312936803390752 and parameters: {'scale_factor': 9.970997844855768}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:43:11,882] Trial 16 finished with value: 0.049875107384195407 and parameters: {'scale_factor': 6.444708440265742}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:44:15,686] Trial 17 finished with value: 0.05179873304363716 and parameters: {'scale_factor': 8.085656099036985}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:45:19,485] Trial 18 finished with value: 0.04510484896471476 and parameters: {'scale_factor': 4.163080469381498}. Best is trial 11 with value: 0.0533036704768556.
# [I 2026-01-30 22:46:23,355] Trial 19 finished with value: 0.05294152923319029 and parameters: {'scale_factor': 9.976983234534682}. Best is trial 11 with value: 0.0533036704768556.
#          Algorithm             Strategy  Number of Optimization Trials  \
# 0  ALS_factors=100  robust_user_centric                             20
#
#    Best Val NDCG@20  Test NDCG@10  Test NDCG@20  Test Precision@10  \
# 0          0.053304      0.046057      0.055862           0.079321
#
#    Test Precision@20  Final Train Time (s)  \
# 0           0.116859             49.531484
#
#                            Best Params
# 0  {'scale_factor': 9.976651717233675}

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 16:36:38,686] A new study created in memory with name: no-name-bf2e5b4b-8333-45f2-b8af-578d5c547780
# Running optimization for ALS_factors=10 with robust_user_centric_weight_v2...
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:364: RuntimeWarning: overflow encountered in exp
#   weights = 1 / (1 + np.exp(-z_scores))
# [I 2026-01-30 16:38:11,087] Trial 2 finished with value: 0.030410633896958618 and parameters: {'lower_q': 35.20098531382598, 'upper_q': 92.67833744045595}. Best is trial 2 with value: 0.030410633896958618.
# [I 2026-01-30 16:38:11,169] Trial 0 finished with value: 0.03090667119894906 and parameters: {'lower_q': 12.126485682155028, 'upper_q': 74.97336299936772}. Best is trial 0 with value: 0.03090667119894906.
# [I 2026-01-30 16:38:11,185] Trial 3 finished with value: 0.03030168970247301 and parameters: {'lower_q': 6.6848124770025485, 'upper_q': 91.36121229778456}. Best is trial 0 with value: 0.03090667119894906.
# [I 2026-01-30 16:38:11,211] Trial 1 finished with value: 0.03094962748121891 and parameters: {'lower_q': 9.812413134433262, 'upper_q': 70.94401974514017}. Best is trial 1 with value: 0.03094962748121891.
# [I 2026-01-30 16:39:43,126] Trial 4 finished with value: 0.030783707408189028 and parameters: {'lower_q': 13.736257655028332, 'upper_q': 80.62711013607023}. Best is trial 1 with value: 0.03094962748121891.
# [I 2026-01-30 16:39:43,270] Trial 7 finished with value: 0.030446557736168573 and parameters: {'lower_q': 10.035983850271904, 'upper_q': 88.19852928462629}. Best is trial 1 with value: 0.03094962748121891.
# [I 2026-01-30 16:39:43,338] Trial 6 finished with value: 0.03107999833270965 and parameters: {'lower_q': 9.276640477876242, 'upper_q': 63.61852988366162}. Best is trial 6 with value: 0.03107999833270965.
# [I 2026-01-30 16:39:43,566] Trial 5 finished with value: 0.030950798208908885 and parameters: {'lower_q': 27.62499561454289, 'upper_q': 76.20296643995275}. Best is trial 6 with value: 0.03107999833270965.
# [I 2026-01-30 16:41:15,373] Trial 10 finished with value: 0.03096383589824356 and parameters: {'lower_q': 14.507224341091112, 'upper_q': 71.46436825945503}. Best is trial 6 with value: 0.03107999833270965.
# [I 2026-01-30 16:41:15,438] Trial 8 finished with value: 0.031053308033362457 and parameters: {'lower_q': 19.383571066689193, 'upper_q': 68.30521543417198}. Best is trial 6 with value: 0.03107999833270965.
# [I 2026-01-30 16:41:15,615] Trial 9 finished with value: 0.031057252848779884 and parameters: {'lower_q': 23.791042918414366, 'upper_q': 69.61512146980571}. Best is trial 6 with value: 0.03107999833270965.
# [I 2026-01-30 16:41:15,820] Trial 11 finished with value: 0.030910123367409517 and parameters: {'lower_q': 26.49027836185949, 'upper_q': 78.99168964389463}. Best is trial 6 with value: 0.03107999833270965.
# [I 2026-01-30 16:42:47,751] Trial 14 finished with value: 0.03182573168212696 and parameters: {'lower_q': 44.46809496445257, 'upper_q': 57.50085931302857}. Best is trial 14 with value: 0.03182573168212696.
# [I 2026-01-30 16:42:47,789] Trial 13 finished with value: 0.03170751037844895 and parameters: {'lower_q': 42.17038980522621, 'upper_q': 59.11466343544876}. Best is trial 14 with value: 0.03182573168212696.
# [I 2026-01-30 16:42:47,823] Trial 12 finished with value: 0.03107666796903145 and parameters: {'lower_q': 16.134923613041924, 'upper_q': 66.22122199458435}. Best is trial 14 with value: 0.03182573168212696.
# [I 2026-01-30 16:42:48,006] Trial 15 finished with value: 0.031593483382097935 and parameters: {'lower_q': 37.3259973456701, 'upper_q': 57.25432006431711}. Best is trial 14 with value: 0.03182573168212696.
# [I 2026-01-30 16:44:20,120] Trial 16 finished with value: 0.03184836107579753 and parameters: {'lower_q': 43.65896031986608, 'upper_q': 56.05773909080314}. Best is trial 16 with value: 0.03184836107579753.
# [I 2026-01-30 16:44:20,155] Trial 18 finished with value: 0.03190322710892231 and parameters: {'lower_q': 44.796934534412074, 'upper_q': 55.52590702350647}. Best is trial 18 with value: 0.03190322710892231.
# [I 2026-01-30 16:44:20,213] Trial 19 finished with value: 0.03186113337890675 and parameters: {'lower_q': 44.35924823424358, 'upper_q': 56.64194875333026}. Best is trial 18 with value: 0.03190322710892231.
# [I 2026-01-30 16:44:20,230] Trial 17 finished with value: 0.031875216419320444 and parameters: {'lower_q': 44.83869960852306, 'upper_q': 56.60601327754665}. Best is trial 18 with value: 0.03190322710892231.
#         Algorithm                       Strategy  \
# 0  ALS_factors=10  robust_user_centric_weight_v2
#
#    Number of Optimization Trials  Best Val NDCG@20  Test NDCG@10  \
# 0                             20          0.031903      0.024617
#
#    Test NDCG@20  Test Precision@10  Test Precision@20  Final Train Time (s)  \
# 0       0.03352           0.046155            0.07796             14.940431
#
#                                          Best Params
# 0  {'lower_q': 44.796934534412074, 'upper_q': 55....

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="robust_user_centric_weight_v2", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)
# Out:
# [I 2026-01-30 22:48:07,175] A new study created in memory with name: no-name-97eead40-3592-4788-b4f9-06e4c688162e
# Running optimization for ALS_factors=100 with robust_user_centric_weight_v2...
# [I 2026-01-30 22:49:10,901] Trial 0 finished with value: 0.03453882003375528 and parameters: {'lower_q': 13.750371790181077, 'upper_q': 68.32057662723072}. Best is trial 0 with value: 0.03453882003375528.
# /home/coder/projects/rec-sys-research/weighting_is_fun/weighting_strategies.py:364: RuntimeWarning: overflow encountered in exp
#   weights = 1 / (1 + np.exp(-z_scores))
# [I 2026-01-30 22:50:14,594] Trial 1 finished with value: 0.035035381720773924 and parameters: {'lower_q': 23.418432411383144, 'upper_q': 67.56940102229336}. Best is trial 1 with value: 0.035035381720773924.
# [I 2026-01-30 22:51:18,295] Trial 2 finished with value: 0.03514546820418699 and parameters: {'lower_q': 20.403398988794798, 'upper_q': 84.9355830289397}. Best is trial 2 with value: 0.03514546820418699.
# [I 2026-01-30 22:52:21,971] Trial 3 finished with value: 0.0345522671616429 and parameters: {'lower_q': 16.714388726586083, 'upper_q': 67.71981018384545}. Best is trial 2 with value: 0.03514546820418699.
# [I 2026-01-30 22:53:25,606] Trial 4 finished with value: 0.03559565668391803 and parameters: {'lower_q': 22.37996803461394, 'upper_q': 72.77422544119975}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 22:54:29,385] Trial 5 finished with value: 0.03505837350204941 and parameters: {'lower_q': 10.682160762916343, 'upper_q': 72.86093274076188}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 22:55:33,188] Trial 6 finished with value: 0.03550045243315505 and parameters: {'lower_q': 36.21669298813812, 'upper_q': 76.7196980868413}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 22:56:37,021] Trial 7 finished with value: 0.034888796322838145 and parameters: {'lower_q': 26.93135138996238, 'upper_q': 57.92360299540799}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 22:57:40,772] Trial 8 finished with value: 0.0353139511054854 and parameters: {'lower_q': 42.55683499181174, 'upper_q': 92.64093674500248}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 22:58:44,543] Trial 9 finished with value: 0.02453727689007576 and parameters: {'lower_q': 39.568147720927065, 'upper_q': 55.38137412213721}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 22:59:48,272] Trial 10 finished with value: 0.03541467911799772 and parameters: {'lower_q': 5.279187755768138, 'upper_q': 83.04017846199523}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:00:52,042] Trial 11 finished with value: 0.034985878376950885 and parameters: {'lower_q': 34.80354035448394, 'upper_q': 79.04145770905802}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:01:55,741] Trial 12 finished with value: 0.035155661540534365 and parameters: {'lower_q': 30.581089506302135, 'upper_q': 75.63927764004562}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:02:59,485] Trial 13 finished with value: 0.03517356131299276 and parameters: {'lower_q': 33.45134622606022, 'upper_q': 62.55676784739736}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:04:03,244] Trial 14 finished with value: 0.03539517246155189 and parameters: {'lower_q': 27.66918583117056, 'upper_q': 88.18299685178135}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:05:06,977] Trial 15 finished with value: 0.035552915293546365 and parameters: {'lower_q': 39.44625188500077, 'upper_q': 77.1852852422153}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:06:10,703] Trial 16 finished with value: 0.03403607794871691 and parameters: {'lower_q': 44.91983463801657, 'upper_q': 80.53506655624554}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:07:14,396] Trial 17 finished with value: 0.034434687306857885 and parameters: {'lower_q': 20.346104792377467, 'upper_q': 70.81492074799539}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:08:18,091] Trial 18 finished with value: 0.03378831837108449 and parameters: {'lower_q': 30.33509791499269, 'upper_q': 61.266674172439714}. Best is trial 4 with value: 0.03559565668391803.
# [I 2026-01-30 23:09:21,752] Trial 19 finished with value: 0.03437253880236808 and parameters: {'lower_q': 39.18729085848532, 'upper_q': 88.51705925475773}. Best is trial 4 with value: 0.03559565668391803.
#          Algorithm                       Strategy  \
# 0  ALS_factors=100  robust_user_centric_weight_v2
#
#    Number of Optimization Trials  Best Val NDCG@20  Test NDCG@10  \
# 0                             20          0.035596      0.029174
#
#    Test NDCG@20  Test Precision@10  Test Precision@20  Final Train Time (s)  \
# 0      0.037284           0.051717            0.08176             49.476779
#
#                                          Best Params
# 0  {'lower_q': 22.37996803461394, 'upper_q': 72.7...

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="sigmoid_propensity", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="ALS_factors=10", n_trials=20, output_dir=results_folder)

# %%
run_hyperparameter_optimization(train_mat, val_mat, train_val_mat, test_mat, weighting_strategy="power_lift", algorithm="ALS_factors=100", n_trials=20, output_dir=results_folder)

# %%
import glob

all_results = []
# Match any CSV in the result folder
for f in glob.glob(f"{results_folder}/*.csv"):
    all_results.append(pd.read_csv(f))

if all_results:
    experiment_results = pd.concat(all_results)
    experiment_results = experiment_results.sort_values("Test NDCG@20", ascending=False)
    experiment_results.to_csv(results_filename, index=False)
else:
    print("No results found.")

experiment_results
# Out:
#          Algorithm                       Strategy  \
# 0  ALS_factors=100                     power_lift
# 0  ALS_factors=100                           bm25
# 0  ALS_factors=100                            pmi
# 0  ALS_factors=100                     log_idf
# 0  ALS_factors=100                          tfidf
# 0  ALS_factors=100                          power
# 0   ALS_factors=10                           bm25
# 0  ALS_factors=100            robust_user_centric
# 0   ALS_factors=10                     log_idf
# 0   ALS_factors=10                            pmi
# 0   ALS_factors=10                          tfidf
# 0   ALS_factors=10            robust_user_centric
# 0   ALS_factors=10                     power_lift
# 0   ALS_factors=10                            log
# 0   ALS_factors=10                          power
# 0  ALS_factors=100                   no_weighting
# 0   ALS_factors=10                   no_weighting
# 0  ALS_factors=100                            log
# 0  ALS_factors=100  robust_user_centric_weight_v2
# 0   ALS_factors=10  robust_user_centric_weight_v2
# 0   ALS_factors=10                     normalized
# 0  ALS_factors=100                     normalized
#
#    Number of Optimization Trials  Best Val NDCG@20  Test NDCG@10  \
# 0                             20          0.066747      0.059160
# 0                             20          0.060766      0.054619
# 0                              1          0.058450      0.052168
# 0                             20          0.059195      0.050841
# 0                              1          0.054623      0.050008
# 0                             20          0.053205      0.046338
# 0                             20          0.052554      0.043694
# 0                             20          0.053304      0.046057
# 0                             20          0.050574      0.041375
# 0                              1          0.047694      0.039062
# 0                              1          0.047966      0.039133
# 0                             20          0.047819      0.039118
# 0                             20          0.045741      0.037153
# 0                              1          0.045315      0.037112
# 0                             20          0.045252      0.037303
# 0                              1          0.045694      0.036990
# 0                              1          0.038249      0.030247
# 0                              1          0.049068      0.032056
# 0                             20          0.035596      0.029174
# 0                             20          0.031903      0.024617
# 0                              1          0.023524      0.018702
# 0                              1          0.016954      0.013379
#
#    Test NDCG@20  Test Precision@10  Test Precision@20  Final Train Time (s)  \
# 0      0.071397           0.102919           0.149900             49.503478
# 0      0.065655           0.093985           0.136512             49.606564
# 0      0.062659           0.089908           0.130247             49.521188
# 0      0.061604           0.087671           0.129272             49.558887
# 0      0.060760           0.086595           0.128038             52.586110
# 0      0.056201           0.080263           0.117913             49.611519
# 0      0.056092           0.078790           0.124467             14.996163
# 0      0.055862           0.079321           0.116859             49.531484
# 0      0.053683           0.075378           0.120844             14.992001
# 0      0.050912           0.071159           0.114757             14.978303
# 0      0.050901           0.071277           0.114584             14.837221
# 0      0.050901           0.070622           0.113674             14.950878
# 0      0.048696           0.068289           0.110765             14.691966
# 0      0.048103           0.065989           0.105739             15.070171
# 0      0.048092           0.065969           0.104961             14.987071
# 0      0.046245           0.065501           0.100690             52.191789
# 0      0.040574           0.056035           0.093654             14.714479
# 0      0.040190           0.055392           0.086068             53.062292
# 0      0.037284           0.051717           0.081760             49.476779
# 0      0.033520           0.046155           0.077960             14.940431
# 0      0.024418           0.031262           0.051934             14.978388
# 0      0.018054           0.024049           0.040970             49.578420
#
#                                          Best Params
# 0                         {'p': 0.37512124004563385}
# 0  {'bm25_k1': 3.464734272938415, 'bm25_b': 0.973...
# 0                                                 {}
# 0                 {'conf_alpha': 1.4332196930253005}
# 0                                                 {}
# 0                    {'power_p': 0.7138199050943289}
# 0  {'bm25_k1': 4.207673145032096, 'bm25_b': 0.990...
# 0                {'scale_factor': 9.976651717233675}
# 0                 {'conf_alpha': 2.7052621584068817}
# 0                                                 {}
# 0                                                 {}
# 0                {'scale_factor': 9.879081226043372}
# 0                         {'p': 0.21111167543799952}
# 0                                                 {}
# 0                    {'power_p': 0.5524939769068045}
# 0                                                 {}
# 0                                                 {}
# 0                                                 {}
# 0  {'lower_q': 22.37996803461394, 'upper_q': 72.7...
# 0  {'lower_q': 44.796934534412074, 'upper_q': 55....
# 0                                                 {}
# 0                                                 {}
